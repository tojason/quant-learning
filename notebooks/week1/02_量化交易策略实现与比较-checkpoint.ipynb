# %% [markdown]
# # 量化交易策略实现与比较
#
# 本笔记本演示了多种交易策略的实现和性能对比。我们将探索：
#
# - 移动平均线策略（单均线和双均线交叉）
# - RSI超买超卖策略
# - 布林带策略
# - MACD策略
# - 策略组合和绩效评估

# %% [markdown]
# ## 导入必要的库和工具

# %%
# 基础库
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from datetime import datetime, timedelta

# 回测框架
import backtrader as bt

# 导入自定义策略
import sys
sys.path.append('..')
from strategies.moving_average import MovingAverageStrategy, MovingAverageCrossStrategy
from strategies.rsi import RSIStrategy
from strategies.bollinger_bands import BollingerBandsStrategy
from strategies.macd import MACDStrategy

# 设置绘图样式
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (14, 7)
plt.rcParams['font.size'] = 12

# 显示所有列
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 获取市场数据
#
# 使用yfinance库获取回测用的历史数据：

# %%
# 定义回测的参数
ticker_symbol = 'SPY'  # 标普500ETF

start_date = '2023-02-28'
end_date = '2025-2-28'

# 获取数据
stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)
print(f"获取到{ticker_symbol}从{start_date}到{end_date}的数据，共{len(stock_data)}个交易日")
stock_data.head()


# 将 MultiIndex 列扁平化：取第一层作为新的列标签
stock_data.columns = stock_data.columns.get_level_values(0)
print("扁平化后的数据：")
print(stock_data.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 end_date = '2025-2-28'
#       7 # 获取数据
# ----> 8 stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)
#       9 print(f"获取到{ticker_symbol}从{start_date}到{end_date}的数据，共{len(stock_data)}个交易日")
#      10 stock_data.head()
#
# NameError: name 'ticker_symbol' is not defined

# %%
stock_data = stock_data[['Open', 'High', 'Low', 'Close', 'Volume']]

# %% [markdown]
# ## 准备回测数据
#
# 将数据转换为Backtrader可用的格式：

# %%
# 将数据保存为CSV用于Backtrader
csv_file = f"{ticker_symbol}_data.csv"
stock_data.to_csv(csv_file)

# 辅助函数：创建Backtrader数据源
def create_bt_data_feed(csv_file):
    return bt.feeds.YahooFinanceCSVData(
        dataname=csv_file,
        fromdate=datetime.strptime(start_date, '%Y-%m-%d'),
        todate=datetime.strptime(end_date, '%Y-%m-%d'),
        reverse=False
    )
    
# 辅助函数：运行回测
def run_backtest(strategy_class, data_feed, cash=100000.0, commission=0.001, **strategy_params):
    # 创建Cerebro引擎
    cerebro = bt.Cerebro()
    
    # 添加数据
    cerebro.adddata(data_feed)
    
    # 添加策略
    cerebro.addstrategy(strategy_class, **strategy_params)
    
    # 设置初始资金和佣金
    cerebro.broker.setcash(cash)
    cerebro.broker.setcommission(commission=commission)
    
    # 添加分析器
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe', riskfreerate=0.0)
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')
    
    # 运行策略
    initial_value = cerebro.broker.getvalue()
    print(f'初始资金: ${initial_value:.2f}')
    
    results = cerebro.run()
    strategy = results[0]
    
    # 获取最终资金
    final_value = cerebro.broker.getvalue()
    print(f'最终资金: ${final_value:.2f}')
    print(f'盈亏: ${final_value - initial_value:.2f} ({(final_value / initial_value - 1) * 100:.2f}%)')
    
    # 分析结果
    print('\n--- 性能指标 ---')
    print(f'夏普比率: {strategy.analyzers.sharpe.get_analysis()["sharperatio"]:.4f}')
    print(f'最大回撤: {strategy.analyzers.drawdown.get_analysis()["max"]["drawdown"]:.2f}%')
    print(f'年化收益率: {strategy.analyzers.returns.get_analysis()["rnorm100"]:.2f}%')
    
    return cerebro, strategy, results

# %% [markdown]
# ## 移动平均线交叉策略回测
#
# 实现并回测移动平均线策略：

# %%
class MovingAverageCrossStrategy(bt.Strategy):
    """
    短期均线(SMA_Fast)上穿长期均线(SMA_Slow) => 全仓买入
    下穿 => 卖出全部
    """
    params = (
        ('fast_period', 20),
        ('slow_period', 50),
        ('printlog', True),
    )
    
    def log(self, txt, dt=None):
        if self.params.printlog:
            dt = dt or self.datas[0].datetime.date(0)
            print(f'{dt.isoformat()}, {txt}')
    
    def __init__(self):
        self.order = None
        
        # 移动平均线
        self.fast_ma = bt.indicators.SimpleMovingAverage(
            self.datas[0].close, period=self.params.fast_period
        )
        self.slow_ma = bt.indicators.SimpleMovingAverage(
            self.datas[0].close, period=self.params.slow_period
        )
        
        # 交叉信号
        self.crossover = bt.indicators.CrossOver(self.fast_ma, self.slow_ma)
    
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'买单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
            else:
                self.log(f'卖单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单取消/拒绝')
        
        self.order = None
    
    def next(self):
        if self.order:
            return
        
        # 若无持仓，且短期MA上穿长期MA => 全仓买入
        if not self.position:
            if self.crossover > 0:
                cash = self.broker.getcash()
                price = self.datas[0].close[0]
                size = int(cash // price)
                if size > 0:
                    self.log(f'买入信号 (fast_ma>slow_ma), 全仓买入: {size} 股')
                    self.order = self.buy(size=size)
        else:
            # 若已持仓，且短期MA下穿长期MA => 卖出全部
            if self.crossover < 0:
                self.log(f'卖出信号 (fast_ma<slow_ma), 卖出全部: {self.position.size} 股')
                self.order = self.sell(size=self.position.size)
    
    def stop(self):
        self.log(f'策略结束，期末资金: {self.broker.getvalue():.2f}')

# %%
# ---------------------------
# 3. 配置并运行回测
# ---------------------------

# 创建 Cerebro 回测引擎
cerebro = bt.Cerebro()
cerebro.broker.setcash(100000.0)  # 设置初始资金

# 将策略加入引擎，同时打开日志便于调试（printlog=True）
cerebro.addstrategy(MovingAverageCrossStrategy, fast_period=20, slow_period=50, printlog=True)

# 创建数据源并添加到 Cerebro
data_feed = bt.feeds.PandasData(dataname=stock_data)
cerebro.adddata(data_feed)

# 输出初始资金
print('初始资金: %.2f' % cerebro.broker.getvalue())

# 运行回测
cerebro.run()

# 输出最终资金
print('期末资金: %.2f' % cerebro.broker.getvalue())

# ---------------------------
# 4. 绘制回测结果图
# ---------------------------
# %matplotlib inline
cerebro.plot(style='candlestick',iplot = False)
# Out:
# 初始资金: 100000.00
# 2023-07-10, 买入信号 (fast_ma>slow_ma), 全仓买入: 1657 股
# 2023-07-11, 买单执行, 价格: 60.11, 股数: 1657
# 2023-08-02, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1657 股
# 2023-08-03, 卖单执行, 价格: 55.98, 股数: -1657
# 2023-10-30, 买入信号 (fast_ma>slow_ma), 全仓买入: 1747 股
# 2023-10-31, 订单取消/拒绝
# 2024-03-18, 买入信号 (fast_ma>slow_ma), 全仓买入: 1777 股
# 2024-03-19, 买单执行, 价格: 52.31, 股数: 1777
# 2024-03-26, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1777 股
# 2024-03-27, 卖单执行, 价格: 46.01, 股数: -1777
# 2024-05-15, 买入信号 (fast_ma>slow_ma), 全仓买入: 1659 股
# 2024-05-16, 订单取消/拒绝
# 2024-10-10, 买入信号 (fast_ma>slow_ma), 全仓买入: 1156 股
# 2024-10-11, 买单执行, 价格: 68.50, 股数: 1156
# 2024-12-11, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1156 股
# 2024-12-12, 卖单执行, 价格: 68.89, 股数: -1156
# 2024-12-24, 买入信号 (fast_ma>slow_ma), 全仓买入: 1141 股
# 2024-12-25, 买单执行, 价格: 72.00, 股数: 1141
# 2025-01-16, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1141 股
# 2025-01-17, 卖单执行, 价格: 65.59, 股数: -1141
# 2025-02-14, 买入信号 (fast_ma>slow_ma), 全仓买入: 1024 股
# 2025-02-17, 订单取消/拒绝
# 2025-02-27, 策略结束，期末资金: 75103.39
# 期末资金: 75103.39
# [[<Figure size 1400x700 with 5 Axes>]]

# %% [markdown]
# ## RSI策略回测
#
# 实现并回测基于RSI的交易策略：

# %%
class RSIStrategy(bt.Strategy):
    """
    - 当 RSI < 30 => 全仓买入
    - 当 RSI > 70 => 卖出全部
    """
    params = (
        ('rsi_period', 14),
        ('rsi_low', 30),
        ('rsi_high', 70),
        ('printlog', True),
    )
    
    def log(self, txt, dt=None):
        if self.params.printlog:
            dt = dt or self.datas[0].datetime.date(0)
            print(f'{dt.isoformat()}, {txt}')
    
    def __init__(self):
        self.order = None
        self.rsi = bt.indicators.RSI_SMA(self.datas[0], period=self.params.rsi_period)
    
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'买单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
            else:
                self.log(f'卖单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单取消/拒绝')
        self.order = None
    
    def next(self):
        price = self.datas[0].close[0]
        rsi_value = self.rsi[0]
        self.log(f'收盘价: {price:.2f}, RSI: {rsi_value:.2f}')
        
        if self.order:
            return
        
        # 若无持仓，且 RSI < 30 => 全仓买入
        if not self.position:
            if rsi_value < self.params.rsi_low:
                cash = self.broker.getcash()
                size = int(cash // price)
                if size > 0:
                    self.log(f'买入信号 (RSI<{self.params.rsi_low}), 全仓买入: {size} 股')
                    self.order = self.buy(size=size)
        else:
            # 有持仓时，若 RSI > 70 => 卖出全部
            if rsi_value > self.params.rsi_high:
                self.log(f'卖出信号 (RSI>{self.params.rsi_high}), 卖出全部: {self.position.size} 股')
                self.order = self.sell(size=self.position.size)
    
    def stop(self):
        self.log(f'策略结束，期末资金: {self.broker.getvalue():.2f}')

# %%
# ---------------------------
# 3. 创建并运行回测引擎
# ---------------------------

# 创建 Cerebro 引擎
cerebro = bt.Cerebro()

# 设置初始资金
cerebro.broker.setcash(100000.0)

# 添加数据源
data_feed = bt.feeds.PandasData(dataname=stock_data)
cerebro.adddata(data_feed)

# 添加策略
cerebro.addstrategy(RSIStrategy, rsi_period=14, rsi_low=30, rsi_high=70, printlog=True)

# 打印初始资金
print(f'初始资金: {cerebro.broker.getvalue():.2f}')

# 运行回测
results = cerebro.run()
final_value = cerebro.broker.getvalue()
print(f'回测结束，期末资金: {final_value:.2f}')
# Out:
# 初始资金: 100000.00
# 2023-03-20, 收盘价: 61.90, RSI: 69.25
# 2023-03-21, 收盘价: 61.38, RSI: 67.95
# 2023-03-22, 收盘价: 62.44, RSI: 73.73
# 2023-03-23, 收盘价: 68.24, RSI: 81.06
# 2023-03-24, 收盘价: 69.40, RSI: 83.13
# 2023-03-27, 收盘价: 67.84, RSI: 81.65
# 2023-03-28, 收盘价: 63.77, RSI: 68.29
# 2023-03-29, 收盘价: 67.49, RSI: 71.80
# 2023-03-30, 收盘价: 69.23, RSI: 75.88
# 2023-03-31, 收盘价: 68.75, RSI: 75.55
# 2023-04-03, 收盘价: 70.74, RSI: 76.85
# 2023-04-04, 收盘价: 73.19, RSI: 78.61
# 2023-04-06, 收盘价: 74.40, RSI: 79.27
# 2023-04-07, 收盘价: 75.46, RSI: 78.92
# 2023-04-10, 收盘价: 70.91, RSI: 64.36
# 2023-04-11, 收盘价: 71.80, RSI: 66.43
# 2023-04-12, 收盘价: 75.57, RSI: 69.07
# 2023-04-13, 收盘价: 70.86, RSI: 53.93
# 2023-04-14, 收盘价: 73.37, RSI: 55.73
# 2023-04-17, 收盘价: 71.21, RSI: 54.78
# 2023-04-18, 收盘价: 69.90, RSI: 59.42
# 2023-04-19, 收盘价: 71.31, RSI: 56.32
# 2023-04-20, 收盘价: 75.62, RSI: 59.74
# 2023-04-21, 收盘价: 71.27, RSI: 53.43
# 2023-04-24, 收盘价: 68.44, RSI: 46.93
# 2023-04-25, 收盘价: 67.99, RSI: 42.69
# 2023-04-26, 收盘价: 63.49, RSI: 35.94
# 2023-04-27, 收盘价: 62.35, RSI: 33.14
# 2023-04-28, 收盘价: 60.23, RSI: 35.35
# 2023-05-04, 收盘价: 58.70, RSI: 32.34
# 2023-05-05, 收盘价: 58.29, RSI: 24.39
# 2023-05-05, 买入信号 (RSI<30), 全仓买入: 1715 股
# 2023-05-08, 订单取消/拒绝
# 2023-05-08, 收盘价: 58.76, RSI: 29.48
# 2023-05-08, 买入信号 (RSI<30), 全仓买入: 1701 股
# 2023-05-09, 订单取消/拒绝
# 2023-05-09, 收盘价: 57.23, RSI: 21.69
# 2023-05-09, 买入信号 (RSI<30), 全仓买入: 1747 股
# 2023-05-10, 订单取消/拒绝
# 2023-05-10, 收盘价: 55.87, RSI: 22.31
# 2023-05-10, 买入信号 (RSI<30), 全仓买入: 1789 股
# 2023-05-11, 订单取消/拒绝
# 2023-05-11, 收盘价: 55.18, RSI: 22.82
# 2023-05-11, 买入信号 (RSI<30), 全仓买入: 1812 股
# 2023-05-12, 订单取消/拒绝
# 2023-05-12, 收盘价: 53.14, RSI: 17.23
# 2023-05-12, 买入信号 (RSI<30), 全仓买入: 1881 股
# 2023-05-15, 订单取消/拒绝
# 2023-05-15, 收盘价: 53.55, RSI: 3.69
# 2023-05-15, 买入信号 (RSI<30), 全仓买入: 1867 股
# 2023-05-16, 订单取消/拒绝
# 2023-05-16, 收盘价: 53.22, RSI: 4.44
# 2023-05-16, 买入信号 (RSI<30), 全仓买入: 1879 股
# 2023-05-17, 订单取消/拒绝
# 2023-05-17, 收盘价: 54.54, RSI: 12.05
# 2023-05-17, 买入信号 (RSI<30), 全仓买入: 1833 股
# 2023-05-18, 买单执行, 价格: 54.39, 股数: 1833
# 2023-05-18, 收盘价: 57.36, RSI: 24.29
# 2023-05-19, 收盘价: 58.31, RSI: 34.87
# 2023-05-22, 收盘价: 58.76, RSI: 39.07
# 2023-05-23, 收盘价: 57.06, RSI: 40.11
# 2023-05-24, 收盘价: 57.36, RSI: 45.48
# 2023-05-25, 收盘价: 59.44, RSI: 53.49
# 2023-05-26, 收盘价: 60.47, RSI: 55.03
# 2023-05-29, 收盘价: 62.23, RSI: 64.49
# 2023-05-30, 收盘价: 63.03, RSI: 71.47
# 2023-05-30, 卖出信号 (RSI>70), 卖出全部: 1833 股
# 2023-05-31, 卖单执行, 价格: 63.10, 股数: -1833
# 2023-05-31, 收盘价: 63.10, RSI: 74.68
# 2023-06-01, 收盘价: 61.42, RSI: 76.37
# 2023-06-02, 收盘价: 60.02, RSI: 69.40
# 2023-06-05, 收盘价: 59.62, RSI: 69.11
# 2023-06-06, 收盘价: 58.44, RSI: 61.74
# 2023-06-07, 收盘价: 59.25, RSI: 56.47
# 2023-06-08, 收盘价: 56.48, RSI: 44.42
# 2023-06-09, 收盘价: 57.55, RSI: 46.46
# 2023-06-12, 收盘价: 57.56, RSI: 51.61
# 2023-06-13, 收盘价: 62.16, RSI: 62.20
# 2023-06-14, 收盘价: 62.22, RSI: 57.88
# 2023-06-15, 收盘价: 60.81, RSI: 50.96
# 2023-06-16, 收盘价: 60.16, RSI: 43.89
# 2023-06-19, 收盘价: 61.43, RSI: 45.39
# 2023-06-20, 收盘价: 59.74, RSI: 41.15
# 2023-06-21, 收盘价: 57.44, RSI: 39.86
# 2023-06-26, 收盘价: 55.38, RSI: 38.56
# 2023-06-27, 收盘价: 55.47, RSI: 39.61
# 2023-06-28, 收盘价: 54.77, RSI: 40.58
# 2023-06-29, 收盘价: 55.06, RSI: 38.94
# 2023-06-30, 收盘价: 56.79, RSI: 50.86
# 2023-07-03, 收盘价: 59.21, RSI: 54.31
# 2023-07-04, 收盘价: 62.01, RSI: 60.09
# 2023-07-05, 收盘价: 61.99, RSI: 49.52
# 2023-07-06, 收盘价: 63.02, RSI: 52.17
# 2023-07-07, 收盘价: 63.00, RSI: 56.41
# 2023-07-10, 收盘价: 60.33, RSI: 50.44
# 2023-07-11, 收盘价: 61.29, RSI: 49.63
# 2023-07-12, 收盘价: 58.43, RSI: 46.73
# 2023-07-13, 收盘价: 60.80, RSI: 58.40
# 2023-07-14, 收盘价: 61.31, RSI: 66.04
# 2023-07-17, 收盘价: 60.43, RSI: 62.87
# 2023-07-18, 收盘价: 59.51, RSI: 62.16
# 2023-07-19, 收盘价: 58.54, RSI: 58.64
# 2023-07-20, 收盘价: 57.11, RSI: 50.82
# 2023-07-21, 收盘价: 56.97, RSI: 43.61
# 2023-07-24, 收盘价: 57.95, RSI: 37.10
# 2023-07-25, 收盘价: 58.63, RSI: 39.76
# 2023-07-26, 收盘价: 58.04, RSI: 34.43
# 2023-07-27, 收盘价: 57.46, RSI: 33.25
# 2023-07-28, 收盘价: 58.37, RSI: 43.37
# 2023-07-31, 收盘价: 57.28, RSI: 36.56
# 2023-08-01, 收盘价: 57.00, RSI: 44.19
# 2023-08-02, 收盘价: 56.03, RSI: 28.14
# 2023-08-02, 买入信号 (RSI<30), 全仓买入: 2069 股
# 2023-08-03, 买单执行, 价格: 55.98, 股数: 2069
# 2023-08-03, 收盘价: 56.32, RSI: 26.75
# 2023-08-04, 收盘价: 57.41, RSI: 36.20
# 2023-08-07, 收盘价: 57.15, RSI: 38.54
# 2023-08-08, 收盘价: 56.86, RSI: 41.24
# 2023-08-09, 收盘价: 56.01, RSI: 43.86
# 2023-08-10, 收盘价: 56.24, RSI: 46.04
# 2023-08-11, 收盘价: 54.24, RSI: 31.71
# 2023-08-14, 收盘价: 52.77, RSI: 23.19
# 2023-08-15, 收盘价: 50.86, RSI: 20.66
# 2023-08-16, 收盘价: 48.47, RSI: 18.01
# 2023-08-17, 收盘价: 48.53, RSI: 12.73
# 2023-08-18, 收盘价: 48.34, RSI: 13.67
# 2023-08-21, 收盘价: 47.52, RSI: 13.10
# 2023-08-22, 收盘价: 48.88, RSI: 22.95
# 2023-08-23, 收盘价: 48.15, RSI: 20.06
# 2023-08-24, 收盘价: 49.41, RSI: 21.07
# 2023-08-25, 收盘价: 47.74, RSI: 19.11
# 2023-08-28, 收盘价: 48.47, RSI: 23.22
# 2023-08-29, 收盘价: 50.51, RSI: 33.68
# 2023-08-30, 收盘价: 51.17, RSI: 35.33
# 2023-08-31, 收盘价: 50.94, RSI: 39.38
# 2023-09-01, 收盘价: 51.06, RSI: 43.96
# 2023-09-04, 收盘价: 51.32, RSI: 51.87
# 2023-09-05, 收盘价: 51.32, RSI: 64.11
# 2023-09-06, 收盘价: 53.48, RSI: 70.28
# 2023-09-06, 卖出信号 (RSI>70), 卖出全部: 2069 股
# 2023-09-07, 卖单执行, 价格: 53.17, 股数: -2069
# 2023-09-07, 收盘价: 51.20, RSI: 60.01
# 2023-09-08, 收盘价: 51.35, RSI: 64.04
# 2023-09-11, 收盘价: 51.51, RSI: 60.59
# 2023-09-12, 收盘价: 50.81, RSI: 60.69
# 2023-09-13, 收盘价: 50.59, RSI: 55.16
# 2023-09-14, 收盘价: 50.09, RSI: 61.50
# 2023-09-15, 收盘价: 51.47, RSI: 63.83
# 2023-09-18, 收盘价: 50.69, RSI: 50.93
# 2023-09-19, 收盘价: 50.54, RSI: 46.50
# 2023-09-20, 收盘价: 50.46, RSI: 47.27
# 2023-09-21, 收盘价: 49.41, RSI: 41.63
# 2023-09-22, 收盘价: 50.97, RSI: 48.44
# 2023-09-25, 收盘价: 49.71, RSI: 43.52
# 2023-09-26, 收盘价: 48.96, RSI: 29.49
# 2023-09-26, 买入信号 (RSI<30), 全仓买入: 2249 股
# 2023-09-27, 买单执行, 价格: 48.96, 股数: 2249
# 2023-09-27, 收盘价: 49.26, RSI: 39.30
# 2023-09-28, 收盘价: 49.41, RSI: 39.30
# 2023-10-09, 收盘价: 50.32, RSI: 43.91
# 2023-10-10, 收盘价: 53.06, RSI: 59.53
# 2023-10-11, 收盘价: 53.43, RSI: 61.86
# 2023-10-12, 收盘价: 53.07, RSI: 62.58
# 2023-10-13, 收盘价: 52.69, RSI: 55.64
# 2023-10-16, 收盘价: 51.30, RSI: 52.69
# 2023-10-17, 收盘价: 52.55, RSI: 58.00
# 2023-10-18, 收盘价: 50.46, RSI: 50.00
# 2023-10-19, 收盘价: 50.11, RSI: 52.51
# 2023-10-20, 收盘价: 47.72, RSI: 38.93
# 2023-10-23, 收盘价: 47.13, RSI: 40.78
# 2023-10-24, 收盘价: 47.91, RSI: 46.28
# 2023-10-25, 收盘价: 48.46, RSI: 47.18
# 2023-10-26, 收盘价: 48.35, RSI: 46.27
# 2023-10-27, 收盘价: 49.50, RSI: 47.19
# 2023-10-30, 收盘价: 53.29, RSI: 50.74
# 2023-10-31, 收盘价: 54.71, RSI: 53.86
# 2023-11-01, 收盘价: 54.95, RSI: 55.70
# 2023-11-02, 收盘价: 55.08, RSI: 57.35
# 2023-11-03, 收盘价: 56.37, RSI: 65.72
# 2023-11-06, 收盘价: 56.97, RSI: 64.29
# 2023-11-07, 收盘价: 57.48, RSI: 75.25
# 2023-11-07, 卖出信号 (RSI>70), 卖出全部: 2249 股
# 2023-11-08, 卖单执行, 价格: 57.03, 股数: -2249
# 2023-11-08, 收盘价: 57.21, RSI: 75.68
# 2023-11-09, 收盘价: 56.55, RSI: 86.51
# 2023-11-10, 收盘价: 56.27, RSI: 88.85
# 2023-11-13, 收盘价: 58.03, RSI: 89.70
# 2023-11-14, 收盘价: 58.78, RSI: 89.86
# 2023-11-15, 收盘价: 59.64, RSI: 91.22
# 2023-11-16, 收盘价: 59.26, RSI: 87.70
# 2023-11-17, 收盘价: 59.56, RSI: 83.18
# 2023-11-20, 收盘价: 57.64, RSI: 64.67
# 2023-11-21, 收盘价: 58.56, RSI: 66.95
# 2023-11-22, 收盘价: 58.13, RSI: 63.94
# 2023-11-23, 收盘价: 58.12, RSI: 59.05
# 2023-11-24, 收盘价: 57.32, RSI: 51.76
# 2023-11-27, 收盘价: 57.55, RSI: 50.36
# 2023-11-28, 收盘价: 57.43, RSI: 51.16
# 2023-11-29, 收盘价: 57.68, RSI: 56.22
# 2023-11-30, 收盘价: 58.64, RSI: 62.17
# 2023-12-01, 收盘价: 59.74, RSI: 59.43
# 2023-12-04, 收盘价: 59.22, RSI: 52.47
# 2023-12-05, 收盘价: 57.49, RSI: 38.89
# 2023-12-06, 收盘价: 57.72, RSI: 41.94
# 2023-12-07, 收盘价: 56.57, RSI: 35.60
# 2023-12-08, 收盘价: 57.17, RSI: 47.42
# 2023-12-11, 收盘价: 59.64, RSI: 55.11
# 2023-12-12, 收盘价: 60.18, RSI: 59.55
# 2023-12-13, 收盘价: 59.80, RSI: 57.58
# 2023-12-14, 收盘价: 61.24, RSI: 66.72
# 2023-12-15, 收盘价: 60.03, RSI: 59.80
# 2023-12-18, 收盘价: 59.16, RSI: 56.43
# 2023-12-19, 收盘价: 59.45, RSI: 56.56
# 2023-12-20, 收盘价: 58.66, RSI: 50.07
# 2023-12-21, 收盘价: 59.76, RSI: 50.07
# 2023-12-22, 收盘价: 58.51, RSI: 47.48
# 2023-12-25, 收盘价: 56.57, RSI: 46.79
# 2023-12-26, 收盘价: 55.11, RSI: 41.58
# 2023-12-27, 收盘价: 57.31, RSI: 52.23
# 2023-12-28, 收盘价: 57.00, RSI: 49.48
# 2023-12-29, 收盘价: 58.42, RSI: 45.97
# 2024-01-02, 收盘价: 57.29, RSI: 40.83
# 2024-01-03, 收盘价: 56.23, RSI: 39.15
# 2024-01-04, 收盘价: 55.57, RSI: 31.94
# 2024-01-05, 收盘价: 55.34, RSI: 34.05
# 2024-01-08, 收盘价: 54.29, RSI: 33.64
# 2024-01-09, 收盘价: 56.22, RSI: 40.26
# 2024-01-10, 收盘价: 54.62, RSI: 38.37
# 2024-01-11, 收盘价: 56.65, RSI: 41.49
# 2024-01-12, 收盘价: 55.27, RSI: 41.20
# 2024-01-15, 收盘价: 54.09, RSI: 42.96
# 2024-01-16, 收盘价: 53.37, RSI: 44.86
# 2024-01-17, 收盘价: 52.29, RSI: 34.11
# 2024-01-18, 收盘价: 53.74, RSI: 40.38
# 2024-01-19, 收盘价: 54.81, RSI: 39.13
# 2024-01-22, 收盘价: 53.78, RSI: 39.36
# 2024-01-23, 收盘价: 53.85, RSI: 42.31
# 2024-01-24, 收盘价: 51.67, RSI: 38.55
# 2024-01-25, 收盘价: 51.37, RSI: 38.39
# 2024-01-26, 收盘价: 49.51, RSI: 36.67
# 2024-01-29, 收盘价: 48.35, RSI: 27.00
# 2024-01-29, 买入信号 (RSI<30), 全仓买入: 2653 股
# 2024-01-30, 买单执行, 价格: 48.20, 股数: 2653
# 2024-01-30, 收盘价: 47.17, RSI: 27.68
# 2024-01-31, 收盘价: 44.94, RSI: 15.35
# 2024-02-01, 收盘价: 46.50, RSI: 24.33
# 2024-02-02, 收盘价: 44.54, RSI: 23.27
# 2024-02-05, 收盘价: 44.33, RSI: 23.95
# 2024-02-06, 收盘价: 47.44, RSI: 37.47
# 2024-02-07, 收盘价: 48.42, RSI: 35.93
# 2024-02-08, 收盘价: 49.61, RSI: 36.33
# 2024-02-19, 收盘价: 51.65, RSI: 44.69
# 2024-02-20, 收盘价: 51.35, RSI: 43.84
# 2024-02-21, 收盘价: 50.50, RSI: 46.90
# 2024-02-22, 收盘价: 51.05, RSI: 49.17
# 2024-02-23, 收盘价: 51.31, RSI: 55.12
# 2024-02-26, 收盘价: 51.90, RSI: 60.43
# 2024-02-27, 收盘价: 53.10, RSI: 67.43
# 2024-02-28, 收盘价: 50.48, RSI: 65.89
# 2024-02-29, 收盘价: 51.90, RSI: 65.61
# 2024-03-01, 收盘价: 52.86, RSI: 75.53
# 2024-03-01, 卖出信号 (RSI>70), 卖出全部: 2653 股
# 2024-03-04, 卖单执行, 价格: 53.99, 股数: -2653
# 2024-03-04, 收盘价: 54.53, RSI: 78.72
# 2024-03-05, 收盘价: 54.16, RSI: 72.35
# 2024-03-06, 收盘价: 52.38, RSI: 62.50
# 2024-03-07, 收盘价: 51.00, RSI: 54.35
# 2024-03-08, 收盘价: 52.06, RSI: 51.36
# 2024-03-11, 收盘价: 51.77, RSI: 51.39
# 2024-03-12, 收盘价: 52.67, RSI: 57.23
# 2024-03-13, 收盘价: 52.62, RSI: 55.36
# 2024-03-14, 收盘价: 51.50, RSI: 50.61
# 2024-03-15, 收盘价: 52.10, RSI: 50.64
# 2024-03-18, 收盘价: 52.40, RSI: 47.57
# 2024-03-19, 收盘价: 48.52, RSI: 43.79
# 2024-03-20, 收盘价: 47.36, RSI: 35.36
# 2024-03-21, 收盘价: 49.38, RSI: 39.51
# 2024-03-22, 收盘价: 49.01, RSI: 31.92
# 2024-03-25, 收盘价: 47.67, RSI: 30.05
# 2024-03-26, 收盘价: 46.77, RSI: 31.76
# 2024-03-27, 收盘价: 45.04, RSI: 31.04
# 2024-03-28, 收盘价: 46.19, RSI: 31.47
# 2024-03-29, 收盘价: 45.69, RSI: 31.04
# 2024-04-01, 收盘价: 45.54, RSI: 26.66
# 2024-04-01, 买入信号 (RSI<30), 全仓买入: 3154 股
# 2024-04-02, 订单取消/拒绝
# 2024-04-02, 收盘价: 45.49, RSI: 26.68
# 2024-04-02, 买入信号 (RSI<30), 全仓买入: 3158 股
# 2024-04-03, 买单执行, 价格: 45.38, 股数: 3158
# 2024-04-03, 收盘价: 45.01, RSI: 27.83
# 2024-04-08, 收盘价: 43.65, RSI: 22.58
# 2024-04-09, 收盘价: 44.00, RSI: 22.83
# 2024-04-10, 收盘价: 42.90, RSI: 27.84
# 2024-04-11, 收盘价: 46.88, RSI: 48.46
# 2024-04-12, 收盘价: 47.66, RSI: 43.96
# 2024-04-15, 收盘价: 48.77, RSI: 49.20
# 2024-04-16, 收盘价: 47.50, RSI: 49.43
# 2024-04-17, 收盘价: 49.21, RSI: 57.78
# 2024-04-18, 收盘价: 47.37, RSI: 57.35
# 2024-04-19, 收盘价: 45.64, RSI: 48.30
# 2024-04-22, 收盘价: 46.46, RSI: 52.32
# 2024-04-23, 收盘价: 45.90, RSI: 51.07
# 2024-04-24, 收盘价: 46.82, RSI: 53.70
# 2024-04-25, 收盘价: 48.02, RSI: 58.05
# 2024-04-26, 收盘价: 50.48, RSI: 67.24
# 2024-04-29, 收盘价: 51.03, RSI: 67.58
# 2024-04-30, 收盘价: 50.62, RSI: 69.94
# 2024-05-06, 收盘价: 50.76, RSI: 62.50
# 2024-05-07, 收盘价: 50.25, RSI: 58.49
# 2024-05-08, 收盘价: 50.58, RSI: 56.26
# 2024-05-09, 收盘价: 50.77, RSI: 62.18
# 2024-05-10, 收盘价: 50.58, RSI: 55.74
# 2024-05-13, 收盘价: 50.57, RSI: 65.97
# 2024-05-14, 收盘价: 50.23, RSI: 76.61
# 2024-05-14, 卖出信号 (RSI>70), 卖出全部: 3158 股
# 2024-05-15, 卖单执行, 价格: 49.78, 股数: -3158
# 2024-05-15, 收盘价: 49.39, RSI: 66.97
# 2024-05-16, 收盘价: 48.93, RSI: 67.67
# 2024-05-17, 收盘价: 49.18, RSI: 64.94
# 2024-05-20, 收盘价: 49.84, RSI: 62.38
# 2024-05-21, 收盘价: 49.61, RSI: 41.55
# 2024-05-22, 收盘价: 50.97, RSI: 49.50
# 2024-05-23, 收盘价: 50.51, RSI: 49.08
# 2024-05-24, 收盘价: 49.46, RSI: 40.61
# 2024-05-27, 收盘价: 52.32, RSI: 61.21
# 2024-05-28, 收盘价: 52.26, RSI: 59.38
# 2024-05-29, 收盘价: 52.49, RSI: 59.56
# 2024-05-30, 收盘价: 52.55, RSI: 61.10
# 2024-05-31, 收盘价: 52.69, RSI: 61.81
# 2024-06-03, 收盘价: 54.06, RSI: 69.08
# 2024-06-04, 收盘价: 53.32, RSI: 69.77
# 2024-06-05, 收盘价: 51.77, RSI: 62.91
# 2024-06-06, 收盘价: 51.21, RSI: 58.98
# 2024-06-07, 收盘价: 50.60, RSI: 53.37
# 2024-06-11, 收盘价: 51.11, RSI: 56.48
# 2024-06-12, 收盘价: 51.60, RSI: 52.93
# 2024-06-13, 收盘价: 52.70, RSI: 59.69
# 2024-06-14, 收盘价: 53.00, RSI: 66.73
# 2024-06-17, 收盘价: 53.83, RSI: 58.85
# 2024-06-18, 收盘价: 54.38, RSI: 61.75
# 2024-06-19, 收盘价: 55.17, RSI: 63.98
# 2024-06-20, 收盘价: 56.08, RSI: 66.91
# 2024-06-21, 收盘价: 56.81, RSI: 68.66
# 2024-06-24, 收盘价: 57.13, RSI: 65.39
# 2024-06-25, 收盘价: 54.96, RSI: 57.18
# 2024-06-26, 收盘价: 56.30, RSI: 70.21
# 2024-06-27, 收盘价: 56.05, RSI: 72.20
# 2024-06-28, 收盘价: 57.16, RSI: 78.77
# 2024-07-01, 收盘价: 56.48, RSI: 73.21
# 2024-07-02, 收盘价: 55.55, RSI: 66.44
# 2024-07-03, 收盘价: 56.06, RSI: 64.71
# 2024-07-04, 收盘价: 56.06, RSI: 63.76
# 2024-07-05, 收盘价: 56.06, RSI: 60.84
# 2024-07-08, 收盘价: 59.53, RSI: 69.49
# 2024-07-09, 收盘价: 59.78, RSI: 68.19
# 2024-07-10, 收盘价: 60.60, RSI: 67.97
# 2024-07-11, 收盘价: 62.22, RSI: 70.08
# 2024-07-12, 收盘价: 63.66, RSI: 72.38
# 2024-07-15, 收盘价: 64.30, RSI: 85.76
# 2024-07-16, 收盘价: 65.03, RSI: 85.06
# 2024-07-17, 收盘价: 63.21, RSI: 75.53
# 2024-07-18, 收盘价: 63.00, RSI: 72.26
# 2024-07-19, 收盘价: 63.01, RSI: 76.22
# 2024-07-22, 收盘价: 63.93, RSI: 83.68
# 2024-07-23, 收盘价: 58.80, RSI: 58.03
# 2024-07-24, 收盘价: 58.98, RSI: 58.47
# 2024-07-25, 收盘价: 58.20, RSI: 55.94
# 2024-07-26, 收盘价: 58.23, RSI: 45.54
# 2024-07-29, 收盘价: 58.00, RSI: 43.89
# 2024-07-30, 收盘价: 58.47, RSI: 42.51
# 2024-07-31, 收盘价: 59.60, RSI: 40.45
# 2024-08-01, 收盘价: 59.26, RSI: 32.57
# 2024-08-02, 收盘价: 56.60, RSI: 23.70
# 2024-08-02, 买入信号 (RSI<30), 全仓买入: 2783 股
# 2024-08-05, 买单执行, 价格: 55.80, 股数: 2783
# 2024-08-05, 收盘价: 53.20, RSI: 15.83
# 2024-08-06, 收盘价: 53.17, RSI: 17.65
# 2024-08-07, 收盘价: 52.86, RSI: 17.54
# 2024-08-08, 收盘价: 53.24, RSI: 19.45
# 2024-08-09, 收盘价: 53.00, RSI: 14.30
# 2024-08-12, 收盘价: 53.80, RSI: 27.23
# 2024-08-13, 收盘价: 54.86, RSI: 32.63
# 2024-08-14, 收盘价: 53.75, RSI: 31.75
# 2024-08-15, 收盘价: 54.10, RSI: 33.49
# 2024-08-16, 收盘价: 53.85, RSI: 33.44
# 2024-08-19, 收盘价: 55.31, RSI: 38.31
# 2024-08-20, 收盘价: 55.06, RSI: 32.04
# 2024-08-21, 收盘价: 54.83, RSI: 32.32
# 2024-08-22, 收盘价: 54.16, RSI: 38.43
# 2024-08-23, 收盘价: 54.00, RSI: 55.48
# 2024-08-26, 收盘价: 53.10, RSI: 49.57
# 2024-08-27, 收盘价: 52.13, RSI: 45.87
# 2024-08-28, 收盘价: 50.94, RSI: 38.07
# 2024-08-29, 收盘价: 51.35, RSI: 41.59
# 2024-08-30, 收盘价: 52.63, RSI: 44.31
# 2024-09-02, 收盘价: 49.95, RSI: 29.39
# 2024-09-03, 收盘价: 52.94, RSI: 47.06
# 2024-09-04, 收盘价: 52.09, RSI: 42.97
# 2024-09-05, 收盘价: 52.00, RSI: 43.45
# 2024-09-06, 收盘价: 51.74, RSI: 36.19
# 2024-09-09, 收盘价: 51.30, RSI: 35.67
# 2024-09-10, 收盘价: 51.50, RSI: 37.28
# 2024-09-11, 收盘价: 51.81, RSI: 40.77
# 2024-09-12, 收盘价: 51.21, RSI: 39.41
# 2024-09-13, 收盘价: 51.07, RSI: 41.82
# 2024-09-18, 收盘价: 49.30, RSI: 39.29
# 2024-09-19, 收盘价: 48.96, RSI: 41.99
# 2024-09-20, 收盘价: 49.59, RSI: 43.00
# 2024-09-23, 收盘价: 48.50, RSI: 33.33
# 2024-09-24, 收盘价: 50.03, RSI: 50.36
# 2024-09-25, 收盘价: 49.91, RSI: 31.90
# 2024-09-26, 收盘价: 52.28, RSI: 50.96
# 2024-09-27, 收盘价: 57.00, RSI: 67.22
# 2024-09-30, 收盘价: 66.88, RSI: 81.36
# 2024-09-30, 卖出信号 (RSI>70), 卖出全部: 2783 股
# 2024-10-08, 卖单执行, 价格: 80.26, 股数: -2783
# 2024-10-08, 收盘价: 80.26, RSI: 89.05
# 2024-10-09, 收盘价: 78.41, RSI: 84.74
# 2024-10-10, 收盘价: 70.89, RSI: 70.77
# 2024-10-11, 收盘价: 65.52, RSI: 64.11
# 2024-10-14, 收盘价: 66.93, RSI: 65.26
# 2024-10-15, 收盘价: 65.00, RSI: 65.06
# 2024-10-16, 收盘价: 62.30, RSI: 62.24
# 2024-10-17, 收盘价: 61.34, RSI: 60.71
# 2024-10-18, 收盘价: 68.95, RSI: 66.67
# 2024-10-21, 收盘价: 69.93, RSI: 66.37
# 2024-10-22, 收盘价: 70.94, RSI: 67.04
# 2024-10-23, 收盘价: 68.65, RSI: 63.29
# 2024-10-24, 收盘价: 69.00, RSI: 60.48
# 2024-10-25, 收盘价: 70.01, RSI: 53.24
# 2024-10-28, 收盘价: 69.09, RSI: 34.45
# 2024-10-29, 收盘价: 67.92, RSI: 35.11
# 2024-10-30, 收盘价: 69.08, RSI: 46.87
# 2024-10-31, 收盘价: 68.41, RSI: 55.98
# 2024-11-01, 收盘价: 64.55, RSI: 45.53
# 2024-11-04, 收盘价: 66.05, RSI: 52.00
# 2024-11-05, 收盘价: 69.00, RSI: 62.67
# 2024-11-06, 收盘价: 68.40, RSI: 63.54
# 2024-11-07, 收盘价: 70.38, RSI: 53.50
# 2024-11-08, 收盘价: 70.63, RSI: 51.77
# 2024-11-11, 收盘价: 78.11, RSI: 63.69
# 2024-11-12, 收盘价: 74.40, RSI: 60.41
# 2024-11-13, 收盘价: 75.39, RSI: 61.31
# 2024-11-14, 收盘价: 71.70, RSI: 52.73
# 2024-11-15, 收盘价: 68.73, RSI: 49.45
# 2024-11-18, 收盘价: 66.20, RSI: 47.50
# 2024-11-19, 收盘价: 68.16, RSI: 48.69
# 2024-11-20, 收盘价: 67.96, RSI: 49.35
# 2024-11-21, 收盘价: 67.60, RSI: 54.89
# 2024-11-22, 收盘价: 63.91, RSI: 46.79
# 2024-11-25, 收盘价: 63.63, RSI: 41.25
# 2024-11-26, 收盘价: 63.11, RSI: 41.36
# 2024-11-27, 收盘价: 66.69, RSI: 44.27
# 2024-11-28, 收盘价: 66.52, RSI: 43.60
# 2024-11-29, 收盘价: 67.38, RSI: 28.97
# 2024-11-29, 买入信号 (RSI<30), 全仓买入: 3348 股
# 2024-12-02, 订单取消/拒绝
# 2024-12-02, 收盘价: 69.13, RSI: 38.81
# 2024-12-03, 收盘价: 68.34, RSI: 34.90
# 2024-12-04, 收盘价: 67.83, RSI: 40.41
# 2024-12-05, 收盘价: 68.30, RSI: 48.78
# 2024-12-06, 收盘价: 70.18, RSI: 61.69
# 2024-12-09, 收盘价: 68.82, RSI: 52.01
# 2024-12-10, 收盘价: 68.39, RSI: 51.29
# 2024-12-11, 收盘价: 68.89, RSI: 53.84
# 2024-12-12, 收盘价: 68.70, RSI: 68.02
# 2024-12-13, 收盘价: 68.02, RSI: 66.03
# 2024-12-16, 收盘价: 68.95, RSI: 70.71
# 2024-12-17, 收盘价: 66.87, RSI: 50.71
# 2024-12-18, 收盘价: 68.80, RSI: 57.94
# 2024-12-19, 收盘价: 70.79, RSI: 61.01
# 2024-12-20, 收盘价: 72.52, RSI: 60.96
# 2024-12-23, 收盘价: 70.92, RSI: 57.92
# 2024-12-24, 收盘价: 72.18, RSI: 62.77
# 2024-12-25, 收盘价: 72.41, RSI: 62.24
# 2024-12-26, 收盘价: 79.99, RSI: 71.81
# 2024-12-27, 收盘价: 75.48, RSI: 62.99
# 2024-12-30, 收盘价: 71.19, RSI: 54.75
# 2024-12-31, 收盘价: 67.90, RSI: 48.47
# 2025-01-02, 收盘价: 65.93, RSI: 45.93
# 2025-01-03, 收盘价: 65.52, RSI: 46.30
# 2025-01-06, 收盘价: 63.91, RSI: 42.69
# 2025-01-07, 收盘价: 66.41, RSI: 49.34
# 2025-01-08, 收盘价: 66.82, RSI: 47.03
# 2025-01-09, 收盘价: 66.30, RSI: 42.96
# 2025-01-10, 收盘价: 64.20, RSI: 37.11
# 2025-01-13, 收盘价: 62.91, RSI: 37.47
# 2025-01-14, 收盘价: 66.43, RSI: 41.60
# 2025-01-15, 收盘价: 66.20, RSI: 40.93
# 2025-01-16, 收盘价: 66.01, RSI: 23.96
# 2025-01-16, 买入信号 (RSI<30), 全仓买入: 3418 股
# 2025-01-17, 买单执行, 价格: 65.59, 股数: 3418
# 2025-01-17, 收盘价: 66.67, RSI: 30.84
# 2025-01-20, 收盘价: 67.28, RSI: 39.88
# 2025-01-21, 收盘价: 70.08, RSI: 55.79
# 2025-01-22, 收盘价: 71.32, RSI: 64.90
# 2025-01-23, 收盘价: 70.10, RSI: 62.12
# 2025-01-24, 收盘价: 70.84, RSI: 69.22
# 2025-01-27, 收盘价: 68.04, RSI: 54.45
# 2025-02-05, 收盘价: 69.40, RSI: 56.69
# 2025-02-06, 收盘价: 71.33, RSI: 62.16
# 2025-02-07, 收盘价: 72.35, RSI: 70.78
# 2025-02-07, 卖出信号 (RSI>70), 卖出全部: 3418 股
# 2025-02-10, 卖单执行, 价格: 72.96, 股数: -3418
# 2025-02-10, 收盘价: 72.61, RSI: 76.10
# 2025-02-11, 收盘价: 71.78, RSI: 66.83
# 2025-02-12, 收盘价: 72.43, RSI: 69.10
# 2025-02-13, 收盘价: 70.00, RSI: 60.75
# 2025-02-14, 收盘价: 73.31, RSI: 65.66
# 2025-02-17, 收盘价: 74.79, RSI: 67.01
# 2025-02-18, 收盘价: 71.90, RSI: 54.11
# 2025-02-19, 收盘价: 73.34, RSI: 54.52
# 2025-02-20, 收盘价: 72.44, RSI: 55.31
# 2025-02-21, 收盘价: 77.01, RSI: 61.93
# 2025-02-24, 收盘价: 77.67, RSI: 70.29
# 2025-02-25, 收盘价: 79.84, RSI: 71.27
# 2025-02-26, 收盘价: 81.66, RSI: 71.14
# 2025-02-27, 收盘价: 83.68, RSI: 72.28
# 2025-02-27, 策略结束，期末资金: 250829.33
# 回测结束，期末资金: 250829.33

# %%
# %matplotlib inline
cerebro.plot(style='candlestick', iplot=False)
# Out:
# [[<Figure size 1400x700 with 5 Axes>]]

# %% [markdown]
# ## 布林带策略回测
#
# 实现并回测基于布林带的交易策略：

# %%
# ---------------------------
# 2. 定义布林带策略（全仓进出）
# ---------------------------
class BollingerBandsStrategy(bt.Strategy):
    """
    简单布林带均值回归:
    - 收盘价 < 下轨 => 全仓买入
    - 收盘价 > 上轨 => 全部卖出
    """
    params = (
        ('period', 20),
        ('devfactor', 2.0),
        ('printlog', True),
    )
    
    def log(self, txt, dt=None):
        if self.params.printlog:
            dt = dt or self.datas[0].datetime.date(0)
            print(f'{dt.isoformat()}, {txt}')
    
    def __init__(self):
        self.order = None
        self.boll = bt.indicators.BollingerBands(
            self.datas[0],
            period=self.params.period,
            devfactor=self.params.devfactor
        )
    
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'买单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
            else:
                self.log(f'卖单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单取消/拒绝')
        
        self.order = None
    
    def next(self):
        close_price = self.datas[0].close[0]
        top = self.boll.top[0]
        bot = self.boll.bot[0]
        
        self.log(f'收盘价: {close_price:.2f}, 上轨: {top:.2f}, 下轨: {bot:.2f}')
        
        if self.order:
            return
        
        if not self.position:
            # 跌破下轨 => 全仓买入
            if close_price < bot:
                cash = self.broker.getcash()
                size = int(cash // close_price)
                if size > 0:
                    self.log(f'买入信号 (收盘价<下轨), 全仓买入: {size} 股')
                    self.order = self.buy(size=size)
        else:
            # 突破上轨 => 全部卖出
            if close_price > top:
                self.log(f'卖出信号 (收盘价>上轨), 卖出全部: {self.position.size} 股')
                self.order = self.sell(size=self.position.size)
    
    def stop(self):
        self.log(f'策略结束，期末资金: {self.broker.getvalue():.2f}')

# ---------------------------
# 3. 定义自定义 Analyzer 用于记录资金曲线
# ---------------------------
class EquityCurveAnalyzer(bt.Analyzer):
    def start(self):
        self.equity = []
        self.dates = []
    
    def next(self):
        # 每个bar记录一次资金量
        self.equity.append(self.strategy.broker.getvalue())
        # 将 datetime 转换为日期对象
        dt = self.strategy.datas[0].datetime.date(0)
        self.dates.append(dt)
    
    def get_analysis(self):
        return {'dates': self.dates, 'equity': self.equity}

# ---------------------------
# 4. 创建并运行回测引擎
# ---------------------------
cerebro = bt.Cerebro()

# 设置初始资金
cerebro.broker.setcash(100000.0)

# 添加数据源
data_feed = bt.feeds.PandasData(dataname=stock_data)
cerebro.adddata(data_feed)

# 添加策略
cerebro.addstrategy(
    BollingerBandsStrategy,
    period=20,      # 布林带周期
    devfactor=2.0,  # 标准差倍数
    printlog=True
)

# 添加资金曲线 Analyzer
cerebro.addanalyzer(EquityCurveAnalyzer, _name='equitycurve')

# 打印初始资金
print(f'初始资金: {cerebro.broker.getvalue():.2f}')

# 运行回测
results = cerebro.run()
final_value = cerebro.broker.getvalue()
print(f'回测结束，期末资金: {final_value:.2f}')

# 获取资金曲线数据
equity_analyzer = results[0].analyzers.equitycurve.get_analysis()
dates = equity_analyzer['dates']
equity = equity_analyzer['equity']
# Out:
# 初始资金: 100000.00
# 2023-03-27, 收盘价: 67.84, 上轨: 68.03, 下轨: 49.58
# 2023-03-28, 收盘价: 63.77, 上轨: 68.57, 下轨: 49.70
# 2023-03-29, 收盘价: 67.49, 上轨: 69.71, 下轨: 49.62
# 2023-03-30, 收盘价: 69.23, 上轨: 71.05, 下轨: 49.59
# 2023-03-31, 收盘价: 68.75, 上轨: 72.12, 下轨: 49.69
# 2023-04-03, 收盘价: 70.74, 上轨: 73.42, 下轨: 49.78
# 2023-04-04, 收盘价: 73.19, 上轨: 74.98, 下轨: 49.99
# 2023-04-06, 收盘价: 74.40, 上轨: 76.50, 下轨: 50.39
# 2023-04-07, 收盘价: 75.46, 上轨: 78.01, 下轨: 50.81
# 2023-04-10, 收盘价: 70.91, 上轨: 78.39, 下轨: 52.00
# 2023-04-11, 收盘价: 71.80, 上轨: 78.64, 下轨: 53.43
# 2023-04-12, 收盘价: 75.57, 上轨: 79.30, 下轨: 54.79
# 2023-04-13, 收盘价: 70.86, 上轨: 78.95, 下轨: 56.69
# 2023-04-14, 收盘价: 73.37, 上轨: 78.58, 下轨: 58.83
# 2023-04-17, 收盘价: 71.21, 上轨: 77.81, 下轨: 60.98
# 2023-04-18, 收盘价: 69.90, 上轨: 77.47, 下轨: 62.12
# 2023-04-19, 收盘价: 71.31, 上轨: 76.94, 下轨: 63.64
# 2023-04-20, 收盘价: 75.62, 上轨: 76.94, 下轨: 64.97
# 2023-04-21, 收盘价: 71.27, 上轨: 76.96, 下轨: 65.25
# 2023-04-24, 收盘价: 68.44, 上轨: 76.98, 下轨: 65.13
# 2023-04-25, 收盘价: 67.99, 上轨: 76.97, 下轨: 65.16
# 2023-04-26, 收盘价: 63.49, 上轨: 77.03, 下轨: 65.07
# 2023-04-26, 买入信号 (收盘价<下轨), 全仓买入: 1574 股
# 2023-04-27, 买单执行, 价格: 62.87, 股数: 1574
# 2023-04-27, 收盘价: 62.35, 上轨: 77.73, 下轨: 63.86
# 2023-04-28, 收盘价: 60.23, 上轨: 78.66, 下轨: 62.03
# 2023-05-04, 收盘价: 58.70, 上轨: 79.57, 下轨: 60.11
# 2023-05-05, 收盘价: 58.29, 上轨: 80.16, 下轨: 58.28
# 2023-05-08, 收盘价: 58.76, 上轨: 80.17, 下轨: 56.82
# 2023-05-09, 收盘价: 57.23, 上轨: 79.96, 下轨: 55.32
# 2023-05-10, 收盘价: 55.87, 上轨: 79.44, 下轨: 53.88
# 2023-05-11, 收盘价: 55.18, 上轨: 79.42, 下轨: 52.32
# 2023-05-12, 收盘价: 53.14, 上轨: 79.28, 下轨: 50.60
# 2023-05-15, 收盘价: 53.55, 上轨: 78.12, 下轨: 49.55
# 2023-05-16, 收盘价: 53.22, 上轨: 77.57, 下轨: 48.34
# 2023-05-17, 收盘价: 54.54, 上轨: 76.25, 下轨: 47.78
# 2023-05-18, 收盘价: 57.36, 上轨: 75.03, 下轨: 47.61
# 2023-05-19, 收盘价: 58.31, 上轨: 73.92, 下轨: 47.56
# 2023-05-22, 收盘价: 58.76, 上轨: 72.39, 下轨: 47.84
# 2023-05-23, 收盘价: 57.06, 上轨: 69.24, 下轨: 49.14
# 2023-05-24, 收盘价: 57.36, 上轨: 66.89, 下轨: 50.09
# 2023-05-25, 收盘价: 59.44, 上轨: 65.12, 下轨: 50.96
# 2023-05-26, 收盘价: 60.47, 上轨: 63.23, 下轨: 52.10
# 2023-05-29, 收盘价: 62.23, 上轨: 62.92, 下轨: 52.28
# 2023-05-30, 收盘价: 63.03, 上轨: 63.09, 下轨: 52.19
# 2023-05-31, 收盘价: 63.10, 上轨: 63.63, 下轨: 51.93
# 2023-06-01, 收盘价: 61.42, 上轨: 63.97, 下轨: 51.86
# 2023-06-02, 收盘价: 60.02, 上轨: 64.12, 下轨: 51.88
# 2023-06-05, 收盘价: 59.62, 上轨: 64.20, 下轨: 51.89
# 2023-06-06, 收盘价: 58.44, 上轨: 64.25, 下轨: 51.96
# 2023-06-07, 收盘价: 59.25, 上轨: 64.35, 下轨: 52.20
# 2023-06-08, 收盘价: 56.48, 上轨: 64.31, 下轨: 52.37
# 2023-06-09, 收盘价: 57.55, 上轨: 64.05, 下轨: 53.07
# 2023-06-12, 收盘价: 57.56, 上轨: 63.78, 下轨: 53.75
# 2023-06-13, 收盘价: 62.16, 上轨: 63.74, 下轨: 54.68
# 2023-06-14, 收盘价: 62.22, 上轨: 63.76, 下轨: 55.42
# 2023-06-15, 收盘价: 60.81, 上轨: 63.83, 下轨: 55.69
# 2023-06-16, 收盘价: 60.16, 上轨: 63.87, 下轨: 55.84
# 2023-06-19, 收盘价: 61.43, 上轨: 64.03, 下轨: 55.95
# 2023-06-20, 收盘价: 59.74, 上轨: 63.94, 下轨: 56.31
# 2023-06-21, 收盘价: 57.44, 上轨: 63.93, 下轨: 56.32
# 2023-06-26, 收盘价: 55.38, 上轨: 64.25, 下轨: 55.60
# 2023-06-27, 收盘价: 55.47, 上轨: 64.40, 下轨: 54.95
# 2023-06-28, 收盘价: 54.77, 上轨: 64.33, 下轨: 54.27
# 2023-06-29, 收盘价: 55.06, 上轨: 63.95, 下轨: 53.85
# 2023-06-30, 收盘价: 56.79, 上轨: 63.33, 下轨: 53.85
# 2023-07-03, 收盘价: 59.21, 上轨: 63.05, 下轨: 53.90
# 2023-07-04, 收盘价: 62.01, 上轨: 63.36, 下轨: 53.79
# 2023-07-05, 收盘价: 61.99, 上轨: 63.69, 下轨: 53.70
# 2023-07-06, 收盘价: 63.02, 上轨: 64.26, 下轨: 53.59
# 2023-07-07, 收盘价: 63.00, 上轨: 64.74, 下轨: 53.49
# 2023-07-10, 收盘价: 60.33, 上轨: 64.82, 下轨: 53.79
# 2023-07-11, 收盘价: 61.29, 上轨: 65.01, 下轨: 53.98
# 2023-07-12, 收盘价: 58.43, 上轨: 65.00, 下轨: 54.07
# 2023-07-13, 收盘价: 60.80, 上轨: 64.84, 下轨: 54.10
# 2023-07-14, 收盘价: 61.31, 上轨: 64.71, 下轨: 54.13
# 2023-07-17, 收盘价: 60.43, 上轨: 64.67, 下轨: 54.13
# 2023-07-18, 收盘价: 59.51, 上轨: 64.63, 下轨: 54.11
# 2023-07-19, 收盘价: 58.54, 上轨: 64.41, 下轨: 54.04
# 2023-07-20, 收盘价: 57.11, 上轨: 64.35, 下轨: 53.84
# 2023-07-21, 收盘价: 56.97, 上轨: 64.36, 下轨: 53.78
# 2023-07-24, 收盘价: 57.95, 上轨: 64.25, 下轨: 54.15
# 2023-07-25, 收盘价: 58.63, 上轨: 64.12, 下轨: 54.60
# 2023-07-26, 收盘价: 58.04, 上轨: 63.84, 下轨: 55.20
# 2023-07-27, 收盘价: 57.46, 上轨: 63.58, 下轨: 55.70
# 2023-07-28, 收盘价: 58.37, 上轨: 63.48, 下轨: 55.95
# 2023-07-31, 收盘价: 57.28, 上轨: 63.53, 下轨: 55.71
# 2023-08-01, 收盘价: 57.00, 上轨: 63.28, 下轨: 55.47
# 2023-08-02, 收盘价: 56.03, 上轨: 63.05, 下轨: 55.10
# 2023-08-03, 收盘价: 56.32, 上轨: 62.44, 下轨: 55.03
# 2023-08-04, 收盘价: 57.41, 上轨: 61.64, 下轨: 55.28
# 2023-08-07, 收盘价: 57.15, 上轨: 61.41, 下轨: 55.19
# 2023-08-08, 收盘价: 56.86, 上轨: 60.93, 下轨: 55.23
# 2023-08-09, 收盘价: 56.01, 上轨: 60.94, 下轨: 54.98
# 2023-08-10, 收盘价: 56.24, 上轨: 60.50, 下轨: 54.96
# 2023-08-11, 收盘价: 54.24, 上轨: 60.03, 下轨: 54.72
# 2023-08-14, 收盘价: 52.77, 上轨: 59.97, 下轨: 54.02
# 2023-08-15, 收盘价: 50.86, 上轨: 60.35, 下轨: 52.77
# 2023-08-16, 收盘价: 48.47, 上轨: 61.12, 下轨: 50.99
# 2023-08-17, 收盘价: 48.53, 上轨: 61.63, 下轨: 49.63
# 2023-08-18, 收盘价: 48.34, 上轨: 61.95, 下轨: 48.45
# 2023-08-21, 收盘价: 47.52, 上轨: 62.08, 下轨: 47.28
# 2023-08-22, 收盘价: 48.88, 上轨: 61.76, 下轨: 46.61
# 2023-08-23, 收盘价: 48.15, 上轨: 61.49, 下轨: 45.90
# 2023-08-24, 收盘价: 49.41, 上轨: 61.10, 下轨: 45.49
# 2023-08-25, 收盘价: 47.74, 上轨: 60.56, 下轨: 44.96
# 2023-08-28, 收盘价: 48.47, 上轨: 60.04, 下轨: 44.60
# 2023-08-29, 收盘价: 50.51, 上轨: 59.44, 下轨: 44.55
# 2023-08-30, 收盘价: 51.17, 上轨: 58.97, 下轨: 44.53
# 2023-08-31, 收盘价: 50.94, 上轨: 58.40, 下轨: 44.57
# 2023-09-01, 收盘价: 51.06, 上轨: 57.52, 下轨: 44.81
# 2023-09-04, 收盘价: 51.32, 上轨: 56.61, 下轨: 45.14
# 2023-09-05, 收盘价: 51.32, 上轨: 55.64, 下轨: 45.55
# 2023-09-06, 收盘价: 53.48, 上轨: 55.08, 下轨: 45.87
# 2023-09-07, 收盘价: 51.20, 上轨: 54.01, 下轨: 46.43
# 2023-09-08, 收盘价: 51.35, 上轨: 53.44, 下轨: 46.71
# 2023-09-11, 收盘价: 51.51, 上轨: 53.22, 下轨: 46.81
# 2023-09-12, 收盘价: 50.81, 上轨: 53.21, 下轨: 46.81
# 2023-09-13, 收盘价: 50.59, 上轨: 53.25, 下轨: 46.98
# 2023-09-14, 收盘价: 50.09, 上轨: 53.24, 下轨: 47.15
# 2023-09-15, 收盘价: 51.47, 上轨: 53.32, 下轨: 47.38
# 2023-09-18, 收盘价: 50.69, 上轨: 53.18, 下轨: 47.83
# 2023-09-19, 收盘价: 50.54, 上轨: 53.16, 下轨: 48.02
# 2023-09-20, 收盘价: 50.46, 上轨: 53.02, 下轨: 48.39
# 2023-09-21, 收盘价: 49.41, 上轨: 53.02, 下轨: 48.39
# 2023-09-22, 收盘价: 50.97, 上轨: 52.74, 下轨: 49.00
# 2023-09-25, 收盘价: 49.71, 上轨: 52.54, 下轨: 49.32
# 2023-09-26, 收盘价: 48.96, 上轨: 52.68, 下轨: 49.03
# 2023-09-27, 收盘价: 49.26, 上轨: 52.70, 下轨: 48.82
# 2023-09-28, 收盘价: 49.41, 上轨: 52.71, 下轨: 48.66
# 2023-10-09, 收盘价: 50.32, 上轨: 52.67, 下轨: 48.62
# 2023-10-10, 收盘价: 53.06, 上轨: 53.00, 下轨: 48.46
# 2023-10-10, 卖出信号 (收盘价>上轨), 卖出全部: 1574 股
# 2023-10-11, 卖单执行, 价格: 52.87, 股数: -1574
# 2023-10-11, 收盘价: 53.43, 上轨: 53.38, 下轨: 48.29
# 2023-10-12, 收盘价: 53.07, 上轨: 53.28, 下轨: 48.35
# 2023-10-13, 收盘价: 52.69, 上轨: 53.49, 下轨: 48.29
# 2023-10-16, 收盘价: 51.30, 上轨: 53.48, 下轨: 48.29
# 2023-10-17, 收盘价: 52.55, 上轨: 53.62, 下轨: 48.26
# 2023-10-18, 收盘价: 50.46, 上轨: 53.61, 下轨: 48.23
# 2023-10-19, 收盘价: 50.11, 上轨: 53.61, 下轨: 48.19
# 2023-10-20, 收盘价: 47.72, 上轨: 53.81, 下轨: 47.75
# 2023-10-20, 买入信号 (收盘价<下轨), 全仓买入: 1765 股
# 2023-10-23, 买单执行, 价格: 47.10, 股数: 1765
# 2023-10-23, 收盘价: 47.13, 上轨: 53.96, 下轨: 47.16
# 2023-10-24, 收盘价: 47.91, 上轨: 54.01, 下轨: 46.84
# 2023-10-25, 收盘价: 48.46, 上轨: 54.01, 下轨: 46.63
# 2023-10-26, 收盘价: 48.35, 上轨: 54.00, 下轨: 46.43
# 2023-10-27, 收盘价: 49.50, 上轨: 54.00, 下轨: 46.44
# 2023-10-30, 收盘价: 53.29, 上轨: 54.34, 下轨: 46.33
# 2023-10-31, 收盘价: 54.71, 上轨: 55.00, 下轨: 46.17
# 2023-11-01, 收盘价: 54.95, 上轨: 55.62, 下轨: 46.15
# 2023-11-02, 收盘价: 55.08, 上轨: 56.19, 下轨: 46.16
# 2023-11-03, 收盘价: 56.37, 上轨: 56.95, 下轨: 46.10
# 2023-11-06, 收盘价: 56.97, 上轨: 57.74, 下轨: 45.97
# 2023-11-07, 收盘价: 57.48, 上轨: 58.44, 下轨: 45.72
# 2023-11-08, 收盘价: 57.21, 上轨: 58.99, 下轨: 45.54
# 2023-11-09, 收盘价: 56.55, 上轨: 59.41, 下轨: 45.47
# 2023-11-10, 收盘价: 56.27, 上轨: 59.79, 下轨: 45.45
# 2023-11-13, 收盘价: 58.03, 上轨: 60.47, 下轨: 45.44
# 2023-11-14, 收盘价: 58.78, 上轨: 61.19, 下轨: 45.34
# 2023-11-15, 收盘价: 59.64, 上轨: 62.01, 下轨: 45.45
# 2023-11-16, 收盘价: 59.26, 上轨: 62.62, 下轨: 45.75
# 2023-11-17, 收盘价: 59.56, 上轨: 62.98, 下轨: 46.58
# 2023-11-20, 收盘价: 57.64, 上轨: 62.79, 下轨: 47.81
# 2023-11-21, 收盘价: 58.56, 上轨: 62.63, 下轨: 49.04
# 2023-11-22, 收盘价: 58.13, 上轨: 62.27, 下轨: 50.37
# 2023-11-23, 收盘价: 58.12, 上轨: 61.54, 下轨: 52.07
# 2023-11-24, 收盘价: 57.32, 上轨: 60.54, 下轨: 53.85
# 2023-11-27, 收盘价: 57.55, 上轨: 60.23, 下轨: 54.59
# 2023-11-28, 收盘价: 57.43, 上轨: 60.08, 下轨: 55.01
# 2023-11-29, 收盘价: 57.68, 上轨: 59.92, 下轨: 55.44
# 2023-11-30, 收盘价: 58.64, 上轨: 59.79, 下轨: 55.93
# 2023-12-01, 收盘价: 59.74, 上轨: 60.00, 下轨: 56.06
# 2023-12-04, 收盘价: 59.22, 上轨: 60.11, 下轨: 56.17
# 2023-12-05, 收盘价: 57.49, 上轨: 60.11, 下轨: 56.17
# 2023-12-06, 收盘价: 57.72, 上轨: 60.10, 下轨: 56.23
# 2023-12-07, 收盘价: 56.57, 上轨: 60.10, 下轨: 56.24
# 2023-12-08, 收盘价: 57.17, 上轨: 60.00, 下轨: 56.42
# 2023-12-11, 收盘价: 59.64, 上轨: 60.19, 下轨: 56.40
# 2023-12-12, 收盘价: 60.18, 上轨: 60.42, 下轨: 56.31
# 2023-12-13, 收盘价: 59.80, 上轨: 60.45, 下轨: 56.29
# 2023-12-14, 收盘价: 61.24, 上轨: 60.87, 下轨: 56.07
# 2023-12-14, 卖出信号 (收盘价>上轨), 卖出全部: 1765 股
# 2023-12-15, 卖单执行, 价格: 61.72, 股数: -1765
# 2023-12-15, 收盘价: 60.03, 上轨: 60.94, 下轨: 56.04
# 2023-12-18, 收盘价: 59.16, 上轨: 61.00, 下轨: 56.13
# 2023-12-19, 收盘价: 59.45, 上轨: 61.08, 下轨: 56.15
# 2023-12-20, 收盘价: 58.66, 上轨: 61.09, 下轨: 56.19
# 2023-12-21, 收盘价: 59.76, 上轨: 61.21, 下轨: 56.23
# 2023-12-22, 收盘价: 58.51, 上轨: 61.19, 下轨: 56.37
# 2023-12-25, 收盘价: 56.57, 上轨: 61.27, 下轨: 56.19
# 2023-12-26, 收盘价: 55.11, 上轨: 61.56, 下轨: 55.67
# 2023-12-26, 买入信号 (收盘价<下轨), 全仓买入: 1997 股
# 2023-12-27, 订单取消/拒绝
# 2023-12-27, 收盘价: 57.31, 上轨: 61.57, 下轨: 55.62
# 2023-12-28, 收盘价: 57.00, 上轨: 61.57, 下轨: 55.46
# 2023-12-29, 收盘价: 58.42, 上轨: 61.45, 下轨: 55.45
# 2024-01-02, 收盘价: 57.29, 上轨: 61.38, 下轨: 55.33
# 2024-01-03, 收盘价: 56.23, 上轨: 61.43, 下轨: 55.15
# 2024-01-04, 收盘价: 55.57, 上轨: 61.54, 下轨: 54.83
# 2024-01-05, 收盘价: 55.34, 上轨: 61.63, 下轨: 54.61
# 2024-01-08, 收盘价: 54.29, 上轨: 61.85, 下轨: 54.11
# 2024-01-09, 收盘价: 56.22, 上轨: 61.67, 下轨: 53.94
# 2024-01-10, 收盘价: 54.62, 上轨: 61.47, 下轨: 53.59
# 2024-01-11, 收盘价: 56.65, 上轨: 61.19, 下轨: 53.56
# 2024-01-12, 收盘价: 55.27, 上轨: 60.55, 下轨: 53.60
# 2024-01-15, 收盘价: 54.09, 上轨: 60.21, 下轨: 53.34
# 2024-01-16, 收盘价: 53.37, 上轨: 60.04, 下轨: 52.93
# 2024-01-17, 收盘价: 52.29, 上轨: 59.86, 下轨: 52.40
# 2024-01-17, 买入信号 (收盘价<下轨), 全仓买入: 2105 股
# 2024-01-18, 买单执行, 价格: 51.70, 股数: 2105
# 2024-01-18, 收盘价: 53.74, 上轨: 59.56, 下轨: 52.21
# 2024-01-19, 收盘价: 54.81, 上轨: 58.87, 下轨: 52.40
# 2024-01-22, 收盘价: 53.78, 上轨: 58.45, 下轨: 52.35
# 2024-01-23, 收盘价: 53.85, 上轨: 58.33, 下轨: 52.19
# 2024-01-24, 收盘价: 51.67, 上轨: 58.54, 下轨: 51.64
# 2024-01-25, 收盘价: 51.37, 上轨: 58.44, 下轨: 51.15
# 2024-01-26, 收盘价: 49.51, 上轨: 58.58, 下轨: 50.25
# 2024-01-29, 收盘价: 48.35, 上轨: 58.44, 下轨: 49.39
# 2024-01-30, 收盘价: 47.17, 上轨: 58.54, 下轨: 48.28
# 2024-01-31, 收盘价: 44.94, 上轨: 58.99, 下轨: 46.70
# 2024-02-01, 收盘价: 46.50, 上轨: 58.99, 下轨: 45.79
# 2024-02-02, 收盘价: 44.54, 上轨: 59.13, 下轨: 44.57
# 2024-02-05, 收盘价: 44.33, 上轨: 59.23, 下轨: 43.47
# 2024-02-06, 收盘价: 47.44, 上轨: 58.64, 下轨: 43.19
# 2024-02-07, 收盘价: 48.42, 上轨: 58.20, 下轨: 43.01
# 2024-02-08, 收盘价: 49.61, 上轨: 57.33, 下轨: 43.17
# 2024-02-19, 收盘价: 51.65, 上轨: 56.81, 下轨: 43.34
# 2024-02-20, 收盘价: 51.35, 上轨: 56.45, 下轨: 43.42
# 2024-02-21, 收盘价: 50.50, 上轨: 56.12, 下轨: 43.47
# 2024-02-22, 收盘价: 51.05, 上轨: 55.98, 下轨: 43.48
# 2024-02-23, 收盘价: 51.31, 上轨: 55.63, 下轨: 43.58
# 2024-02-26, 收盘价: 51.90, 上轨: 55.10, 下轨: 43.82
# 2024-02-27, 收盘价: 53.10, 上轨: 54.97, 下轨: 43.88
# 2024-02-28, 收盘价: 50.48, 上轨: 54.45, 下轨: 44.07
# 2024-02-29, 收盘价: 51.90, 上轨: 54.49, 下轨: 44.06
# 2024-03-01, 收盘价: 52.86, 上轨: 54.72, 下轨: 43.97
# 2024-03-04, 收盘价: 54.53, 上轨: 55.43, 下轨: 43.77
# 2024-03-05, 收盘价: 54.16, 上轨: 56.01, 下轨: 43.76
# 2024-03-06, 收盘价: 52.38, 上轨: 56.23, 下轨: 44.07
# 2024-03-07, 收盘价: 51.00, 上轨: 56.05, 下轨: 44.85
# 2024-03-08, 收盘价: 52.06, 上轨: 56.06, 下轨: 45.40
# 2024-03-11, 收盘价: 51.77, 上轨: 55.61, 下轨: 46.57
# 2024-03-12, 收盘价: 52.67, 上轨: 54.84, 下轨: 48.17
# 2024-03-13, 收盘价: 52.62, 上轨: 54.56, 下轨: 48.97
# 2024-03-14, 收盘价: 51.50, 上轨: 54.26, 下轨: 49.58
# 2024-03-15, 收盘价: 52.10, 上轨: 54.13, 下轨: 49.96
# 2024-03-18, 收盘价: 52.40, 上轨: 54.17, 下轨: 50.00
# 2024-03-19, 收盘价: 48.52, 上轨: 54.53, 下轨: 49.35
# 2024-03-20, 收盘价: 47.36, 上轨: 55.01, 下轨: 48.56
# 2024-03-21, 收盘价: 49.38, 上轨: 55.08, 下轨: 48.32
# 2024-03-22, 收盘价: 49.01, 上轨: 55.16, 下轨: 48.01
# 2024-03-25, 收盘价: 47.67, 上轨: 55.33, 下轨: 47.42
# 2024-03-26, 收盘价: 46.77, 上轨: 55.40, 下轨: 46.71
# 2024-03-27, 收盘价: 45.04, 上轨: 55.86, 下轨: 45.71
# 2024-03-28, 收盘价: 46.19, 上轨: 55.92, 下轨: 45.08
# 2024-03-29, 收盘价: 45.69, 上轨: 55.83, 下轨: 44.45
# 2024-04-01, 收盘价: 45.54, 上轨: 55.34, 下轨: 44.04
# 2024-04-02, 收盘价: 45.49, 上轨: 54.80, 下轨: 43.71
# 2024-04-03, 收盘价: 45.01, 上轨: 54.54, 下轨: 43.24
# 2024-04-08, 收盘价: 43.65, 上轨: 54.52, 下轨: 42.53
# 2024-04-09, 收盘价: 44.00, 上轨: 54.19, 下轨: 42.04
# 2024-04-10, 收盘价: 42.90, 上轨: 53.91, 下轨: 41.44
# 2024-04-11, 收盘价: 46.88, 上轨: 53.19, 下轨: 41.58
# 2024-04-12, 收盘价: 47.66, 上轨: 52.42, 下轨: 41.85
# 2024-04-15, 收盘价: 48.77, 上轨: 51.96, 下轨: 42.04
# 2024-04-16, 收盘价: 47.50, 上轨: 51.16, 下轨: 42.38
# 2024-04-17, 收盘价: 49.21, 上轨: 50.35, 下轨: 42.87
# 2024-04-18, 收盘价: 47.37, 上轨: 50.21, 下轨: 42.90
# 2024-04-19, 收盘价: 45.64, 上轨: 50.13, 下轨: 42.81
# 2024-04-22, 收盘价: 46.46, 上轨: 49.73, 下轨: 42.91
# 2024-04-23, 收盘价: 45.90, 上轨: 49.35, 下轨: 42.99
# 2024-04-24, 收盘价: 46.82, 上轨: 49.24, 下轨: 43.00
# 2024-04-25, 收盘价: 48.02, 上轨: 49.40, 下轨: 42.97
# 2024-04-26, 收盘价: 50.48, 上轨: 50.13, 下轨: 42.79
# 2024-04-26, 卖出信号 (收盘价>上轨), 卖出全部: 2105 股
# 2024-04-29, 卖单执行, 价格: 50.41, 股数: -2105
# 2024-04-29, 收盘价: 51.03, 上轨: 50.87, 下轨: 42.53
# 2024-04-30, 收盘价: 50.62, 上轨: 51.42, 下轨: 42.47
# 2024-05-06, 收盘价: 50.76, 上轨: 51.93, 下轨: 42.49
# 2024-05-07, 收盘价: 50.25, 上轨: 52.27, 下轨: 42.62
# 2024-05-08, 收盘价: 50.58, 上轨: 52.60, 下轨: 42.85
# 2024-05-09, 收盘价: 50.77, 上轨: 52.75, 下轨: 43.41
# 2024-05-10, 收盘价: 50.58, 上轨: 52.80, 下轨: 44.02
# 2024-05-13, 收盘价: 50.57, 上轨: 52.47, 下轨: 45.12
# 2024-05-14, 收盘价: 50.23, 上轨: 52.58, 下轨: 45.34
# 2024-05-15, 收盘价: 49.39, 上轨: 52.62, 下轨: 45.47
# 2024-05-16, 收盘价: 48.93, 上轨: 52.63, 下轨: 45.48
# 2024-05-17, 收盘价: 49.18, 上轨: 52.64, 下轨: 45.64
# 2024-05-20, 收盘价: 49.84, 上轨: 52.68, 下轨: 45.66
# 2024-05-21, 收盘价: 49.61, 上轨: 52.70, 下轨: 45.86
# 2024-05-22, 收盘价: 50.97, 上轨: 52.60, 下轨: 46.50
# 2024-05-23, 收盘价: 50.51, 上轨: 52.47, 下轨: 47.03
# 2024-05-24, 收盘价: 49.46, 上轨: 52.01, 下轨: 47.84
# 2024-05-27, 收盘价: 52.32, 上轨: 52.01, 下轨: 48.40
# 2024-05-28, 收盘价: 52.26, 上轨: 52.14, 下轨: 48.69
# 2024-05-29, 收盘价: 52.49, 上轨: 52.46, 下轨: 48.57
# 2024-05-30, 收盘价: 52.55, 上轨: 52.72, 下轨: 48.46
# 2024-05-31, 收盘价: 52.69, 上轨: 53.01, 下轨: 48.38
# 2024-06-03, 收盘价: 54.06, 上轨: 53.60, 下轨: 48.12
# 2024-06-04, 收盘价: 53.32, 上轨: 53.94, 下轨: 48.09
# 2024-06-05, 收盘价: 51.77, 上轨: 54.01, 下轨: 48.14
# 2024-06-06, 收盘价: 51.21, 上轨: 54.03, 下轨: 48.16
# 2024-06-07, 收盘价: 50.60, 上轨: 54.03, 下轨: 48.17
# 2024-06-11, 收盘价: 51.11, 上轨: 54.05, 下轨: 48.20
# 2024-06-12, 收盘价: 51.60, 上轨: 54.09, 下轨: 48.29
# 2024-06-13, 收盘价: 52.70, 上轨: 54.20, 下轨: 48.51
# 2024-06-14, 收盘价: 53.00, 上轨: 54.26, 下轨: 48.86
# 2024-06-17, 收盘价: 53.83, 上轨: 54.43, 下轨: 49.16
# 2024-06-18, 收盘价: 54.38, 上轨: 54.73, 下轨: 49.31
# 2024-06-19, 收盘价: 55.17, 上轨: 55.10, 下轨: 49.50
# 2024-06-20, 收盘价: 56.08, 上轨: 55.73, 下轨: 49.38
# 2024-06-21, 收盘价: 56.81, 上轨: 56.40, 下轨: 49.34
# 2024-06-24, 收盘价: 57.13, 上轨: 56.89, 下轨: 49.62
# 2024-06-25, 收盘价: 54.96, 上轨: 57.06, 下轨: 49.71
# 2024-06-26, 收盘价: 56.30, 上轨: 57.44, 下轨: 49.74
# 2024-06-27, 收盘价: 56.05, 上轨: 57.72, 下轨: 49.81
# 2024-06-28, 收盘价: 57.16, 上轨: 58.17, 下轨: 49.82
# 2024-07-01, 收盘价: 56.48, 上轨: 58.45, 下轨: 49.92
# 2024-07-02, 收盘价: 55.55, 上轨: 58.57, 下轨: 49.95
# 2024-07-03, 收盘价: 56.06, 上轨: 58.75, 下轨: 50.05
# 2024-07-04, 收盘价: 56.06, 上轨: 58.85, 下轨: 50.38
# 2024-07-05, 收盘价: 56.06, 上轨: 58.83, 下轨: 50.88
# 2024-07-08, 收盘价: 59.53, 上轨: 59.27, 下轨: 51.33
# 2024-07-09, 收盘价: 59.78, 上轨: 59.67, 下轨: 51.80
# 2024-07-10, 收盘价: 60.60, 上轨: 60.19, 下轨: 52.18
# 2024-07-11, 收盘价: 62.22, 上轨: 61.13, 下轨: 52.19
# 2024-07-12, 收盘价: 63.66, 上轨: 62.29, 下轨: 52.10
# 2024-07-15, 收盘价: 64.30, 上轨: 63.43, 下轨: 52.00
# 2024-07-16, 收盘价: 65.03, 上轨: 64.58, 下轨: 51.92
# 2024-07-17, 收盘价: 63.21, 上轨: 65.16, 下轨: 52.14
# 2024-07-18, 收盘价: 63.00, 上轨: 65.66, 下轨: 52.34
# 2024-07-19, 收盘价: 63.01, 上轨: 66.11, 下轨: 52.51
# 2024-07-22, 收盘价: 63.93, 上轨: 66.66, 下轨: 52.64
# 2024-07-23, 收盘价: 58.80, 上轨: 66.53, 下轨: 53.15
# 2024-07-24, 收盘价: 58.98, 上轨: 66.48, 下轨: 53.47
# 2024-07-25, 收盘价: 58.20, 上轨: 66.39, 下轨: 53.77
# 2024-07-26, 收盘价: 58.23, 上轨: 66.36, 下轨: 53.91
# 2024-07-29, 收盘价: 58.00, 上轨: 66.29, 下轨: 54.13
# 2024-07-30, 收盘价: 58.47, 上轨: 66.11, 下轨: 54.60
# 2024-07-31, 收盘价: 59.60, 上轨: 65.96, 下轨: 55.11
# 2024-08-01, 收盘价: 59.26, 上轨: 65.76, 下轨: 55.63
# 2024-08-02, 收盘价: 56.60, 上轨: 65.69, 下轨: 55.75
# 2024-08-05, 收盘价: 53.20, 上轨: 66.35, 下轨: 54.46
# 2024-08-05, 买入信号 (收盘价<下轨), 全仓买入: 2018 股
# 2024-08-06, 订单取消/拒绝
# 2024-08-06, 收盘价: 53.17, 上轨: 66.80, 下轨: 53.34
# 2024-08-06, 买入信号 (收盘价<下轨), 全仓买入: 2019 股
# 2024-08-07, 买单执行, 价格: 53.08, 股数: 2019
# 2024-08-07, 收盘价: 52.86, 上轨: 67.11, 下轨: 52.27
# 2024-08-08, 收盘价: 53.24, 上轨: 67.07, 下轨: 51.41
# 2024-08-09, 收盘价: 53.00, 上轨: 66.71, 下轨: 50.70
# 2024-08-12, 收盘价: 53.80, 上轨: 66.02, 下轨: 50.34
# 2024-08-13, 收盘价: 54.86, 上轨: 64.97, 下轨: 50.37
# 2024-08-14, 收盘价: 53.75, 上轨: 64.22, 下轨: 50.18
# 2024-08-15, 收盘价: 54.10, 上轨: 63.36, 下轨: 50.14
# 2024-08-16, 收盘价: 53.85, 上轨: 62.35, 下轨: 50.24
# 2024-08-19, 收盘价: 55.31, 上轨: 60.81, 下轨: 50.92
# 2024-08-20, 收盘价: 55.06, 上轨: 60.45, 下轨: 50.91
# 2024-08-21, 收盘价: 54.83, 上轨: 60.00, 下轨: 50.94
# 2024-08-22, 收盘价: 54.16, 上轨: 59.65, 下轨: 50.88
# 2024-08-23, 收盘价: 54.00, 上轨: 59.25, 下轨: 50.86
# 2024-08-26, 收盘价: 53.10, 上轨: 58.86, 下轨: 50.76
# 2024-08-27, 收盘价: 52.13, 上轨: 58.34, 下轨: 50.65
# 2024-08-28, 收盘价: 50.94, 上轨: 57.43, 下轨: 50.69
# 2024-08-29, 收盘价: 51.35, 上轨: 56.27, 下轨: 51.06
# 2024-08-30, 收盘价: 52.63, 上轨: 55.73, 下轨: 51.21
# 2024-09-02, 收盘价: 49.95, 上轨: 56.04, 下轨: 50.57
# 2024-09-03, 收盘价: 52.94, 上轨: 56.03, 下轨: 50.56
# 2024-09-04, 收盘价: 52.09, 上轨: 56.03, 下轨: 50.47
# 2024-09-05, 收盘价: 52.00, 上轨: 56.03, 下轨: 50.36
# 2024-09-06, 收盘价: 51.74, 上轨: 56.03, 下轨: 50.23
# 2024-09-09, 收盘价: 51.30, 上轨: 55.99, 下轨: 50.01
# 2024-09-10, 收盘价: 51.50, 上轨: 55.77, 下轨: 49.91
# 2024-09-11, 收盘价: 51.81, 上轨: 55.67, 下轨: 49.81
# 2024-09-12, 收盘价: 51.21, 上轨: 55.53, 下轨: 49.66
# 2024-09-13, 收盘价: 51.07, 上轨: 55.40, 下轨: 49.51
# 2024-09-18, 收盘价: 49.30, 上轨: 55.10, 下轨: 49.21
# 2024-09-19, 收盘价: 48.96, 上轨: 54.80, 下轨: 48.91
# 2024-09-20, 收盘价: 49.59, 上轨: 54.35, 下轨: 48.82
# 2024-09-23, 收盘价: 48.50, 上轨: 54.12, 下轨: 48.49
# 2024-09-24, 收盘价: 50.03, 上轨: 53.68, 下轨: 48.53
# 2024-09-25, 收盘价: 49.91, 上轨: 53.40, 下轨: 48.50
# 2024-09-26, 收盘价: 52.28, 上轨: 53.42, 下轨: 48.49
# 2024-09-27, 收盘价: 57.00, 上轨: 54.87, 下轨: 47.65
# 2024-09-27, 卖出信号 (收盘价>上轨), 卖出全部: 2019 股
# 2024-09-30, 卖单执行, 价格: 59.46, 股数: -2019
# 2024-09-30, 收盘价: 66.88, 上轨: 59.74, 下轨: 44.33
# 2024-10-08, 收盘价: 80.26, 上轨: 67.94, 下轨: 38.89
# 2024-10-09, 收盘价: 78.41, 上轨: 72.88, 下轨: 36.80
# 2024-10-10, 收盘价: 70.89, 上轨: 75.05, 下轨: 36.42
# 2024-10-11, 收盘价: 65.52, 上轨: 76.10, 下轨: 36.72
# 2024-10-14, 收盘价: 66.93, 上轨: 77.25, 下轨: 37.06
# 2024-10-15, 收盘价: 65.00, 上轨: 78.03, 下轨: 37.61
# 2024-10-16, 收盘价: 62.30, 上轨: 78.44, 下轨: 38.30
# 2024-10-17, 收盘价: 61.34, 上轨: 78.71, 下轨: 39.01
# 2024-10-18, 收盘价: 68.95, 上轨: 79.76, 下轨: 39.68
# 2024-10-21, 收盘价: 69.93, 上轨: 80.77, 下轨: 40.54
# 2024-10-22, 收盘价: 70.94, 上轨: 81.73, 下轨: 41.56
# 2024-10-23, 收盘价: 68.65, 上轨: 82.08, 下轨: 43.15
# 2024-10-24, 收盘价: 69.00, 上轨: 82.21, 下轨: 45.02
# 2024-10-25, 收盘价: 70.01, 上轨: 82.26, 下轨: 47.02
# 2024-10-28, 收盘价: 69.09, 上轨: 81.73, 下轨: 49.60
# 2024-10-29, 收盘价: 67.92, 上轨: 80.95, 下轨: 52.17
# 2024-10-30, 收盘价: 69.08, 上轨: 79.73, 下轨: 55.30
# 2024-10-31, 收盘价: 68.41, 上轨: 78.34, 下轨: 58.31
# 2024-11-01, 收盘价: 64.55, 上轨: 77.47, 下轨: 59.93
# 2024-11-04, 收盘价: 66.05, 上轨: 77.47, 下轨: 59.85
# 2024-11-05, 收盘价: 69.00, 上轨: 75.14, 下轨: 61.06
# 2024-11-06, 收盘价: 68.40, 上轨: 72.82, 下轨: 62.38
# 2024-11-07, 收盘价: 70.38, 上轨: 72.74, 下轨: 62.41
# 2024-11-08, 收盘价: 70.63, 上轨: 73.06, 下轨: 62.59
# 2024-11-11, 收盘价: 78.11, 上轨: 75.25, 下轨: 61.52
# 2024-11-12, 收盘价: 74.40, 上轨: 76.01, 下轨: 61.70
# 2024-11-13, 收盘价: 75.39, 上轨: 76.54, 下轨: 62.48
# 2024-11-14, 收盘价: 71.70, 上轨: 76.03, 下轨: 64.03
# 2024-11-15, 收盘价: 68.73, 上轨: 76.02, 下轨: 64.01
# 2024-11-18, 收盘价: 66.20, 上轨: 76.06, 下轨: 63.60
# 2024-11-19, 收盘价: 68.16, 上轨: 75.94, 下轨: 63.44
# 2024-11-20, 收盘价: 67.96, 上轨: 75.94, 下轨: 63.38
# 2024-11-21, 收盘价: 67.60, 上轨: 75.93, 下轨: 63.25
# 2024-11-22, 收盘价: 63.91, 上轨: 76.08, 下轨: 62.48
# 2024-11-25, 收盘价: 63.63, 上轨: 76.24, 下轨: 61.78
# 2024-11-26, 收盘价: 63.11, 上轨: 76.44, 下轨: 61.10
# 2024-11-27, 收盘价: 66.69, 上轨: 76.37, 下轨: 60.93
# 2024-11-28, 收盘价: 66.52, 上轨: 76.33, 下轨: 60.78
# 2024-11-29, 收盘价: 67.38, 上轨: 76.28, 下轨: 61.12
# 2024-12-02, 收盘价: 69.13, 上轨: 76.33, 下轨: 61.37
# 2024-12-03, 收盘价: 68.34, 上轨: 76.30, 下轨: 61.33
# 2024-12-04, 收盘价: 67.83, 上轨: 76.29, 下轨: 61.29
# 2024-12-05, 收盘价: 68.30, 上轨: 76.15, 下轨: 61.22
# 2024-12-06, 收盘价: 70.18, 上轨: 76.11, 下轨: 61.22
# 2024-12-09, 收盘价: 68.82, 上轨: 74.26, 下轨: 62.14
# 2024-12-10, 收盘价: 68.39, 上轨: 73.25, 下轨: 62.55
# 2024-12-11, 收盘价: 68.89, 上轨: 71.72, 下轨: 63.43
# 2024-12-12, 收盘价: 68.70, 上轨: 71.16, 下轨: 63.69
# 2024-12-13, 收盘价: 68.02, 上轨: 71.08, 下轨: 63.69
# 2024-12-16, 收盘价: 68.95, 上轨: 71.24, 下轨: 63.81
# 2024-12-17, 收盘价: 66.87, 上轨: 71.17, 下轨: 63.75
# 2024-12-18, 收盘价: 68.80, 上轨: 71.26, 下轨: 63.75
# 2024-12-19, 收盘价: 70.79, 上轨: 71.68, 下轨: 63.64
# 2024-12-20, 收盘价: 72.52, 上轨: 72.25, 下轨: 63.93
# 2024-12-23, 收盘价: 70.92, 上轨: 72.25, 下轨: 64.66
# 2024-12-24, 收盘价: 72.18, 上轨: 72.17, 下轨: 65.65
# 2024-12-25, 收盘价: 72.41, 上轨: 72.63, 下轨: 65.77
# 2024-12-26, 收盘价: 79.99, 上轨: 75.51, 下轨: 64.23
# 2024-12-27, 收盘价: 75.48, 上轨: 76.29, 下轨: 64.26
# 2024-12-30, 收盘价: 71.19, 上轨: 76.38, 下轨: 64.37
# 2024-12-31, 收盘价: 67.90, 上轨: 76.39, 下轨: 64.32
# 2025-01-02, 收盘价: 65.93, 上轨: 76.51, 下轨: 64.01
# 2025-01-03, 收盘价: 65.52, 上轨: 76.66, 下轨: 63.59
# 2025-01-06, 收盘价: 63.91, 上轨: 76.88, 下轨: 62.74
# 2025-01-07, 收盘价: 66.41, 上轨: 76.91, 下轨: 62.47
# 2025-01-08, 收盘价: 66.82, 上轨: 76.92, 下轨: 62.30
# 2025-01-09, 收盘价: 66.30, 上轨: 76.92, 下轨: 62.04
# 2025-01-10, 收盘价: 64.20, 上轨: 77.04, 下轨: 61.47
# 2025-01-13, 收盘价: 62.91, 上轨: 77.25, 下轨: 60.75
# 2025-01-14, 收盘价: 66.43, 上轨: 77.20, 下轨: 60.54
# 2025-01-15, 收盘价: 66.20, 上轨: 77.21, 下轨: 60.47
# 2025-01-16, 收盘价: 66.01, 上轨: 77.16, 下轨: 60.24
# 2025-01-17, 收盘价: 66.67, 上轨: 76.94, 下轨: 60.05
# 2025-01-20, 收盘价: 67.28, 上轨: 76.49, 下轨: 59.98
# 2025-01-21, 收盘价: 70.08, 上轨: 76.40, 下轨: 59.99
# 2025-01-22, 收盘价: 71.32, 上轨: 76.28, 下轨: 60.02
# 2025-01-23, 收盘价: 70.10, 上轨: 75.98, 下轨: 60.08
# 2025-01-24, 收盘价: 70.84, 上轨: 73.52, 下轨: 61.63
# 2025-01-27, 收盘价: 68.04, 上轨: 71.93, 下轨: 62.48
# 2025-02-05, 收盘价: 69.40, 上轨: 71.59, 下轨: 62.63
# 2025-02-06, 收盘价: 71.33, 上轨: 72.12, 下轨: 62.45
# 2025-02-07, 收盘价: 72.35, 上轨: 72.87, 下轨: 62.34
# 2025-02-10, 收盘价: 72.61, 上轨: 73.56, 下轨: 62.36
# 2025-02-11, 收盘价: 71.78, 上轨: 73.87, 下轨: 62.84
# 2025-02-12, 收盘价: 72.43, 上轨: 74.36, 下轨: 62.95
# 2025-02-13, 收盘价: 70.00, 上轨: 74.49, 下轨: 63.14
# 2025-02-14, 收盘价: 73.31, 上轨: 75.04, 下轨: 63.29
# 2025-02-17, 收盘价: 74.79, 上轨: 75.59, 下轨: 63.80
# 2025-02-18, 收盘价: 71.90, 上轨: 75.21, 下轨: 65.07
# 2025-02-19, 收盘价: 73.34, 上轨: 75.44, 下轨: 65.54
# 2025-02-20, 收盘价: 72.44, 上轨: 75.41, 下轨: 66.20
# 2025-02-21, 收盘价: 77.01, 上轨: 76.16, 下轨: 66.54
# 2025-02-24, 收盘价: 77.67, 上轨: 76.95, 下轨: 66.85
# 2025-02-25, 收盘价: 79.84, 上轨: 78.21, 下轨: 66.85
# 2025-02-26, 收盘价: 81.66, 上轨: 79.92, 下轨: 66.30
# 2025-02-27, 收盘价: 83.68, 上轨: 81.89, 下轨: 65.57
# 2025-02-27, 策略结束，期末资金: 120239.20
# 回测结束，期末资金: 120239.20

# %%
# ---------------------------
# 5. 绘制回测结果及资金曲线
# ---------------------------
plt.rcParams['font.sans-serif'] = ['PingFang HK']
plt.rcParams['axes.unicode_minus'] = False


# 使用 Backtrader 内置绘图
# %matplotlib inline
cerebro.plot(style='candlestick', iplot=False)

# 绘制资金曲线
plt.figure(figsize=(10,6))
plt.plot(dates, equity, label='资金曲线')
plt.xlabel('日期')
plt.ylabel('组合价值')
plt.title('资金曲线变化')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()



# from IPython.display import display

# figs = cerebro.plot(style='candlestick')
# # cerebro.plot() 返回的是一个嵌套列表
# for fig in figs[0]:
#     display(fig)

# %% [markdown]
# ## MACD策略回测
#
# 实现并回测基于MACD的趋势跟踪策略：

# %%
# ---------------------------
# 2. 定义 MACD 策略 (全仓进出)
# ---------------------------
class MACDStrategy(bt.Strategy):
    """
    简单的 MACD 策略:
    - 当 MACD 线上穿信号线 => 全仓买入
    - 当 MACD 线下穿信号线 => 卖出全部
    """
    params = (
        ('fastperiod', 12),      # MACD 快线 EMA 周期
        ('slowperiod', 26),      # MACD 慢线 EMA 周期
        ('signalperiod', 9),     # 信号线 EMA 周期
        ('printlog', True),      # 是否打印日志
    )
    
    def log(self, txt, dt=None):
        """日志记录函数"""
        if self.params.printlog:
            dt = dt or self.datas[0].datetime.date(0)
            print(f'{dt.isoformat()}, {txt}')
    
    def __init__(self):
        self.order = None
        
        # 在 Backtrader 中，MACD 指标会有 macd, signal, hist 三条线
        self.macd_ind = bt.indicators.MACD(
            self.datas[0].close,
            period_me1=self.p.fastperiod,
            period_me2=self.p.slowperiod,
            period_signal=self.p.signalperiod
        )
        
        # 我们只需要判断 MACD 线 (macd) 与 信号线 (signal) 的交叉
        # >0 表示 macd 上穿 signal, <0 表示 macd 下穿 signal
        self.macd_crossover = bt.indicators.CrossOver(self.macd_ind.macd, self.macd_ind.signal)
    
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'买单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
            else:
                self.log(f'卖单执行, 价格: {order.executed.price:.2f}, 股数: {order.executed.size}')
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单取消/拒绝')
        
        self.order = None
    
    def next(self):
        # 如果有订单在执行，则不再继续下单
        if self.order:
            return
        
        # 若无持仓且 MACD 线上穿信号线 => 全仓买入
        if not self.position:
            if self.macd_crossover > 0:
                cash = self.broker.getcash()
                price = self.datas[0].close[0]
                size = int(cash // price)
                if size > 0:
                    self.log(f'买入信号 (MACD>Signal), 全仓买入: {size} 股, 当前收盘价: {price:.2f}')
                    self.order = self.buy(size=size)
        else:
            # 若已持仓且 MACD 线下穿信号线 => 卖出全部
            if self.macd_crossover < 0:
                self.log(f'卖出信号 (MACD<Signal), 卖出全部: {self.position.size} 股')
                self.order = self.sell(size=self.position.size)
    
    def stop(self):
        """策略结束时输出最终资金"""
        self.log(f'策略结束，期末资金: {self.broker.getvalue():.2f}')

# %%
# ---------------------------
# 3. 创建并运行回测引擎
# ---------------------------
cerebro = bt.Cerebro()
cerebro.broker.setcash(100000.0)

data_feed = bt.feeds.PandasData(dataname=stock_data)
cerebro.adddata(data_feed)

# 添加 MACD 策略
cerebro.addstrategy(MACDStrategy,
                    fastperiod=12,
                    slowperiod=26,
                    signalperiod=9,
                    printlog=True)

print(f'初始资金: {cerebro.broker.getvalue():.2f}')
cerebro.run()
final_value = cerebro.broker.getvalue()
print(f'回测结束，期末资金: {final_value:.2f}')

# 绘制回测结果
# %matplotlib inline
cerebro.plot(style='candlestick',iplot=False)
# Out:
# 初始资金: 100000.00
# 2023-05-23, 买入信号 (MACD>Signal), 全仓买入: 1752 股, 当前收盘价: 57.06
# 2023-05-24, 买单执行, 价格: 56.78, 股数: 1752
# 2023-06-09, 卖出信号 (MACD<Signal), 卖出全部: 1752 股
# 2023-06-12, 卖单执行, 价格: 57.65, 股数: -1752
# 2023-06-13, 买入信号 (MACD>Signal), 全仓买入: 1633 股, 当前收盘价: 62.16
# 2023-06-14, 买单执行, 价格: 61.50, 股数: 1633
# 2023-06-26, 卖出信号 (MACD<Signal), 卖出全部: 1633 股
# 2023-06-27, 卖单执行, 价格: 55.93, 股数: -1633
# 2023-07-04, 买入信号 (MACD>Signal), 全仓买入: 1490 股, 当前收盘价: 62.01
# 2023-07-05, 买单执行, 价格: 61.66, 股数: 1490
# 2023-07-19, 卖出信号 (MACD<Signal), 卖出全部: 1490 股
# 2023-07-20, 卖单执行, 价格: 58.68, 股数: -1490
# 2023-08-29, 买入信号 (MACD>Signal), 全仓买入: 1741 股, 当前收盘价: 50.51
# 2023-08-30, 订单取消/拒绝
# 2023-10-09, 买入信号 (MACD>Signal), 全仓买入: 1748 股, 当前收盘价: 50.32
# 2023-10-10, 订单取消/拒绝
# 2023-10-30, 买入信号 (MACD>Signal), 全仓买入: 1650 股, 当前收盘价: 53.29
# 2023-10-31, 订单取消/拒绝
# 2023-12-14, 买入信号 (MACD>Signal), 全仓买入: 1436 股, 当前收盘价: 61.24
# 2023-12-15, 订单取消/拒绝
# 2024-02-08, 买入信号 (MACD>Signal), 全仓买入: 1773 股, 当前收盘价: 49.61
# 2024-02-19, 订单取消/拒绝
# 2024-04-12, 买入信号 (MACD>Signal), 全仓买入: 1845 股, 当前收盘价: 47.66
# 2024-04-15, 订单取消/拒绝
# 2024-05-22, 买入信号 (MACD>Signal), 全仓买入: 1725 股, 当前收盘价: 50.97
# 2024-05-23, 订单取消/拒绝
# 2024-05-27, 买入信号 (MACD>Signal), 全仓买入: 1681 股, 当前收盘价: 52.32
# 2024-05-28, 买单执行, 价格: 52.00, 股数: 1681
# 2024-06-06, 卖出信号 (MACD<Signal), 卖出全部: 1681 股
# 2024-06-07, 卖单执行, 价格: 51.55, 股数: -1681
# 2024-06-17, 买入信号 (MACD>Signal), 全仓买入: 1620 股, 当前收盘价: 53.83
# 2024-06-18, 订单取消/拒绝
# 2024-07-08, 买入信号 (MACD>Signal), 全仓买入: 1465 股, 当前收盘价: 59.53
# 2024-07-09, 买单执行, 价格: 59.40, 股数: 1465
# 2024-07-23, 卖出信号 (MACD<Signal), 卖出全部: 1465 股
# 2024-07-24, 卖单执行, 价格: 59.65, 股数: -1465
# 2024-08-21, 买入信号 (MACD>Signal), 全仓买入: 1597 股, 当前收盘价: 54.83
# 2024-08-22, 订单取消/拒绝
# 2024-09-05, 买入信号 (MACD>Signal), 全仓买入: 1684 股, 当前收盘价: 52.00
# 2024-09-06, 订单取消/拒绝
# 2024-09-26, 买入信号 (MACD>Signal), 全仓买入: 1675 股, 当前收盘价: 52.28
# 2024-09-27, 订单取消/拒绝
# 2024-11-11, 买入信号 (MACD>Signal), 全仓买入: 1121 股, 当前收盘价: 78.11
# 2024-11-12, 订单取消/拒绝
# 2024-12-06, 买入信号 (MACD>Signal), 全仓买入: 1248 股, 当前收盘价: 70.18
# 2024-12-09, 买单执行, 价格: 70.00, 股数: 1248
# 2024-12-17, 卖出信号 (MACD<Signal), 卖出全部: 1248 股
# 2024-12-18, 卖单执行, 价格: 67.21, 股数: -1248
# 2024-12-19, 买入信号 (MACD>Signal), 全仓买入: 1188 股, 当前收盘价: 70.79
# 2024-12-20, 买单执行, 价格: 70.00, 股数: 1188
# 2025-01-02, 卖出信号 (MACD<Signal), 卖出全部: 1188 股
# 2025-01-03, 卖单执行, 价格: 66.23, 股数: -1188
# 2025-01-21, 买入信号 (MACD>Signal), 全仓买入: 1136 股, 当前收盘价: 70.08
# 2025-01-22, 买单执行, 价格: 69.95, 股数: 1136
# 2025-02-27, 策略结束，期末资金: 95230.57
# 回测结束，期末资金: 95230.57
# [[<Figure size 1400x700 with 6 Axes>]]

# %% [markdown]
# ## Buy & Hold 策略回测
#
# 实现并回测Buy & Hold策略：

# %%
class BuyHoldStrategy(bt.Strategy):
    params = (
        ('printlog', True),
    )
    
    def log(self, txt, dt=None):
        """日志记录函数"""
        if self.params.printlog:
            dt = dt or self.datas[0].datetime.date(0)
            print(f'{dt.isoformat()}, {txt}')
    
    def __init__(self):
        # 用于跟踪订单状态
        self.order = None

    def next(self):
        if not self.position:  # 没有持仓时
            # 当前现金
            cash = self.broker.getcash()
            # 当前收盘价
            price = self.datas[0].close[0]
            # 计算可买股数（整股）
            size = int(cash // price)  # 使用整除保证是整数
            
            if size > 0:
                self.order = self.buy(size=size)  # 买入 size 股

    
    def notify_order(self, order):
        """订单通知函数"""
        if order.status in [order.Submitted, order.Accepted]:
            return  # 等待执行
        
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'买入订单执行，价格: {order.executed.price:.2f}')
            elif order.issell():
                self.log(f'卖出订单执行，价格: {order.executed.price:.2f}')
        
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单被取消/拒绝')
        
        # 重置订单引用
        self.order = None
    
    def stop(self):
        """策略结束时记录期末资金"""
        self.log(f'策略结束，期末资金: {self.broker.getvalue():.2f}')

# %%
# ---------------------------
# 3. 创建并运行回测引擎
# ---------------------------

cerebro = bt.Cerebro()
cerebro.broker.setcash(100000.0)  # 设置初始资金

# 添加数据
data_feed = bt.feeds.PandasData(dataname=stock_data)
cerebro.adddata(data_feed)

# 添加 Buy & Hold 策略
cerebro.addstrategy(BuyHoldStrategy, printlog=True)

print(f'初始资金: {cerebro.broker.getvalue():.2f}')
results = cerebro.run()
final_value = cerebro.broker.getvalue()
print(f'期末资金: {final_value:.2f}')

# ---------------------------
# 4. 绘制回测结果
# ---------------------------
# %matplotlib inline
cerebro.plot(style='candlestick', iplot=False)
# Out:
# 初始资金: 100000.00
# 2023-03-01, 买入订单执行，价格: 56.75
# 2025-02-27, 策略结束，期末资金: 147130.20
# 期末资金: 147130.20
# [[<Figure size 1400x700 with 4 Axes>]]

# %% [markdown]
# ## 策略性能比较
#
# 比较不同策略的性能指标：

# %%
# ---------------------------
# 2. 定义通用回测函数，运行策略并提取绩效指标
# ---------------------------
def run_strategy_and_get_metrics(strategy_class, data_feed, cash=100000.0, commission=0.0, **strategy_params):
    cerebro = bt.Cerebro()
    cerebro.broker.setcash(cash)
    cerebro.broker.setcommission(commission=commission)
    cerebro.adddata(data_feed)
    cerebro.addstrategy(strategy_class, **strategy_params)
    
    # 添加常见的分析器
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
    cerebro.addanalyzer(bt.analyzers.Returns, _name='returns', tann=252)
    
    results = cerebro.run()
    strat = results[0]
    
    sharpe = strat.analyzers.sharpe.get_analysis().get('sharperatio', None)
    drawdown = strat.analyzers.drawdown.get_analysis().get('max', {}).get('drawdown', None)
    annual_return = strat.analyzers.returns.get_analysis().get('rnorm100', None)
    
    metrics = {
        'Sharpe Ratio': sharpe,
        'Max Drawdown (%)': drawdown,
        'Annual Return (%)': annual_return
    }
    return metrics

# ---------------------------
# 4. 定义要比较的策略及其参数
# ---------------------------
strategy_configs = [
    ('MA Cross', MovingAverageCrossStrategy, dict(fast_period=20, slow_period=50)),
    ('RSI', RSIStrategy, dict(rsi_period=14, rsi_low=30, rsi_high=70)),
    ('Bollinger Bands', BollingerBandsStrategy, dict(period=20, devfactor=2.0)),
    ('MACD', MACDStrategy, dict(fastperiod=12, slowperiod=26, signalperiod=9)),
]

results_dict = {}
for name, strat_class, params in strategy_configs:
    metrics = run_strategy_and_get_metrics(strat_class, data_feed, cash=100000.0, commission=0.0, **params)
    results_dict[name] = metrics

performance_df = pd.DataFrame.from_dict(results_dict, orient='index')
performance_df = performance_df.sort_values('Annual Return (%)', ascending=False)

print("策略绩效对比：")
print(performance_df)
# Out:
# 2023-07-10, 买入信号 (fast_ma>slow_ma), 全仓买入: 1657 股
# 2023-07-11, 买单执行, 价格: 60.11, 股数: 1657
# 2023-08-02, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1657 股
# 2023-08-03, 卖单执行, 价格: 55.98, 股数: -1657
# 2023-10-30, 买入信号 (fast_ma>slow_ma), 全仓买入: 1747 股
# 2023-10-31, 订单取消/拒绝
# 2024-03-18, 买入信号 (fast_ma>slow_ma), 全仓买入: 1777 股
# 2024-03-19, 买单执行, 价格: 52.31, 股数: 1777
# 2024-03-26, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1777 股
# 2024-03-27, 卖单执行, 价格: 46.01, 股数: -1777
# 2024-05-15, 买入信号 (fast_ma>slow_ma), 全仓买入: 1659 股
# 2024-05-16, 订单取消/拒绝
# 2024-10-10, 买入信号 (fast_ma>slow_ma), 全仓买入: 1156 股
# 2024-10-11, 买单执行, 价格: 68.50, 股数: 1156
# 2024-12-11, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1156 股
# 2024-12-12, 卖单执行, 价格: 68.89, 股数: -1156
# 2024-12-24, 买入信号 (fast_ma>slow_ma), 全仓买入: 1141 股
# 2024-12-25, 买单执行, 价格: 72.00, 股数: 1141
# 2025-01-16, 卖出信号 (fast_ma<slow_ma), 卖出全部: 1141 股
# 2025-01-17, 卖单执行, 价格: 65.59, 股数: -1141
# 2025-02-14, 买入信号 (fast_ma>slow_ma), 全仓买入: 1024 股
# 2025-02-17, 订单取消/拒绝
# 2025-02-27, 策略结束，期末资金: 75103.39
# 2023-03-20, 收盘价: 61.90, RSI: 69.25
# 2023-03-21, 收盘价: 61.38, RSI: 67.95
# 2023-03-22, 收盘价: 62.44, RSI: 73.73
# 2023-03-23, 收盘价: 68.24, RSI: 81.06
# 2023-03-24, 收盘价: 69.40, RSI: 83.13
# 2023-03-27, 收盘价: 67.84, RSI: 81.65
# 2023-03-28, 收盘价: 63.77, RSI: 68.29
# 2023-03-29, 收盘价: 67.49, RSI: 71.80
# 2023-03-30, 收盘价: 69.23, RSI: 75.88
# 2023-03-31, 收盘价: 68.75, RSI: 75.55
# 2023-04-03, 收盘价: 70.74, RSI: 76.85
# 2023-04-04, 收盘价: 73.19, RSI: 78.61
# 2023-04-06, 收盘价: 74.40, RSI: 79.27
# 2023-04-07, 收盘价: 75.46, RSI: 78.92
# 2023-04-10, 收盘价: 70.91, RSI: 64.36
# 2023-04-11, 收盘价: 71.80, RSI: 66.43
# 2023-04-12, 收盘价: 75.57, RSI: 69.07
# 2023-04-13, 收盘价: 70.86, RSI: 53.93
# 2023-04-14, 收盘价: 73.37, RSI: 55.73
# 2023-04-17, 收盘价: 71.21, RSI: 54.78
# 2023-04-18, 收盘价: 69.90, RSI: 59.42
# 2023-04-19, 收盘价: 71.31, RSI: 56.32
# 2023-04-20, 收盘价: 75.62, RSI: 59.74
# 2023-04-21, 收盘价: 71.27, RSI: 53.43
# 2023-04-24, 收盘价: 68.44, RSI: 46.93
# 2023-04-25, 收盘价: 67.99, RSI: 42.69
# 2023-04-26, 收盘价: 63.49, RSI: 35.94
# 2023-04-27, 收盘价: 62.35, RSI: 33.14
# 2023-04-28, 收盘价: 60.23, RSI: 35.35
# 2023-05-04, 收盘价: 58.70, RSI: 32.34
# 2023-05-05, 收盘价: 58.29, RSI: 24.39
# 2023-05-05, 买入信号 (RSI<30), 全仓买入: 1715 股
# 2023-05-08, 订单取消/拒绝
# 2023-05-08, 收盘价: 58.76, RSI: 29.48
# 2023-05-08, 买入信号 (RSI<30), 全仓买入: 1701 股
# 2023-05-09, 订单取消/拒绝
# 2023-05-09, 收盘价: 57.23, RSI: 21.69
# 2023-05-09, 买入信号 (RSI<30), 全仓买入: 1747 股
# 2023-05-10, 订单取消/拒绝
# 2023-05-10, 收盘价: 55.87, RSI: 22.31
# 2023-05-10, 买入信号 (RSI<30), 全仓买入: 1789 股
# 2023-05-11, 订单取消/拒绝
# 2023-05-11, 收盘价: 55.18, RSI: 22.82
# 2023-05-11, 买入信号 (RSI<30), 全仓买入: 1812 股
# 2023-05-12, 订单取消/拒绝
# 2023-05-12, 收盘价: 53.14, RSI: 17.23
# 2023-05-12, 买入信号 (RSI<30), 全仓买入: 1881 股
# 2023-05-15, 订单取消/拒绝
# 2023-05-15, 收盘价: 53.55, RSI: 3.69
# 2023-05-15, 买入信号 (RSI<30), 全仓买入: 1867 股
# 2023-05-16, 订单取消/拒绝
# 2023-05-16, 收盘价: 53.22, RSI: 4.44
# 2023-05-16, 买入信号 (RSI<30), 全仓买入: 1879 股
# 2023-05-17, 订单取消/拒绝
# 2023-05-17, 收盘价: 54.54, RSI: 12.05
# 2023-05-17, 买入信号 (RSI<30), 全仓买入: 1833 股
# 2023-05-18, 买单执行, 价格: 54.39, 股数: 1833
# 2023-05-18, 收盘价: 57.36, RSI: 24.29
# 2023-05-19, 收盘价: 58.31, RSI: 34.87
# 2023-05-22, 收盘价: 58.76, RSI: 39.07
# 2023-05-23, 收盘价: 57.06, RSI: 40.11
# 2023-05-24, 收盘价: 57.36, RSI: 45.48
# 2023-05-25, 收盘价: 59.44, RSI: 53.49
# 2023-05-26, 收盘价: 60.47, RSI: 55.03
# 2023-05-29, 收盘价: 62.23, RSI: 64.49
# 2023-05-30, 收盘价: 63.03, RSI: 71.47
# 2023-05-30, 卖出信号 (RSI>70), 卖出全部: 1833 股
# 2023-05-31, 卖单执行, 价格: 63.10, 股数: -1833
# 2023-05-31, 收盘价: 63.10, RSI: 74.68
# 2023-06-01, 收盘价: 61.42, RSI: 76.37
# 2023-06-02, 收盘价: 60.02, RSI: 69.40
# 2023-06-05, 收盘价: 59.62, RSI: 69.11
# 2023-06-06, 收盘价: 58.44, RSI: 61.74
# 2023-06-07, 收盘价: 59.25, RSI: 56.47
# 2023-06-08, 收盘价: 56.48, RSI: 44.42
# 2023-06-09, 收盘价: 57.55, RSI: 46.46
# 2023-06-12, 收盘价: 57.56, RSI: 51.61
# 2023-06-13, 收盘价: 62.16, RSI: 62.20
# 2023-06-14, 收盘价: 62.22, RSI: 57.88
# 2023-06-15, 收盘价: 60.81, RSI: 50.96
# 2023-06-16, 收盘价: 60.16, RSI: 43.89
# 2023-06-19, 收盘价: 61.43, RSI: 45.39
# 2023-06-20, 收盘价: 59.74, RSI: 41.15
# 2023-06-21, 收盘价: 57.44, RSI: 39.86
# 2023-06-26, 收盘价: 55.38, RSI: 38.56
# 2023-06-27, 收盘价: 55.47, RSI: 39.61
# 2023-06-28, 收盘价: 54.77, RSI: 40.58
# 2023-06-29, 收盘价: 55.06, RSI: 38.94
# 2023-06-30, 收盘价: 56.79, RSI: 50.86
# 2023-07-03, 收盘价: 59.21, RSI: 54.31
# 2023-07-04, 收盘价: 62.01, RSI: 60.09
# 2023-07-05, 收盘价: 61.99, RSI: 49.52
# 2023-07-06, 收盘价: 63.02, RSI: 52.17
# 2023-07-07, 收盘价: 63.00, RSI: 56.41
# 2023-07-10, 收盘价: 60.33, RSI: 50.44
# 2023-07-11, 收盘价: 61.29, RSI: 49.63
# 2023-07-12, 收盘价: 58.43, RSI: 46.73
# 2023-07-13, 收盘价: 60.80, RSI: 58.40
# 2023-07-14, 收盘价: 61.31, RSI: 66.04
# 2023-07-17, 收盘价: 60.43, RSI: 62.87
# 2023-07-18, 收盘价: 59.51, RSI: 62.16
# 2023-07-19, 收盘价: 58.54, RSI: 58.64
# 2023-07-20, 收盘价: 57.11, RSI: 50.82
# 2023-07-21, 收盘价: 56.97, RSI: 43.61
# 2023-07-24, 收盘价: 57.95, RSI: 37.10
# 2023-07-25, 收盘价: 58.63, RSI: 39.76
# 2023-07-26, 收盘价: 58.04, RSI: 34.43
# 2023-07-27, 收盘价: 57.46, RSI: 33.25
# 2023-07-28, 收盘价: 58.37, RSI: 43.37
# 2023-07-31, 收盘价: 57.28, RSI: 36.56
# 2023-08-01, 收盘价: 57.00, RSI: 44.19
# 2023-08-02, 收盘价: 56.03, RSI: 28.14
# 2023-08-02, 买入信号 (RSI<30), 全仓买入: 2069 股
# 2023-08-03, 买单执行, 价格: 55.98, 股数: 2069
# 2023-08-03, 收盘价: 56.32, RSI: 26.75
# 2023-08-04, 收盘价: 57.41, RSI: 36.20
# 2023-08-07, 收盘价: 57.15, RSI: 38.54
# 2023-08-08, 收盘价: 56.86, RSI: 41.24
# 2023-08-09, 收盘价: 56.01, RSI: 43.86
# 2023-08-10, 收盘价: 56.24, RSI: 46.04
# 2023-08-11, 收盘价: 54.24, RSI: 31.71
# 2023-08-14, 收盘价: 52.77, RSI: 23.19
# 2023-08-15, 收盘价: 50.86, RSI: 20.66
# 2023-08-16, 收盘价: 48.47, RSI: 18.01
# 2023-08-17, 收盘价: 48.53, RSI: 12.73
# 2023-08-18, 收盘价: 48.34, RSI: 13.67
# 2023-08-21, 收盘价: 47.52, RSI: 13.10
# 2023-08-22, 收盘价: 48.88, RSI: 22.95
# 2023-08-23, 收盘价: 48.15, RSI: 20.06
# 2023-08-24, 收盘价: 49.41, RSI: 21.07
# 2023-08-25, 收盘价: 47.74, RSI: 19.11
# 2023-08-28, 收盘价: 48.47, RSI: 23.22
# 2023-08-29, 收盘价: 50.51, RSI: 33.68
# 2023-08-30, 收盘价: 51.17, RSI: 35.33
# 2023-08-31, 收盘价: 50.94, RSI: 39.38
# 2023-09-01, 收盘价: 51.06, RSI: 43.96
# 2023-09-04, 收盘价: 51.32, RSI: 51.87
# 2023-09-05, 收盘价: 51.32, RSI: 64.11
# 2023-09-06, 收盘价: 53.48, RSI: 70.28
# 2023-09-06, 卖出信号 (RSI>70), 卖出全部: 2069 股
# 2023-09-07, 卖单执行, 价格: 53.17, 股数: -2069
# 2023-09-07, 收盘价: 51.20, RSI: 60.01
# 2023-09-08, 收盘价: 51.35, RSI: 64.04
# 2023-09-11, 收盘价: 51.51, RSI: 60.59
# 2023-09-12, 收盘价: 50.81, RSI: 60.69
# 2023-09-13, 收盘价: 50.59, RSI: 55.16
# 2023-09-14, 收盘价: 50.09, RSI: 61.50
# 2023-09-15, 收盘价: 51.47, RSI: 63.83
# 2023-09-18, 收盘价: 50.69, RSI: 50.93
# 2023-09-19, 收盘价: 50.54, RSI: 46.50
# 2023-09-20, 收盘价: 50.46, RSI: 47.27
# 2023-09-21, 收盘价: 49.41, RSI: 41.63
# 2023-09-22, 收盘价: 50.97, RSI: 48.44
# 2023-09-25, 收盘价: 49.71, RSI: 43.52
# 2023-09-26, 收盘价: 48.96, RSI: 29.49
# 2023-09-26, 买入信号 (RSI<30), 全仓买入: 2249 股
# 2023-09-27, 买单执行, 价格: 48.96, 股数: 2249
# 2023-09-27, 收盘价: 49.26, RSI: 39.30
# 2023-09-28, 收盘价: 49.41, RSI: 39.30
# 2023-10-09, 收盘价: 50.32, RSI: 43.91
# 2023-10-10, 收盘价: 53.06, RSI: 59.53
# 2023-10-11, 收盘价: 53.43, RSI: 61.86
# 2023-10-12, 收盘价: 53.07, RSI: 62.58
# 2023-10-13, 收盘价: 52.69, RSI: 55.64
# 2023-10-16, 收盘价: 51.30, RSI: 52.69
# 2023-10-17, 收盘价: 52.55, RSI: 58.00
# 2023-10-18, 收盘价: 50.46, RSI: 50.00
# 2023-10-19, 收盘价: 50.11, RSI: 52.51
# 2023-10-20, 收盘价: 47.72, RSI: 38.93
# 2023-10-23, 收盘价: 47.13, RSI: 40.78
# 2023-10-24, 收盘价: 47.91, RSI: 46.28
# 2023-10-25, 收盘价: 48.46, RSI: 47.18
# 2023-10-26, 收盘价: 48.35, RSI: 46.27
# 2023-10-27, 收盘价: 49.50, RSI: 47.19
# 2023-10-30, 收盘价: 53.29, RSI: 50.74
# 2023-10-31, 收盘价: 54.71, RSI: 53.86
# 2023-11-01, 收盘价: 54.95, RSI: 55.70
# 2023-11-02, 收盘价: 55.08, RSI: 57.35
# 2023-11-03, 收盘价: 56.37, RSI: 65.72
# 2023-11-06, 收盘价: 56.97, RSI: 64.29
# 2023-11-07, 收盘价: 57.48, RSI: 75.25
# 2023-11-07, 卖出信号 (RSI>70), 卖出全部: 2249 股
# 2023-11-08, 卖单执行, 价格: 57.03, 股数: -2249
# 2023-11-08, 收盘价: 57.21, RSI: 75.68
# 2023-11-09, 收盘价: 56.55, RSI: 86.51
# 2023-11-10, 收盘价: 56.27, RSI: 88.85
# 2023-11-13, 收盘价: 58.03, RSI: 89.70
# 2023-11-14, 收盘价: 58.78, RSI: 89.86
# 2023-11-15, 收盘价: 59.64, RSI: 91.22
# 2023-11-16, 收盘价: 59.26, RSI: 87.70
# 2023-11-17, 收盘价: 59.56, RSI: 83.18
# 2023-11-20, 收盘价: 57.64, RSI: 64.67
# 2023-11-21, 收盘价: 58.56, RSI: 66.95
# 2023-11-22, 收盘价: 58.13, RSI: 63.94
# 2023-11-23, 收盘价: 58.12, RSI: 59.05
# 2023-11-24, 收盘价: 57.32, RSI: 51.76
# 2023-11-27, 收盘价: 57.55, RSI: 50.36
# 2023-11-28, 收盘价: 57.43, RSI: 51.16
# 2023-11-29, 收盘价: 57.68, RSI: 56.22
# 2023-11-30, 收盘价: 58.64, RSI: 62.17
# 2023-12-01, 收盘价: 59.74, RSI: 59.43
# 2023-12-04, 收盘价: 59.22, RSI: 52.47
# 2023-12-05, 收盘价: 57.49, RSI: 38.89
# 2023-12-06, 收盘价: 57.72, RSI: 41.94
# 2023-12-07, 收盘价: 56.57, RSI: 35.60
# 2023-12-08, 收盘价: 57.17, RSI: 47.42
# 2023-12-11, 收盘价: 59.64, RSI: 55.11
# 2023-12-12, 收盘价: 60.18, RSI: 59.55
# 2023-12-13, 收盘价: 59.80, RSI: 57.58
# 2023-12-14, 收盘价: 61.24, RSI: 66.72
# 2023-12-15, 收盘价: 60.03, RSI: 59.80
# 2023-12-18, 收盘价: 59.16, RSI: 56.43
# 2023-12-19, 收盘价: 59.45, RSI: 56.56
# 2023-12-20, 收盘价: 58.66, RSI: 50.07
# 2023-12-21, 收盘价: 59.76, RSI: 50.07
# 2023-12-22, 收盘价: 58.51, RSI: 47.48
# 2023-12-25, 收盘价: 56.57, RSI: 46.79
# 2023-12-26, 收盘价: 55.11, RSI: 41.58
# 2023-12-27, 收盘价: 57.31, RSI: 52.23
# 2023-12-28, 收盘价: 57.00, RSI: 49.48
# 2023-12-29, 收盘价: 58.42, RSI: 45.97
# 2024-01-02, 收盘价: 57.29, RSI: 40.83
# 2024-01-03, 收盘价: 56.23, RSI: 39.15
# 2024-01-04, 收盘价: 55.57, RSI: 31.94
# 2024-01-05, 收盘价: 55.34, RSI: 34.05
# 2024-01-08, 收盘价: 54.29, RSI: 33.64
# 2024-01-09, 收盘价: 56.22, RSI: 40.26
# 2024-01-10, 收盘价: 54.62, RSI: 38.37
# 2024-01-11, 收盘价: 56.65, RSI: 41.49
# 2024-01-12, 收盘价: 55.27, RSI: 41.20
# 2024-01-15, 收盘价: 54.09, RSI: 42.96
# 2024-01-16, 收盘价: 53.37, RSI: 44.86
# 2024-01-17, 收盘价: 52.29, RSI: 34.11
# 2024-01-18, 收盘价: 53.74, RSI: 40.38
# 2024-01-19, 收盘价: 54.81, RSI: 39.13
# 2024-01-22, 收盘价: 53.78, RSI: 39.36
# 2024-01-23, 收盘价: 53.85, RSI: 42.31
# 2024-01-24, 收盘价: 51.67, RSI: 38.55
# 2024-01-25, 收盘价: 51.37, RSI: 38.39
# 2024-01-26, 收盘价: 49.51, RSI: 36.67
# 2024-01-29, 收盘价: 48.35, RSI: 27.00
# 2024-01-29, 买入信号 (RSI<30), 全仓买入: 2653 股
# 2024-01-30, 买单执行, 价格: 48.20, 股数: 2653
# 2024-01-30, 收盘价: 47.17, RSI: 27.68
# 2024-01-31, 收盘价: 44.94, RSI: 15.35
# 2024-02-01, 收盘价: 46.50, RSI: 24.33
# 2024-02-02, 收盘价: 44.54, RSI: 23.27
# 2024-02-05, 收盘价: 44.33, RSI: 23.95
# 2024-02-06, 收盘价: 47.44, RSI: 37.47
# 2024-02-07, 收盘价: 48.42, RSI: 35.93
# 2024-02-08, 收盘价: 49.61, RSI: 36.33
# 2024-02-19, 收盘价: 51.65, RSI: 44.69
# 2024-02-20, 收盘价: 51.35, RSI: 43.84
# 2024-02-21, 收盘价: 50.50, RSI: 46.90
# 2024-02-22, 收盘价: 51.05, RSI: 49.17
# 2024-02-23, 收盘价: 51.31, RSI: 55.12
# 2024-02-26, 收盘价: 51.90, RSI: 60.43
# 2024-02-27, 收盘价: 53.10, RSI: 67.43
# 2024-02-28, 收盘价: 50.48, RSI: 65.89
# 2024-02-29, 收盘价: 51.90, RSI: 65.61
# 2024-03-01, 收盘价: 52.86, RSI: 75.53
# 2024-03-01, 卖出信号 (RSI>70), 卖出全部: 2653 股
# 2024-03-04, 卖单执行, 价格: 53.99, 股数: -2653
# 2024-03-04, 收盘价: 54.53, RSI: 78.72
# 2024-03-05, 收盘价: 54.16, RSI: 72.35
# 2024-03-06, 收盘价: 52.38, RSI: 62.50
# 2024-03-07, 收盘价: 51.00, RSI: 54.35
# 2024-03-08, 收盘价: 52.06, RSI: 51.36
# 2024-03-11, 收盘价: 51.77, RSI: 51.39
# 2024-03-12, 收盘价: 52.67, RSI: 57.23
# 2024-03-13, 收盘价: 52.62, RSI: 55.36
# 2024-03-14, 收盘价: 51.50, RSI: 50.61
# 2024-03-15, 收盘价: 52.10, RSI: 50.64
# 2024-03-18, 收盘价: 52.40, RSI: 47.57
# 2024-03-19, 收盘价: 48.52, RSI: 43.79
# 2024-03-20, 收盘价: 47.36, RSI: 35.36
# 2024-03-21, 收盘价: 49.38, RSI: 39.51
# 2024-03-22, 收盘价: 49.01, RSI: 31.92
# 2024-03-25, 收盘价: 47.67, RSI: 30.05
# 2024-03-26, 收盘价: 46.77, RSI: 31.76
# 2024-03-27, 收盘价: 45.04, RSI: 31.04
# 2024-03-28, 收盘价: 46.19, RSI: 31.47
# 2024-03-29, 收盘价: 45.69, RSI: 31.04
# 2024-04-01, 收盘价: 45.54, RSI: 26.66
# 2024-04-01, 买入信号 (RSI<30), 全仓买入: 3154 股
# 2024-04-02, 订单取消/拒绝
# 2024-04-02, 收盘价: 45.49, RSI: 26.68
# 2024-04-02, 买入信号 (RSI<30), 全仓买入: 3158 股
# 2024-04-03, 买单执行, 价格: 45.38, 股数: 3158
# 2024-04-03, 收盘价: 45.01, RSI: 27.83
# 2024-04-08, 收盘价: 43.65, RSI: 22.58
# 2024-04-09, 收盘价: 44.00, RSI: 22.83
# 2024-04-10, 收盘价: 42.90, RSI: 27.84
# 2024-04-11, 收盘价: 46.88, RSI: 48.46
# 2024-04-12, 收盘价: 47.66, RSI: 43.96
# 2024-04-15, 收盘价: 48.77, RSI: 49.20
# 2024-04-16, 收盘价: 47.50, RSI: 49.43
# 2024-04-17, 收盘价: 49.21, RSI: 57.78
# 2024-04-18, 收盘价: 47.37, RSI: 57.35
# 2024-04-19, 收盘价: 45.64, RSI: 48.30
# 2024-04-22, 收盘价: 46.46, RSI: 52.32
# 2024-04-23, 收盘价: 45.90, RSI: 51.07
# 2024-04-24, 收盘价: 46.82, RSI: 53.70
# 2024-04-25, 收盘价: 48.02, RSI: 58.05
# 2024-04-26, 收盘价: 50.48, RSI: 67.24
# 2024-04-29, 收盘价: 51.03, RSI: 67.58
# 2024-04-30, 收盘价: 50.62, RSI: 69.94
# 2024-05-06, 收盘价: 50.76, RSI: 62.50
# 2024-05-07, 收盘价: 50.25, RSI: 58.49
# 2024-05-08, 收盘价: 50.58, RSI: 56.26
# 2024-05-09, 收盘价: 50.77, RSI: 62.18
# 2024-05-10, 收盘价: 50.58, RSI: 55.74
# 2024-05-13, 收盘价: 50.57, RSI: 65.97
# 2024-05-14, 收盘价: 50.23, RSI: 76.61
# 2024-05-14, 卖出信号 (RSI>70), 卖出全部: 3158 股
# 2024-05-15, 卖单执行, 价格: 49.78, 股数: -3158
# 2024-05-15, 收盘价: 49.39, RSI: 66.97
# 2024-05-16, 收盘价: 48.93, RSI: 67.67
# 2024-05-17, 收盘价: 49.18, RSI: 64.94
# 2024-05-20, 收盘价: 49.84, RSI: 62.38
# 2024-05-21, 收盘价: 49.61, RSI: 41.55
# 2024-05-22, 收盘价: 50.97, RSI: 49.50
# 2024-05-23, 收盘价: 50.51, RSI: 49.08
# 2024-05-24, 收盘价: 49.46, RSI: 40.61
# 2024-05-27, 收盘价: 52.32, RSI: 61.21
# 2024-05-28, 收盘价: 52.26, RSI: 59.38
# 2024-05-29, 收盘价: 52.49, RSI: 59.56
# 2024-05-30, 收盘价: 52.55, RSI: 61.10
# 2024-05-31, 收盘价: 52.69, RSI: 61.81
# 2024-06-03, 收盘价: 54.06, RSI: 69.08
# 2024-06-04, 收盘价: 53.32, RSI: 69.77
# 2024-06-05, 收盘价: 51.77, RSI: 62.91
# 2024-06-06, 收盘价: 51.21, RSI: 58.98
# 2024-06-07, 收盘价: 50.60, RSI: 53.37
# 2024-06-11, 收盘价: 51.11, RSI: 56.48
# 2024-06-12, 收盘价: 51.60, RSI: 52.93
# 2024-06-13, 收盘价: 52.70, RSI: 59.69
# 2024-06-14, 收盘价: 53.00, RSI: 66.73
# 2024-06-17, 收盘价: 53.83, RSI: 58.85
# 2024-06-18, 收盘价: 54.38, RSI: 61.75
# 2024-06-19, 收盘价: 55.17, RSI: 63.98
# 2024-06-20, 收盘价: 56.08, RSI: 66.91
# 2024-06-21, 收盘价: 56.81, RSI: 68.66
# 2024-06-24, 收盘价: 57.13, RSI: 65.39
# 2024-06-25, 收盘价: 54.96, RSI: 57.18
# 2024-06-26, 收盘价: 56.30, RSI: 70.21
# 2024-06-27, 收盘价: 56.05, RSI: 72.20
# 2024-06-28, 收盘价: 57.16, RSI: 78.77
# 2024-07-01, 收盘价: 56.48, RSI: 73.21
# 2024-07-02, 收盘价: 55.55, RSI: 66.44
# 2024-07-03, 收盘价: 56.06, RSI: 64.71
# 2024-07-04, 收盘价: 56.06, RSI: 63.76
# 2024-07-05, 收盘价: 56.06, RSI: 60.84
# 2024-07-08, 收盘价: 59.53, RSI: 69.49
# 2024-07-09, 收盘价: 59.78, RSI: 68.19
# 2024-07-10, 收盘价: 60.60, RSI: 67.97
# 2024-07-11, 收盘价: 62.22, RSI: 70.08
# 2024-07-12, 收盘价: 63.66, RSI: 72.38
# 2024-07-15, 收盘价: 64.30, RSI: 85.76
# 2024-07-16, 收盘价: 65.03, RSI: 85.06
# 2024-07-17, 收盘价: 63.21, RSI: 75.53
# 2024-07-18, 收盘价: 63.00, RSI: 72.26
# 2024-07-19, 收盘价: 63.01, RSI: 76.22
# 2024-07-22, 收盘价: 63.93, RSI: 83.68
# 2024-07-23, 收盘价: 58.80, RSI: 58.03
# 2024-07-24, 收盘价: 58.98, RSI: 58.47
# 2024-07-25, 收盘价: 58.20, RSI: 55.94
# 2024-07-26, 收盘价: 58.23, RSI: 45.54
# 2024-07-29, 收盘价: 58.00, RSI: 43.89
# 2024-07-30, 收盘价: 58.47, RSI: 42.51
# 2024-07-31, 收盘价: 59.60, RSI: 40.45
# 2024-08-01, 收盘价: 59.26, RSI: 32.57
# 2024-08-02, 收盘价: 56.60, RSI: 23.70
# 2024-08-02, 买入信号 (RSI<30), 全仓买入: 2783 股
# 2024-08-05, 买单执行, 价格: 55.80, 股数: 2783
# 2024-08-05, 收盘价: 53.20, RSI: 15.83
# 2024-08-06, 收盘价: 53.17, RSI: 17.65
# 2024-08-07, 收盘价: 52.86, RSI: 17.54
# 2024-08-08, 收盘价: 53.24, RSI: 19.45
# 2024-08-09, 收盘价: 53.00, RSI: 14.30
# 2024-08-12, 收盘价: 53.80, RSI: 27.23
# 2024-08-13, 收盘价: 54.86, RSI: 32.63
# 2024-08-14, 收盘价: 53.75, RSI: 31.75
# 2024-08-15, 收盘价: 54.10, RSI: 33.49
# 2024-08-16, 收盘价: 53.85, RSI: 33.44
# 2024-08-19, 收盘价: 55.31, RSI: 38.31
# 2024-08-20, 收盘价: 55.06, RSI: 32.04
# 2024-08-21, 收盘价: 54.83, RSI: 32.32
# 2024-08-22, 收盘价: 54.16, RSI: 38.43
# 2024-08-23, 收盘价: 54.00, RSI: 55.48
# 2024-08-26, 收盘价: 53.10, RSI: 49.57
# 2024-08-27, 收盘价: 52.13, RSI: 45.87
# 2024-08-28, 收盘价: 50.94, RSI: 38.07
# 2024-08-29, 收盘价: 51.35, RSI: 41.59
# 2024-08-30, 收盘价: 52.63, RSI: 44.31
# 2024-09-02, 收盘价: 49.95, RSI: 29.39
# 2024-09-03, 收盘价: 52.94, RSI: 47.06
# 2024-09-04, 收盘价: 52.09, RSI: 42.97
# 2024-09-05, 收盘价: 52.00, RSI: 43.45
# 2024-09-06, 收盘价: 51.74, RSI: 36.19
# 2024-09-09, 收盘价: 51.30, RSI: 35.67
# 2024-09-10, 收盘价: 51.50, RSI: 37.28
# 2024-09-11, 收盘价: 51.81, RSI: 40.77
# 2024-09-12, 收盘价: 51.21, RSI: 39.41
# 2024-09-13, 收盘价: 51.07, RSI: 41.82
# 2024-09-18, 收盘价: 49.30, RSI: 39.29
# 2024-09-19, 收盘价: 48.96, RSI: 41.99
# 2024-09-20, 收盘价: 49.59, RSI: 43.00
# 2024-09-23, 收盘价: 48.50, RSI: 33.33
# 2024-09-24, 收盘价: 50.03, RSI: 50.36
# 2024-09-25, 收盘价: 49.91, RSI: 31.90
# 2024-09-26, 收盘价: 52.28, RSI: 50.96
# 2024-09-27, 收盘价: 57.00, RSI: 67.22
# 2024-09-30, 收盘价: 66.88, RSI: 81.36
# 2024-09-30, 卖出信号 (RSI>70), 卖出全部: 2783 股
# 2024-10-08, 卖单执行, 价格: 80.26, 股数: -2783
# 2024-10-08, 收盘价: 80.26, RSI: 89.05
# 2024-10-09, 收盘价: 78.41, RSI: 84.74
# 2024-10-10, 收盘价: 70.89, RSI: 70.77
# 2024-10-11, 收盘价: 65.52, RSI: 64.11
# 2024-10-14, 收盘价: 66.93, RSI: 65.26
# 2024-10-15, 收盘价: 65.00, RSI: 65.06
# 2024-10-16, 收盘价: 62.30, RSI: 62.24
# 2024-10-17, 收盘价: 61.34, RSI: 60.71
# 2024-10-18, 收盘价: 68.95, RSI: 66.67
# 2024-10-21, 收盘价: 69.93, RSI: 66.37
# 2024-10-22, 收盘价: 70.94, RSI: 67.04
# 2024-10-23, 收盘价: 68.65, RSI: 63.29
# 2024-10-24, 收盘价: 69.00, RSI: 60.48
# 2024-10-25, 收盘价: 70.01, RSI: 53.24
# 2024-10-28, 收盘价: 69.09, RSI: 34.45
# 2024-10-29, 收盘价: 67.92, RSI: 35.11
# 2024-10-30, 收盘价: 69.08, RSI: 46.87
# 2024-10-31, 收盘价: 68.41, RSI: 55.98
# 2024-11-01, 收盘价: 64.55, RSI: 45.53
# 2024-11-04, 收盘价: 66.05, RSI: 52.00
# 2024-11-05, 收盘价: 69.00, RSI: 62.67
# 2024-11-06, 收盘价: 68.40, RSI: 63.54
# 2024-11-07, 收盘价: 70.38, RSI: 53.50
# 2024-11-08, 收盘价: 70.63, RSI: 51.77
# 2024-11-11, 收盘价: 78.11, RSI: 63.69
# 2024-11-12, 收盘价: 74.40, RSI: 60.41
# 2024-11-13, 收盘价: 75.39, RSI: 61.31
# 2024-11-14, 收盘价: 71.70, RSI: 52.73
# 2024-11-15, 收盘价: 68.73, RSI: 49.45
# 2024-11-18, 收盘价: 66.20, RSI: 47.50
# 2024-11-19, 收盘价: 68.16, RSI: 48.69
# 2024-11-20, 收盘价: 67.96, RSI: 49.35
# 2024-11-21, 收盘价: 67.60, RSI: 54.89
# 2024-11-22, 收盘价: 63.91, RSI: 46.79
# 2024-11-25, 收盘价: 63.63, RSI: 41.25
# 2024-11-26, 收盘价: 63.11, RSI: 41.36
# 2024-11-27, 收盘价: 66.69, RSI: 44.27
# 2024-11-28, 收盘价: 66.52, RSI: 43.60
# 2024-11-29, 收盘价: 67.38, RSI: 28.97
# 2024-11-29, 买入信号 (RSI<30), 全仓买入: 3348 股
# 2024-12-02, 订单取消/拒绝
# 2024-12-02, 收盘价: 69.13, RSI: 38.81
# 2024-12-03, 收盘价: 68.34, RSI: 34.90
# 2024-12-04, 收盘价: 67.83, RSI: 40.41
# 2024-12-05, 收盘价: 68.30, RSI: 48.78
# 2024-12-06, 收盘价: 70.18, RSI: 61.69
# 2024-12-09, 收盘价: 68.82, RSI: 52.01
# 2024-12-10, 收盘价: 68.39, RSI: 51.29
# 2024-12-11, 收盘价: 68.89, RSI: 53.84
# 2024-12-12, 收盘价: 68.70, RSI: 68.02
# 2024-12-13, 收盘价: 68.02, RSI: 66.03
# 2024-12-16, 收盘价: 68.95, RSI: 70.71
# 2024-12-17, 收盘价: 66.87, RSI: 50.71
# 2024-12-18, 收盘价: 68.80, RSI: 57.94
# 2024-12-19, 收盘价: 70.79, RSI: 61.01
# 2024-12-20, 收盘价: 72.52, RSI: 60.96
# 2024-12-23, 收盘价: 70.92, RSI: 57.92
# 2024-12-24, 收盘价: 72.18, RSI: 62.77
# 2024-12-25, 收盘价: 72.41, RSI: 62.24
# 2024-12-26, 收盘价: 79.99, RSI: 71.81
# 2024-12-27, 收盘价: 75.48, RSI: 62.99
# 2024-12-30, 收盘价: 71.19, RSI: 54.75
# 2024-12-31, 收盘价: 67.90, RSI: 48.47
# 2025-01-02, 收盘价: 65.93, RSI: 45.93
# 2025-01-03, 收盘价: 65.52, RSI: 46.30
# 2025-01-06, 收盘价: 63.91, RSI: 42.69
# 2025-01-07, 收盘价: 66.41, RSI: 49.34
# 2025-01-08, 收盘价: 66.82, RSI: 47.03
# 2025-01-09, 收盘价: 66.30, RSI: 42.96
# 2025-01-10, 收盘价: 64.20, RSI: 37.11
# 2025-01-13, 收盘价: 62.91, RSI: 37.47
# 2025-01-14, 收盘价: 66.43, RSI: 41.60
# 2025-01-15, 收盘价: 66.20, RSI: 40.93
# 2025-01-16, 收盘价: 66.01, RSI: 23.96
# 2025-01-16, 买入信号 (RSI<30), 全仓买入: 3418 股
# 2025-01-17, 买单执行, 价格: 65.59, 股数: 3418
# 2025-01-17, 收盘价: 66.67, RSI: 30.84
# 2025-01-20, 收盘价: 67.28, RSI: 39.88
# 2025-01-21, 收盘价: 70.08, RSI: 55.79
# 2025-01-22, 收盘价: 71.32, RSI: 64.90
# 2025-01-23, 收盘价: 70.10, RSI: 62.12
# 2025-01-24, 收盘价: 70.84, RSI: 69.22
# 2025-01-27, 收盘价: 68.04, RSI: 54.45
# 2025-02-05, 收盘价: 69.40, RSI: 56.69
# 2025-02-06, 收盘价: 71.33, RSI: 62.16
# 2025-02-07, 收盘价: 72.35, RSI: 70.78
# 2025-02-07, 卖出信号 (RSI>70), 卖出全部: 3418 股
# 2025-02-10, 卖单执行, 价格: 72.96, 股数: -3418
# 2025-02-10, 收盘价: 72.61, RSI: 76.10
# 2025-02-11, 收盘价: 71.78, RSI: 66.83
# 2025-02-12, 收盘价: 72.43, RSI: 69.10
# 2025-02-13, 收盘价: 70.00, RSI: 60.75
# 2025-02-14, 收盘价: 73.31, RSI: 65.66
# 2025-02-17, 收盘价: 74.79, RSI: 67.01
# 2025-02-18, 收盘价: 71.90, RSI: 54.11
# 2025-02-19, 收盘价: 73.34, RSI: 54.52
# 2025-02-20, 收盘价: 72.44, RSI: 55.31
# 2025-02-21, 收盘价: 77.01, RSI: 61.93
# 2025-02-24, 收盘价: 77.67, RSI: 70.29
# 2025-02-25, 收盘价: 79.84, RSI: 71.27
# 2025-02-26, 收盘价: 81.66, RSI: 71.14
# 2025-02-27, 收盘价: 83.68, RSI: 72.28
# 2025-02-27, 策略结束，期末资金: 250829.33
# 2023-03-27, 收盘价: 67.84, 上轨: 68.03, 下轨: 49.58
# 2023-03-28, 收盘价: 63.77, 上轨: 68.57, 下轨: 49.70
# 2023-03-29, 收盘价: 67.49, 上轨: 69.71, 下轨: 49.62
# 2023-03-30, 收盘价: 69.23, 上轨: 71.05, 下轨: 49.59
# 2023-03-31, 收盘价: 68.75, 上轨: 72.12, 下轨: 49.69
# 2023-04-03, 收盘价: 70.74, 上轨: 73.42, 下轨: 49.78
# 2023-04-04, 收盘价: 73.19, 上轨: 74.98, 下轨: 49.99
# 2023-04-06, 收盘价: 74.40, 上轨: 76.50, 下轨: 50.39
# 2023-04-07, 收盘价: 75.46, 上轨: 78.01, 下轨: 50.81
# 2023-04-10, 收盘价: 70.91, 上轨: 78.39, 下轨: 52.00
# 2023-04-11, 收盘价: 71.80, 上轨: 78.64, 下轨: 53.43
# 2023-04-12, 收盘价: 75.57, 上轨: 79.30, 下轨: 54.79
# 2023-04-13, 收盘价: 70.86, 上轨: 78.95, 下轨: 56.69
# 2023-04-14, 收盘价: 73.37, 上轨: 78.58, 下轨: 58.83
# 2023-04-17, 收盘价: 71.21, 上轨: 77.81, 下轨: 60.98
# 2023-04-18, 收盘价: 69.90, 上轨: 77.47, 下轨: 62.12
# 2023-04-19, 收盘价: 71.31, 上轨: 76.94, 下轨: 63.64
# 2023-04-20, 收盘价: 75.62, 上轨: 76.94, 下轨: 64.97
# 2023-04-21, 收盘价: 71.27, 上轨: 76.96, 下轨: 65.25
# 2023-04-24, 收盘价: 68.44, 上轨: 76.98, 下轨: 65.13
# 2023-04-25, 收盘价: 67.99, 上轨: 76.97, 下轨: 65.16
# 2023-04-26, 收盘价: 63.49, 上轨: 77.03, 下轨: 65.07
# 2023-04-26, 买入信号 (收盘价<下轨), 全仓买入: 1574 股
# 2023-04-27, 买单执行, 价格: 62.87, 股数: 1574
# 2023-04-27, 收盘价: 62.35, 上轨: 77.73, 下轨: 63.86
# 2023-04-28, 收盘价: 60.23, 上轨: 78.66, 下轨: 62.03
# 2023-05-04, 收盘价: 58.70, 上轨: 79.57, 下轨: 60.11
# 2023-05-05, 收盘价: 58.29, 上轨: 80.16, 下轨: 58.28
# 2023-05-08, 收盘价: 58.76, 上轨: 80.17, 下轨: 56.82
# 2023-05-09, 收盘价: 57.23, 上轨: 79.96, 下轨: 55.32
# 2023-05-10, 收盘价: 55.87, 上轨: 79.44, 下轨: 53.88
# 2023-05-11, 收盘价: 55.18, 上轨: 79.42, 下轨: 52.32
# 2023-05-12, 收盘价: 53.14, 上轨: 79.28, 下轨: 50.60
# 2023-05-15, 收盘价: 53.55, 上轨: 78.12, 下轨: 49.55
# 2023-05-16, 收盘价: 53.22, 上轨: 77.57, 下轨: 48.34
# 2023-05-17, 收盘价: 54.54, 上轨: 76.25, 下轨: 47.78
# 2023-05-18, 收盘价: 57.36, 上轨: 75.03, 下轨: 47.61
# 2023-05-19, 收盘价: 58.31, 上轨: 73.92, 下轨: 47.56
# 2023-05-22, 收盘价: 58.76, 上轨: 72.39, 下轨: 47.84
# 2023-05-23, 收盘价: 57.06, 上轨: 69.24, 下轨: 49.14
# 2023-05-24, 收盘价: 57.36, 上轨: 66.89, 下轨: 50.09
# 2023-05-25, 收盘价: 59.44, 上轨: 65.12, 下轨: 50.96
# 2023-05-26, 收盘价: 60.47, 上轨: 63.23, 下轨: 52.10
# 2023-05-29, 收盘价: 62.23, 上轨: 62.92, 下轨: 52.28
# 2023-05-30, 收盘价: 63.03, 上轨: 63.09, 下轨: 52.19
# 2023-05-31, 收盘价: 63.10, 上轨: 63.63, 下轨: 51.93
# 2023-06-01, 收盘价: 61.42, 上轨: 63.97, 下轨: 51.86
# 2023-06-02, 收盘价: 60.02, 上轨: 64.12, 下轨: 51.88
# 2023-06-05, 收盘价: 59.62, 上轨: 64.20, 下轨: 51.89
# 2023-06-06, 收盘价: 58.44, 上轨: 64.25, 下轨: 51.96
# 2023-06-07, 收盘价: 59.25, 上轨: 64.35, 下轨: 52.20
# 2023-06-08, 收盘价: 56.48, 上轨: 64.31, 下轨: 52.37
# 2023-06-09, 收盘价: 57.55, 上轨: 64.05, 下轨: 53.07
# 2023-06-12, 收盘价: 57.56, 上轨: 63.78, 下轨: 53.75
# 2023-06-13, 收盘价: 62.16, 上轨: 63.74, 下轨: 54.68
# 2023-06-14, 收盘价: 62.22, 上轨: 63.76, 下轨: 55.42
# 2023-06-15, 收盘价: 60.81, 上轨: 63.83, 下轨: 55.69
# 2023-06-16, 收盘价: 60.16, 上轨: 63.87, 下轨: 55.84
# 2023-06-19, 收盘价: 61.43, 上轨: 64.03, 下轨: 55.95
# 2023-06-20, 收盘价: 59.74, 上轨: 63.94, 下轨: 56.31
# 2023-06-21, 收盘价: 57.44, 上轨: 63.93, 下轨: 56.32
# 2023-06-26, 收盘价: 55.38, 上轨: 64.25, 下轨: 55.60
# 2023-06-27, 收盘价: 55.47, 上轨: 64.40, 下轨: 54.95
# 2023-06-28, 收盘价: 54.77, 上轨: 64.33, 下轨: 54.27
# 2023-06-29, 收盘价: 55.06, 上轨: 63.95, 下轨: 53.85
# 2023-06-30, 收盘价: 56.79, 上轨: 63.33, 下轨: 53.85
# 2023-07-03, 收盘价: 59.21, 上轨: 63.05, 下轨: 53.90
# 2023-07-04, 收盘价: 62.01, 上轨: 63.36, 下轨: 53.79
# 2023-07-05, 收盘价: 61.99, 上轨: 63.69, 下轨: 53.70
# 2023-07-06, 收盘价: 63.02, 上轨: 64.26, 下轨: 53.59
# 2023-07-07, 收盘价: 63.00, 上轨: 64.74, 下轨: 53.49
# 2023-07-10, 收盘价: 60.33, 上轨: 64.82, 下轨: 53.79
# 2023-07-11, 收盘价: 61.29, 上轨: 65.01, 下轨: 53.98
# 2023-07-12, 收盘价: 58.43, 上轨: 65.00, 下轨: 54.07
# 2023-07-13, 收盘价: 60.80, 上轨: 64.84, 下轨: 54.10
# 2023-07-14, 收盘价: 61.31, 上轨: 64.71, 下轨: 54.13
# 2023-07-17, 收盘价: 60.43, 上轨: 64.67, 下轨: 54.13
# 2023-07-18, 收盘价: 59.51, 上轨: 64.63, 下轨: 54.11
# 2023-07-19, 收盘价: 58.54, 上轨: 64.41, 下轨: 54.04
# 2023-07-20, 收盘价: 57.11, 上轨: 64.35, 下轨: 53.84
# 2023-07-21, 收盘价: 56.97, 上轨: 64.36, 下轨: 53.78
# 2023-07-24, 收盘价: 57.95, 上轨: 64.25, 下轨: 54.15
# 2023-07-25, 收盘价: 58.63, 上轨: 64.12, 下轨: 54.60
# 2023-07-26, 收盘价: 58.04, 上轨: 63.84, 下轨: 55.20
# 2023-07-27, 收盘价: 57.46, 上轨: 63.58, 下轨: 55.70
# 2023-07-28, 收盘价: 58.37, 上轨: 63.48, 下轨: 55.95
# 2023-07-31, 收盘价: 57.28, 上轨: 63.53, 下轨: 55.71
# 2023-08-01, 收盘价: 57.00, 上轨: 63.28, 下轨: 55.47
# 2023-08-02, 收盘价: 56.03, 上轨: 63.05, 下轨: 55.10
# 2023-08-03, 收盘价: 56.32, 上轨: 62.44, 下轨: 55.03
# 2023-08-04, 收盘价: 57.41, 上轨: 61.64, 下轨: 55.28
# 2023-08-07, 收盘价: 57.15, 上轨: 61.41, 下轨: 55.19
# 2023-08-08, 收盘价: 56.86, 上轨: 60.93, 下轨: 55.23
# 2023-08-09, 收盘价: 56.01, 上轨: 60.94, 下轨: 54.98
# 2023-08-10, 收盘价: 56.24, 上轨: 60.50, 下轨: 54.96
# 2023-08-11, 收盘价: 54.24, 上轨: 60.03, 下轨: 54.72
# 2023-08-14, 收盘价: 52.77, 上轨: 59.97, 下轨: 54.02
# 2023-08-15, 收盘价: 50.86, 上轨: 60.35, 下轨: 52.77
# 2023-08-16, 收盘价: 48.47, 上轨: 61.12, 下轨: 50.99
# 2023-08-17, 收盘价: 48.53, 上轨: 61.63, 下轨: 49.63
# 2023-08-18, 收盘价: 48.34, 上轨: 61.95, 下轨: 48.45
# 2023-08-21, 收盘价: 47.52, 上轨: 62.08, 下轨: 47.28
# 2023-08-22, 收盘价: 48.88, 上轨: 61.76, 下轨: 46.61
# 2023-08-23, 收盘价: 48.15, 上轨: 61.49, 下轨: 45.90
# 2023-08-24, 收盘价: 49.41, 上轨: 61.10, 下轨: 45.49
# 2023-08-25, 收盘价: 47.74, 上轨: 60.56, 下轨: 44.96
# 2023-08-28, 收盘价: 48.47, 上轨: 60.04, 下轨: 44.60
# 2023-08-29, 收盘价: 50.51, 上轨: 59.44, 下轨: 44.55
# 2023-08-30, 收盘价: 51.17, 上轨: 58.97, 下轨: 44.53
# 2023-08-31, 收盘价: 50.94, 上轨: 58.40, 下轨: 44.57
# 2023-09-01, 收盘价: 51.06, 上轨: 57.52, 下轨: 44.81
# 2023-09-04, 收盘价: 51.32, 上轨: 56.61, 下轨: 45.14
# 2023-09-05, 收盘价: 51.32, 上轨: 55.64, 下轨: 45.55
# 2023-09-06, 收盘价: 53.48, 上轨: 55.08, 下轨: 45.87
# 2023-09-07, 收盘价: 51.20, 上轨: 54.01, 下轨: 46.43
# 2023-09-08, 收盘价: 51.35, 上轨: 53.44, 下轨: 46.71
# 2023-09-11, 收盘价: 51.51, 上轨: 53.22, 下轨: 46.81
# 2023-09-12, 收盘价: 50.81, 上轨: 53.21, 下轨: 46.81
# 2023-09-13, 收盘价: 50.59, 上轨: 53.25, 下轨: 46.98
# 2023-09-14, 收盘价: 50.09, 上轨: 53.24, 下轨: 47.15
# 2023-09-15, 收盘价: 51.47, 上轨: 53.32, 下轨: 47.38
# 2023-09-18, 收盘价: 50.69, 上轨: 53.18, 下轨: 47.83
# 2023-09-19, 收盘价: 50.54, 上轨: 53.16, 下轨: 48.02
# 2023-09-20, 收盘价: 50.46, 上轨: 53.02, 下轨: 48.39
# 2023-09-21, 收盘价: 49.41, 上轨: 53.02, 下轨: 48.39
# 2023-09-22, 收盘价: 50.97, 上轨: 52.74, 下轨: 49.00
# 2023-09-25, 收盘价: 49.71, 上轨: 52.54, 下轨: 49.32
# 2023-09-26, 收盘价: 48.96, 上轨: 52.68, 下轨: 49.03
# 2023-09-27, 收盘价: 49.26, 上轨: 52.70, 下轨: 48.82
# 2023-09-28, 收盘价: 49.41, 上轨: 52.71, 下轨: 48.66
# 2023-10-09, 收盘价: 50.32, 上轨: 52.67, 下轨: 48.62
# 2023-10-10, 收盘价: 53.06, 上轨: 53.00, 下轨: 48.46
# 2023-10-10, 卖出信号 (收盘价>上轨), 卖出全部: 1574 股
# 2023-10-11, 卖单执行, 价格: 52.87, 股数: -1574
# 2023-10-11, 收盘价: 53.43, 上轨: 53.38, 下轨: 48.29
# 2023-10-12, 收盘价: 53.07, 上轨: 53.28, 下轨: 48.35
# 2023-10-13, 收盘价: 52.69, 上轨: 53.49, 下轨: 48.29
# 2023-10-16, 收盘价: 51.30, 上轨: 53.48, 下轨: 48.29
# 2023-10-17, 收盘价: 52.55, 上轨: 53.62, 下轨: 48.26
# 2023-10-18, 收盘价: 50.46, 上轨: 53.61, 下轨: 48.23
# 2023-10-19, 收盘价: 50.11, 上轨: 53.61, 下轨: 48.19
# 2023-10-20, 收盘价: 47.72, 上轨: 53.81, 下轨: 47.75
# 2023-10-20, 买入信号 (收盘价<下轨), 全仓买入: 1765 股
# 2023-10-23, 买单执行, 价格: 47.10, 股数: 1765
# 2023-10-23, 收盘价: 47.13, 上轨: 53.96, 下轨: 47.16
# 2023-10-24, 收盘价: 47.91, 上轨: 54.01, 下轨: 46.84
# 2023-10-25, 收盘价: 48.46, 上轨: 54.01, 下轨: 46.63
# 2023-10-26, 收盘价: 48.35, 上轨: 54.00, 下轨: 46.43
# 2023-10-27, 收盘价: 49.50, 上轨: 54.00, 下轨: 46.44
# 2023-10-30, 收盘价: 53.29, 上轨: 54.34, 下轨: 46.33
# 2023-10-31, 收盘价: 54.71, 上轨: 55.00, 下轨: 46.17
# 2023-11-01, 收盘价: 54.95, 上轨: 55.62, 下轨: 46.15
# 2023-11-02, 收盘价: 55.08, 上轨: 56.19, 下轨: 46.16
# 2023-11-03, 收盘价: 56.37, 上轨: 56.95, 下轨: 46.10
# 2023-11-06, 收盘价: 56.97, 上轨: 57.74, 下轨: 45.97
# 2023-11-07, 收盘价: 57.48, 上轨: 58.44, 下轨: 45.72
# 2023-11-08, 收盘价: 57.21, 上轨: 58.99, 下轨: 45.54
# 2023-11-09, 收盘价: 56.55, 上轨: 59.41, 下轨: 45.47
# 2023-11-10, 收盘价: 56.27, 上轨: 59.79, 下轨: 45.45
# 2023-11-13, 收盘价: 58.03, 上轨: 60.47, 下轨: 45.44
# 2023-11-14, 收盘价: 58.78, 上轨: 61.19, 下轨: 45.34
# 2023-11-15, 收盘价: 59.64, 上轨: 62.01, 下轨: 45.45
# 2023-11-16, 收盘价: 59.26, 上轨: 62.62, 下轨: 45.75
# 2023-11-17, 收盘价: 59.56, 上轨: 62.98, 下轨: 46.58
# 2023-11-20, 收盘价: 57.64, 上轨: 62.79, 下轨: 47.81
# 2023-11-21, 收盘价: 58.56, 上轨: 62.63, 下轨: 49.04
# 2023-11-22, 收盘价: 58.13, 上轨: 62.27, 下轨: 50.37
# 2023-11-23, 收盘价: 58.12, 上轨: 61.54, 下轨: 52.07
# 2023-11-24, 收盘价: 57.32, 上轨: 60.54, 下轨: 53.85
# 2023-11-27, 收盘价: 57.55, 上轨: 60.23, 下轨: 54.59
# 2023-11-28, 收盘价: 57.43, 上轨: 60.08, 下轨: 55.01
# 2023-11-29, 收盘价: 57.68, 上轨: 59.92, 下轨: 55.44
# 2023-11-30, 收盘价: 58.64, 上轨: 59.79, 下轨: 55.93
# 2023-12-01, 收盘价: 59.74, 上轨: 60.00, 下轨: 56.06
# 2023-12-04, 收盘价: 59.22, 上轨: 60.11, 下轨: 56.17
# 2023-12-05, 收盘价: 57.49, 上轨: 60.11, 下轨: 56.17
# 2023-12-06, 收盘价: 57.72, 上轨: 60.10, 下轨: 56.23
# 2023-12-07, 收盘价: 56.57, 上轨: 60.10, 下轨: 56.24
# 2023-12-08, 收盘价: 57.17, 上轨: 60.00, 下轨: 56.42
# 2023-12-11, 收盘价: 59.64, 上轨: 60.19, 下轨: 56.40
# 2023-12-12, 收盘价: 60.18, 上轨: 60.42, 下轨: 56.31
# 2023-12-13, 收盘价: 59.80, 上轨: 60.45, 下轨: 56.29
# 2023-12-14, 收盘价: 61.24, 上轨: 60.87, 下轨: 56.07
# 2023-12-14, 卖出信号 (收盘价>上轨), 卖出全部: 1765 股
# 2023-12-15, 卖单执行, 价格: 61.72, 股数: -1765
# 2023-12-15, 收盘价: 60.03, 上轨: 60.94, 下轨: 56.04
# 2023-12-18, 收盘价: 59.16, 上轨: 61.00, 下轨: 56.13
# 2023-12-19, 收盘价: 59.45, 上轨: 61.08, 下轨: 56.15
# 2023-12-20, 收盘价: 58.66, 上轨: 61.09, 下轨: 56.19
# 2023-12-21, 收盘价: 59.76, 上轨: 61.21, 下轨: 56.23
# 2023-12-22, 收盘价: 58.51, 上轨: 61.19, 下轨: 56.37
# 2023-12-25, 收盘价: 56.57, 上轨: 61.27, 下轨: 56.19
# 2023-12-26, 收盘价: 55.11, 上轨: 61.56, 下轨: 55.67
# 2023-12-26, 买入信号 (收盘价<下轨), 全仓买入: 1997 股
# 2023-12-27, 订单取消/拒绝
# 2023-12-27, 收盘价: 57.31, 上轨: 61.57, 下轨: 55.62
# 2023-12-28, 收盘价: 57.00, 上轨: 61.57, 下轨: 55.46
# 2023-12-29, 收盘价: 58.42, 上轨: 61.45, 下轨: 55.45
# 2024-01-02, 收盘价: 57.29, 上轨: 61.38, 下轨: 55.33
# 2024-01-03, 收盘价: 56.23, 上轨: 61.43, 下轨: 55.15
# 2024-01-04, 收盘价: 55.57, 上轨: 61.54, 下轨: 54.83
# 2024-01-05, 收盘价: 55.34, 上轨: 61.63, 下轨: 54.61
# 2024-01-08, 收盘价: 54.29, 上轨: 61.85, 下轨: 54.11
# 2024-01-09, 收盘价: 56.22, 上轨: 61.67, 下轨: 53.94
# 2024-01-10, 收盘价: 54.62, 上轨: 61.47, 下轨: 53.59
# 2024-01-11, 收盘价: 56.65, 上轨: 61.19, 下轨: 53.56
# 2024-01-12, 收盘价: 55.27, 上轨: 60.55, 下轨: 53.60
# 2024-01-15, 收盘价: 54.09, 上轨: 60.21, 下轨: 53.34
# 2024-01-16, 收盘价: 53.37, 上轨: 60.04, 下轨: 52.93
# 2024-01-17, 收盘价: 52.29, 上轨: 59.86, 下轨: 52.40
# 2024-01-17, 买入信号 (收盘价<下轨), 全仓买入: 2105 股
# 2024-01-18, 买单执行, 价格: 51.70, 股数: 2105
# 2024-01-18, 收盘价: 53.74, 上轨: 59.56, 下轨: 52.21
# 2024-01-19, 收盘价: 54.81, 上轨: 58.87, 下轨: 52.40
# 2024-01-22, 收盘价: 53.78, 上轨: 58.45, 下轨: 52.35
# 2024-01-23, 收盘价: 53.85, 上轨: 58.33, 下轨: 52.19
# 2024-01-24, 收盘价: 51.67, 上轨: 58.54, 下轨: 51.64
# 2024-01-25, 收盘价: 51.37, 上轨: 58.44, 下轨: 51.15
# 2024-01-26, 收盘价: 49.51, 上轨: 58.58, 下轨: 50.25
# 2024-01-29, 收盘价: 48.35, 上轨: 58.44, 下轨: 49.39
# 2024-01-30, 收盘价: 47.17, 上轨: 58.54, 下轨: 48.28
# 2024-01-31, 收盘价: 44.94, 上轨: 58.99, 下轨: 46.70
# 2024-02-01, 收盘价: 46.50, 上轨: 58.99, 下轨: 45.79
# 2024-02-02, 收盘价: 44.54, 上轨: 59.13, 下轨: 44.57
# 2024-02-05, 收盘价: 44.33, 上轨: 59.23, 下轨: 43.47
# 2024-02-06, 收盘价: 47.44, 上轨: 58.64, 下轨: 43.19
# 2024-02-07, 收盘价: 48.42, 上轨: 58.20, 下轨: 43.01
# 2024-02-08, 收盘价: 49.61, 上轨: 57.33, 下轨: 43.17
# 2024-02-19, 收盘价: 51.65, 上轨: 56.81, 下轨: 43.34
# 2024-02-20, 收盘价: 51.35, 上轨: 56.45, 下轨: 43.42
# 2024-02-21, 收盘价: 50.50, 上轨: 56.12, 下轨: 43.47
# 2024-02-22, 收盘价: 51.05, 上轨: 55.98, 下轨: 43.48
# 2024-02-23, 收盘价: 51.31, 上轨: 55.63, 下轨: 43.58
# 2024-02-26, 收盘价: 51.90, 上轨: 55.10, 下轨: 43.82
# 2024-02-27, 收盘价: 53.10, 上轨: 54.97, 下轨: 43.88
# 2024-02-28, 收盘价: 50.48, 上轨: 54.45, 下轨: 44.07
# 2024-02-29, 收盘价: 51.90, 上轨: 54.49, 下轨: 44.06
# 2024-03-01, 收盘价: 52.86, 上轨: 54.72, 下轨: 43.97
# 2024-03-04, 收盘价: 54.53, 上轨: 55.43, 下轨: 43.77
# 2024-03-05, 收盘价: 54.16, 上轨: 56.01, 下轨: 43.76
# 2024-03-06, 收盘价: 52.38, 上轨: 56.23, 下轨: 44.07
# 2024-03-07, 收盘价: 51.00, 上轨: 56.05, 下轨: 44.85
# 2024-03-08, 收盘价: 52.06, 上轨: 56.06, 下轨: 45.40
# 2024-03-11, 收盘价: 51.77, 上轨: 55.61, 下轨: 46.57
# 2024-03-12, 收盘价: 52.67, 上轨: 54.84, 下轨: 48.17
# 2024-03-13, 收盘价: 52.62, 上轨: 54.56, 下轨: 48.97
# 2024-03-14, 收盘价: 51.50, 上轨: 54.26, 下轨: 49.58
# 2024-03-15, 收盘价: 52.10, 上轨: 54.13, 下轨: 49.96
# 2024-03-18, 收盘价: 52.40, 上轨: 54.17, 下轨: 50.00
# 2024-03-19, 收盘价: 48.52, 上轨: 54.53, 下轨: 49.35
# 2024-03-20, 收盘价: 47.36, 上轨: 55.01, 下轨: 48.56
# 2024-03-21, 收盘价: 49.38, 上轨: 55.08, 下轨: 48.32
# 2024-03-22, 收盘价: 49.01, 上轨: 55.16, 下轨: 48.01
# 2024-03-25, 收盘价: 47.67, 上轨: 55.33, 下轨: 47.42
# 2024-03-26, 收盘价: 46.77, 上轨: 55.40, 下轨: 46.71
# 2024-03-27, 收盘价: 45.04, 上轨: 55.86, 下轨: 45.71
# 2024-03-28, 收盘价: 46.19, 上轨: 55.92, 下轨: 45.08
# 2024-03-29, 收盘价: 45.69, 上轨: 55.83, 下轨: 44.45
# 2024-04-01, 收盘价: 45.54, 上轨: 55.34, 下轨: 44.04
# 2024-04-02, 收盘价: 45.49, 上轨: 54.80, 下轨: 43.71
# 2024-04-03, 收盘价: 45.01, 上轨: 54.54, 下轨: 43.24
# 2024-04-08, 收盘价: 43.65, 上轨: 54.52, 下轨: 42.53
# 2024-04-09, 收盘价: 44.00, 上轨: 54.19, 下轨: 42.04
# 2024-04-10, 收盘价: 42.90, 上轨: 53.91, 下轨: 41.44
# 2024-04-11, 收盘价: 46.88, 上轨: 53.19, 下轨: 41.58
# 2024-04-12, 收盘价: 47.66, 上轨: 52.42, 下轨: 41.85
# 2024-04-15, 收盘价: 48.77, 上轨: 51.96, 下轨: 42.04
# 2024-04-16, 收盘价: 47.50, 上轨: 51.16, 下轨: 42.38
# 2024-04-17, 收盘价: 49.21, 上轨: 50.35, 下轨: 42.87
# 2024-04-18, 收盘价: 47.37, 上轨: 50.21, 下轨: 42.90
# 2024-04-19, 收盘价: 45.64, 上轨: 50.13, 下轨: 42.81
# 2024-04-22, 收盘价: 46.46, 上轨: 49.73, 下轨: 42.91
# 2024-04-23, 收盘价: 45.90, 上轨: 49.35, 下轨: 42.99
# 2024-04-24, 收盘价: 46.82, 上轨: 49.24, 下轨: 43.00
# 2024-04-25, 收盘价: 48.02, 上轨: 49.40, 下轨: 42.97
# 2024-04-26, 收盘价: 50.48, 上轨: 50.13, 下轨: 42.79
# 2024-04-26, 卖出信号 (收盘价>上轨), 卖出全部: 2105 股
# 2024-04-29, 卖单执行, 价格: 50.41, 股数: -2105
# 2024-04-29, 收盘价: 51.03, 上轨: 50.87, 下轨: 42.53
# 2024-04-30, 收盘价: 50.62, 上轨: 51.42, 下轨: 42.47
# 2024-05-06, 收盘价: 50.76, 上轨: 51.93, 下轨: 42.49
# 2024-05-07, 收盘价: 50.25, 上轨: 52.27, 下轨: 42.62
# 2024-05-08, 收盘价: 50.58, 上轨: 52.60, 下轨: 42.85
# 2024-05-09, 收盘价: 50.77, 上轨: 52.75, 下轨: 43.41
# 2024-05-10, 收盘价: 50.58, 上轨: 52.80, 下轨: 44.02
# 2024-05-13, 收盘价: 50.57, 上轨: 52.47, 下轨: 45.12
# 2024-05-14, 收盘价: 50.23, 上轨: 52.58, 下轨: 45.34
# 2024-05-15, 收盘价: 49.39, 上轨: 52.62, 下轨: 45.47
# 2024-05-16, 收盘价: 48.93, 上轨: 52.63, 下轨: 45.48
# 2024-05-17, 收盘价: 49.18, 上轨: 52.64, 下轨: 45.64
# 2024-05-20, 收盘价: 49.84, 上轨: 52.68, 下轨: 45.66
# 2024-05-21, 收盘价: 49.61, 上轨: 52.70, 下轨: 45.86
# 2024-05-22, 收盘价: 50.97, 上轨: 52.60, 下轨: 46.50
# 2024-05-23, 收盘价: 50.51, 上轨: 52.47, 下轨: 47.03
# 2024-05-24, 收盘价: 49.46, 上轨: 52.01, 下轨: 47.84
# 2024-05-27, 收盘价: 52.32, 上轨: 52.01, 下轨: 48.40
# 2024-05-28, 收盘价: 52.26, 上轨: 52.14, 下轨: 48.69
# 2024-05-29, 收盘价: 52.49, 上轨: 52.46, 下轨: 48.57
# 2024-05-30, 收盘价: 52.55, 上轨: 52.72, 下轨: 48.46
# 2024-05-31, 收盘价: 52.69, 上轨: 53.01, 下轨: 48.38
# 2024-06-03, 收盘价: 54.06, 上轨: 53.60, 下轨: 48.12
# 2024-06-04, 收盘价: 53.32, 上轨: 53.94, 下轨: 48.09
# 2024-06-05, 收盘价: 51.77, 上轨: 54.01, 下轨: 48.14
# 2024-06-06, 收盘价: 51.21, 上轨: 54.03, 下轨: 48.16
# 2024-06-07, 收盘价: 50.60, 上轨: 54.03, 下轨: 48.17
# 2024-06-11, 收盘价: 51.11, 上轨: 54.05, 下轨: 48.20
# 2024-06-12, 收盘价: 51.60, 上轨: 54.09, 下轨: 48.29
# 2024-06-13, 收盘价: 52.70, 上轨: 54.20, 下轨: 48.51
# 2024-06-14, 收盘价: 53.00, 上轨: 54.26, 下轨: 48.86
# 2024-06-17, 收盘价: 53.83, 上轨: 54.43, 下轨: 49.16
# 2024-06-18, 收盘价: 54.38, 上轨: 54.73, 下轨: 49.31
# 2024-06-19, 收盘价: 55.17, 上轨: 55.10, 下轨: 49.50
# 2024-06-20, 收盘价: 56.08, 上轨: 55.73, 下轨: 49.38
# 2024-06-21, 收盘价: 56.81, 上轨: 56.40, 下轨: 49.34
# 2024-06-24, 收盘价: 57.13, 上轨: 56.89, 下轨: 49.62
# 2024-06-25, 收盘价: 54.96, 上轨: 57.06, 下轨: 49.71
# 2024-06-26, 收盘价: 56.30, 上轨: 57.44, 下轨: 49.74
# 2024-06-27, 收盘价: 56.05, 上轨: 57.72, 下轨: 49.81
# 2024-06-28, 收盘价: 57.16, 上轨: 58.17, 下轨: 49.82
# 2024-07-01, 收盘价: 56.48, 上轨: 58.45, 下轨: 49.92
# 2024-07-02, 收盘价: 55.55, 上轨: 58.57, 下轨: 49.95
# 2024-07-03, 收盘价: 56.06, 上轨: 58.75, 下轨: 50.05
# 2024-07-04, 收盘价: 56.06, 上轨: 58.85, 下轨: 50.38
# 2024-07-05, 收盘价: 56.06, 上轨: 58.83, 下轨: 50.88
# 2024-07-08, 收盘价: 59.53, 上轨: 59.27, 下轨: 51.33
# 2024-07-09, 收盘价: 59.78, 上轨: 59.67, 下轨: 51.80
# 2024-07-10, 收盘价: 60.60, 上轨: 60.19, 下轨: 52.18
# 2024-07-11, 收盘价: 62.22, 上轨: 61.13, 下轨: 52.19
# 2024-07-12, 收盘价: 63.66, 上轨: 62.29, 下轨: 52.10
# 2024-07-15, 收盘价: 64.30, 上轨: 63.43, 下轨: 52.00
# 2024-07-16, 收盘价: 65.03, 上轨: 64.58, 下轨: 51.92
# 2024-07-17, 收盘价: 63.21, 上轨: 65.16, 下轨: 52.14
# 2024-07-18, 收盘价: 63.00, 上轨: 65.66, 下轨: 52.34
# 2024-07-19, 收盘价: 63.01, 上轨: 66.11, 下轨: 52.51
# 2024-07-22, 收盘价: 63.93, 上轨: 66.66, 下轨: 52.64
# 2024-07-23, 收盘价: 58.80, 上轨: 66.53, 下轨: 53.15
# 2024-07-24, 收盘价: 58.98, 上轨: 66.48, 下轨: 53.47
# 2024-07-25, 收盘价: 58.20, 上轨: 66.39, 下轨: 53.77
# 2024-07-26, 收盘价: 58.23, 上轨: 66.36, 下轨: 53.91
# 2024-07-29, 收盘价: 58.00, 上轨: 66.29, 下轨: 54.13
# 2024-07-30, 收盘价: 58.47, 上轨: 66.11, 下轨: 54.60
# 2024-07-31, 收盘价: 59.60, 上轨: 65.96, 下轨: 55.11
# 2024-08-01, 收盘价: 59.26, 上轨: 65.76, 下轨: 55.63
# 2024-08-02, 收盘价: 56.60, 上轨: 65.69, 下轨: 55.75
# 2024-08-05, 收盘价: 53.20, 上轨: 66.35, 下轨: 54.46
# 2024-08-05, 买入信号 (收盘价<下轨), 全仓买入: 2018 股
# 2024-08-06, 订单取消/拒绝
# 2024-08-06, 收盘价: 53.17, 上轨: 66.80, 下轨: 53.34
# 2024-08-06, 买入信号 (收盘价<下轨), 全仓买入: 2019 股
# 2024-08-07, 买单执行, 价格: 53.08, 股数: 2019
# 2024-08-07, 收盘价: 52.86, 上轨: 67.11, 下轨: 52.27
# 2024-08-08, 收盘价: 53.24, 上轨: 67.07, 下轨: 51.41
# 2024-08-09, 收盘价: 53.00, 上轨: 66.71, 下轨: 50.70
# 2024-08-12, 收盘价: 53.80, 上轨: 66.02, 下轨: 50.34
# 2024-08-13, 收盘价: 54.86, 上轨: 64.97, 下轨: 50.37
# 2024-08-14, 收盘价: 53.75, 上轨: 64.22, 下轨: 50.18
# 2024-08-15, 收盘价: 54.10, 上轨: 63.36, 下轨: 50.14
# 2024-08-16, 收盘价: 53.85, 上轨: 62.35, 下轨: 50.24
# 2024-08-19, 收盘价: 55.31, 上轨: 60.81, 下轨: 50.92
# 2024-08-20, 收盘价: 55.06, 上轨: 60.45, 下轨: 50.91
# 2024-08-21, 收盘价: 54.83, 上轨: 60.00, 下轨: 50.94
# 2024-08-22, 收盘价: 54.16, 上轨: 59.65, 下轨: 50.88
# 2024-08-23, 收盘价: 54.00, 上轨: 59.25, 下轨: 50.86
# 2024-08-26, 收盘价: 53.10, 上轨: 58.86, 下轨: 50.76
# 2024-08-27, 收盘价: 52.13, 上轨: 58.34, 下轨: 50.65
# 2024-08-28, 收盘价: 50.94, 上轨: 57.43, 下轨: 50.69
# 2024-08-29, 收盘价: 51.35, 上轨: 56.27, 下轨: 51.06
# 2024-08-30, 收盘价: 52.63, 上轨: 55.73, 下轨: 51.21
# 2024-09-02, 收盘价: 49.95, 上轨: 56.04, 下轨: 50.57
# 2024-09-03, 收盘价: 52.94, 上轨: 56.03, 下轨: 50.56
# 2024-09-04, 收盘价: 52.09, 上轨: 56.03, 下轨: 50.47
# 2024-09-05, 收盘价: 52.00, 上轨: 56.03, 下轨: 50.36
# 2024-09-06, 收盘价: 51.74, 上轨: 56.03, 下轨: 50.23
# 2024-09-09, 收盘价: 51.30, 上轨: 55.99, 下轨: 50.01
# 2024-09-10, 收盘价: 51.50, 上轨: 55.77, 下轨: 49.91
# 2024-09-11, 收盘价: 51.81, 上轨: 55.67, 下轨: 49.81
# 2024-09-12, 收盘价: 51.21, 上轨: 55.53, 下轨: 49.66
# 2024-09-13, 收盘价: 51.07, 上轨: 55.40, 下轨: 49.51
# 2024-09-18, 收盘价: 49.30, 上轨: 55.10, 下轨: 49.21
# 2024-09-19, 收盘价: 48.96, 上轨: 54.80, 下轨: 48.91
# 2024-09-20, 收盘价: 49.59, 上轨: 54.35, 下轨: 48.82
# 2024-09-23, 收盘价: 48.50, 上轨: 54.12, 下轨: 48.49
# 2024-09-24, 收盘价: 50.03, 上轨: 53.68, 下轨: 48.53
# 2024-09-25, 收盘价: 49.91, 上轨: 53.40, 下轨: 48.50
# 2024-09-26, 收盘价: 52.28, 上轨: 53.42, 下轨: 48.49
# 2024-09-27, 收盘价: 57.00, 上轨: 54.87, 下轨: 47.65
# 2024-09-27, 卖出信号 (收盘价>上轨), 卖出全部: 2019 股
# 2024-09-30, 卖单执行, 价格: 59.46, 股数: -2019
# 2024-09-30, 收盘价: 66.88, 上轨: 59.74, 下轨: 44.33
# 2024-10-08, 收盘价: 80.26, 上轨: 67.94, 下轨: 38.89
# 2024-10-09, 收盘价: 78.41, 上轨: 72.88, 下轨: 36.80
# 2024-10-10, 收盘价: 70.89, 上轨: 75.05, 下轨: 36.42
# 2024-10-11, 收盘价: 65.52, 上轨: 76.10, 下轨: 36.72
# 2024-10-14, 收盘价: 66.93, 上轨: 77.25, 下轨: 37.06
# 2024-10-15, 收盘价: 65.00, 上轨: 78.03, 下轨: 37.61
# 2024-10-16, 收盘价: 62.30, 上轨: 78.44, 下轨: 38.30
# 2024-10-17, 收盘价: 61.34, 上轨: 78.71, 下轨: 39.01
# 2024-10-18, 收盘价: 68.95, 上轨: 79.76, 下轨: 39.68
# 2024-10-21, 收盘价: 69.93, 上轨: 80.77, 下轨: 40.54
# 2024-10-22, 收盘价: 70.94, 上轨: 81.73, 下轨: 41.56
# 2024-10-23, 收盘价: 68.65, 上轨: 82.08, 下轨: 43.15
# 2024-10-24, 收盘价: 69.00, 上轨: 82.21, 下轨: 45.02
# 2024-10-25, 收盘价: 70.01, 上轨: 82.26, 下轨: 47.02
# 2024-10-28, 收盘价: 69.09, 上轨: 81.73, 下轨: 49.60
# 2024-10-29, 收盘价: 67.92, 上轨: 80.95, 下轨: 52.17
# 2024-10-30, 收盘价: 69.08, 上轨: 79.73, 下轨: 55.30
# 2024-10-31, 收盘价: 68.41, 上轨: 78.34, 下轨: 58.31
# 2024-11-01, 收盘价: 64.55, 上轨: 77.47, 下轨: 59.93
# 2024-11-04, 收盘价: 66.05, 上轨: 77.47, 下轨: 59.85
# 2024-11-05, 收盘价: 69.00, 上轨: 75.14, 下轨: 61.06
# 2024-11-06, 收盘价: 68.40, 上轨: 72.82, 下轨: 62.38
# 2024-11-07, 收盘价: 70.38, 上轨: 72.74, 下轨: 62.41
# 2024-11-08, 收盘价: 70.63, 上轨: 73.06, 下轨: 62.59
# 2024-11-11, 收盘价: 78.11, 上轨: 75.25, 下轨: 61.52
# 2024-11-12, 收盘价: 74.40, 上轨: 76.01, 下轨: 61.70
# 2024-11-13, 收盘价: 75.39, 上轨: 76.54, 下轨: 62.48
# 2024-11-14, 收盘价: 71.70, 上轨: 76.03, 下轨: 64.03
# 2024-11-15, 收盘价: 68.73, 上轨: 76.02, 下轨: 64.01
# 2024-11-18, 收盘价: 66.20, 上轨: 76.06, 下轨: 63.60
# 2024-11-19, 收盘价: 68.16, 上轨: 75.94, 下轨: 63.44
# 2024-11-20, 收盘价: 67.96, 上轨: 75.94, 下轨: 63.38
# 2024-11-21, 收盘价: 67.60, 上轨: 75.93, 下轨: 63.25
# 2024-11-22, 收盘价: 63.91, 上轨: 76.08, 下轨: 62.48
# 2024-11-25, 收盘价: 63.63, 上轨: 76.24, 下轨: 61.78
# 2024-11-26, 收盘价: 63.11, 上轨: 76.44, 下轨: 61.10
# 2024-11-27, 收盘价: 66.69, 上轨: 76.37, 下轨: 60.93
# 2024-11-28, 收盘价: 66.52, 上轨: 76.33, 下轨: 60.78
# 2024-11-29, 收盘价: 67.38, 上轨: 76.28, 下轨: 61.12
# 2024-12-02, 收盘价: 69.13, 上轨: 76.33, 下轨: 61.37
# 2024-12-03, 收盘价: 68.34, 上轨: 76.30, 下轨: 61.33
# 2024-12-04, 收盘价: 67.83, 上轨: 76.29, 下轨: 61.29
# 2024-12-05, 收盘价: 68.30, 上轨: 76.15, 下轨: 61.22
# 2024-12-06, 收盘价: 70.18, 上轨: 76.11, 下轨: 61.22
# 2024-12-09, 收盘价: 68.82, 上轨: 74.26, 下轨: 62.14
# 2024-12-10, 收盘价: 68.39, 上轨: 73.25, 下轨: 62.55
# 2024-12-11, 收盘价: 68.89, 上轨: 71.72, 下轨: 63.43
# 2024-12-12, 收盘价: 68.70, 上轨: 71.16, 下轨: 63.69
# 2024-12-13, 收盘价: 68.02, 上轨: 71.08, 下轨: 63.69
# 2024-12-16, 收盘价: 68.95, 上轨: 71.24, 下轨: 63.81
# 2024-12-17, 收盘价: 66.87, 上轨: 71.17, 下轨: 63.75
# 2024-12-18, 收盘价: 68.80, 上轨: 71.26, 下轨: 63.75
# 2024-12-19, 收盘价: 70.79, 上轨: 71.68, 下轨: 63.64
# 2024-12-20, 收盘价: 72.52, 上轨: 72.25, 下轨: 63.93
# 2024-12-23, 收盘价: 70.92, 上轨: 72.25, 下轨: 64.66
# 2024-12-24, 收盘价: 72.18, 上轨: 72.17, 下轨: 65.65
# 2024-12-25, 收盘价: 72.41, 上轨: 72.63, 下轨: 65.77
# 2024-12-26, 收盘价: 79.99, 上轨: 75.51, 下轨: 64.23
# 2024-12-27, 收盘价: 75.48, 上轨: 76.29, 下轨: 64.26
# 2024-12-30, 收盘价: 71.19, 上轨: 76.38, 下轨: 64.37
# 2024-12-31, 收盘价: 67.90, 上轨: 76.39, 下轨: 64.32
# 2025-01-02, 收盘价: 65.93, 上轨: 76.51, 下轨: 64.01
# 2025-01-03, 收盘价: 65.52, 上轨: 76.66, 下轨: 63.59
# 2025-01-06, 收盘价: 63.91, 上轨: 76.88, 下轨: 62.74
# 2025-01-07, 收盘价: 66.41, 上轨: 76.91, 下轨: 62.47
# 2025-01-08, 收盘价: 66.82, 上轨: 76.92, 下轨: 62.30
# 2025-01-09, 收盘价: 66.30, 上轨: 76.92, 下轨: 62.04
# 2025-01-10, 收盘价: 64.20, 上轨: 77.04, 下轨: 61.47
# 2025-01-13, 收盘价: 62.91, 上轨: 77.25, 下轨: 60.75
# 2025-01-14, 收盘价: 66.43, 上轨: 77.20, 下轨: 60.54
# 2025-01-15, 收盘价: 66.20, 上轨: 77.21, 下轨: 60.47
# 2025-01-16, 收盘价: 66.01, 上轨: 77.16, 下轨: 60.24
# 2025-01-17, 收盘价: 66.67, 上轨: 76.94, 下轨: 60.05
# 2025-01-20, 收盘价: 67.28, 上轨: 76.49, 下轨: 59.98
# 2025-01-21, 收盘价: 70.08, 上轨: 76.40, 下轨: 59.99
# 2025-01-22, 收盘价: 71.32, 上轨: 76.28, 下轨: 60.02
# 2025-01-23, 收盘价: 70.10, 上轨: 75.98, 下轨: 60.08
# 2025-01-24, 收盘价: 70.84, 上轨: 73.52, 下轨: 61.63
# 2025-01-27, 收盘价: 68.04, 上轨: 71.93, 下轨: 62.48
# 2025-02-05, 收盘价: 69.40, 上轨: 71.59, 下轨: 62.63
# 2025-02-06, 收盘价: 71.33, 上轨: 72.12, 下轨: 62.45
# 2025-02-07, 收盘价: 72.35, 上轨: 72.87, 下轨: 62.34
# 2025-02-10, 收盘价: 72.61, 上轨: 73.56, 下轨: 62.36
# 2025-02-11, 收盘价: 71.78, 上轨: 73.87, 下轨: 62.84
# 2025-02-12, 收盘价: 72.43, 上轨: 74.36, 下轨: 62.95
# 2025-02-13, 收盘价: 70.00, 上轨: 74.49, 下轨: 63.14
# 2025-02-14, 收盘价: 73.31, 上轨: 75.04, 下轨: 63.29
# 2025-02-17, 收盘价: 74.79, 上轨: 75.59, 下轨: 63.80
# 2025-02-18, 收盘价: 71.90, 上轨: 75.21, 下轨: 65.07
# 2025-02-19, 收盘价: 73.34, 上轨: 75.44, 下轨: 65.54
# 2025-02-20, 收盘价: 72.44, 上轨: 75.41, 下轨: 66.20
# 2025-02-21, 收盘价: 77.01, 上轨: 76.16, 下轨: 66.54
# 2025-02-24, 收盘价: 77.67, 上轨: 76.95, 下轨: 66.85
# 2025-02-25, 收盘价: 79.84, 上轨: 78.21, 下轨: 66.85
# 2025-02-26, 收盘价: 81.66, 上轨: 79.92, 下轨: 66.30
# 2025-02-27, 收盘价: 83.68, 上轨: 81.89, 下轨: 65.57
# 2025-02-27, 策略结束，期末资金: 120239.20
# 2023-05-23, 买入信号 (MACD>Signal), 全仓买入: 1752 股, 当前收盘价: 57.06
# 2023-05-24, 买单执行, 价格: 56.78, 股数: 1752
# 2023-06-09, 卖出信号 (MACD<Signal), 卖出全部: 1752 股
# 2023-06-12, 卖单执行, 价格: 57.65, 股数: -1752
# 2023-06-13, 买入信号 (MACD>Signal), 全仓买入: 1633 股, 当前收盘价: 62.16
# 2023-06-14, 买单执行, 价格: 61.50, 股数: 1633
# 2023-06-26, 卖出信号 (MACD<Signal), 卖出全部: 1633 股
# 2023-06-27, 卖单执行, 价格: 55.93, 股数: -1633
# 2023-07-04, 买入信号 (MACD>Signal), 全仓买入: 1490 股, 当前收盘价: 62.01
# 2023-07-05, 买单执行, 价格: 61.66, 股数: 1490
# 2023-07-19, 卖出信号 (MACD<Signal), 卖出全部: 1490 股
# 2023-07-20, 卖单执行, 价格: 58.68, 股数: -1490
# 2023-08-29, 买入信号 (MACD>Signal), 全仓买入: 1741 股, 当前收盘价: 50.51
# 2023-08-30, 订单取消/拒绝
# 2023-10-09, 买入信号 (MACD>Signal), 全仓买入: 1748 股, 当前收盘价: 50.32
# 2023-10-10, 订单取消/拒绝
# 2023-10-30, 买入信号 (MACD>Signal), 全仓买入: 1650 股, 当前收盘价: 53.29
# 2023-10-31, 订单取消/拒绝
# 2023-12-14, 买入信号 (MACD>Signal), 全仓买入: 1436 股, 当前收盘价: 61.24
# 2023-12-15, 订单取消/拒绝
# 2024-02-08, 买入信号 (MACD>Signal), 全仓买入: 1773 股, 当前收盘价: 49.61
# 2024-02-19, 订单取消/拒绝
# 2024-04-12, 买入信号 (MACD>Signal), 全仓买入: 1845 股, 当前收盘价: 47.66
# 2024-04-15, 订单取消/拒绝
# 2024-05-22, 买入信号 (MACD>Signal), 全仓买入: 1725 股, 当前收盘价: 50.97
# 2024-05-23, 订单取消/拒绝
# 2024-05-27, 买入信号 (MACD>Signal), 全仓买入: 1681 股, 当前收盘价: 52.32
# 2024-05-28, 买单执行, 价格: 52.00, 股数: 1681
# 2024-06-06, 卖出信号 (MACD<Signal), 卖出全部: 1681 股
# 2024-06-07, 卖单执行, 价格: 51.55, 股数: -1681
# 2024-06-17, 买入信号 (MACD>Signal), 全仓买入: 1620 股, 当前收盘价: 53.83
# 2024-06-18, 订单取消/拒绝
# 2024-07-08, 买入信号 (MACD>Signal), 全仓买入: 1465 股, 当前收盘价: 59.53
# 2024-07-09, 买单执行, 价格: 59.40, 股数: 1465
# 2024-07-23, 卖出信号 (MACD<Signal), 卖出全部: 1465 股
# 2024-07-24, 卖单执行, 价格: 59.65, 股数: -1465
# 2024-08-21, 买入信号 (MACD>Signal), 全仓买入: 1597 股, 当前收盘价: 54.83
# 2024-08-22, 订单取消/拒绝
# 2024-09-05, 买入信号 (MACD>Signal), 全仓买入: 1684 股, 当前收盘价: 52.00
# 2024-09-06, 订单取消/拒绝
# 2024-09-26, 买入信号 (MACD>Signal), 全仓买入: 1675 股, 当前收盘价: 52.28
# 2024-09-27, 订单取消/拒绝
# 2024-11-11, 买入信号 (MACD>Signal), 全仓买入: 1121 股, 当前收盘价: 78.11
# 2024-11-12, 订单取消/拒绝
# 2024-12-06, 买入信号 (MACD>Signal), 全仓买入: 1248 股, 当前收盘价: 70.18
# 2024-12-09, 买单执行, 价格: 70.00, 股数: 1248
# 2024-12-17, 卖出信号 (MACD<Signal), 卖出全部: 1248 股
# 2024-12-18, 卖单执行, 价格: 67.21, 股数: -1248
# 2024-12-19, 买入信号 (MACD>Signal), 全仓买入: 1188 股, 当前收盘价: 70.79
# 2024-12-20, 买单执行, 价格: 70.00, 股数: 1188
# 2025-01-02, 卖出信号 (MACD<Signal), 卖出全部: 1188 股
# 2025-01-03, 卖单执行, 价格: 66.23, 股数: -1188
# 2025-01-21, 买入信号 (MACD>Signal), 全仓买入: 1136 股, 当前收盘价: 70.08
# 2025-01-22, 买单执行, 价格: 69.95, 股数: 1136
# 2025-02-27, 策略结束，期末资金: 95230.57
# 策略绩效对比：
#                  Sharpe Ratio  Max Drawdown (%)  Annual Return (%)
# RSI                  1.368165         17.200765          61.413844
# Bollinger Bands      1.191044         24.424762          10.072005
# MACD                -0.147973         30.258312          -2.512331
# MA Cross            -1.783275         29.355307         -13.848914

# %%
# ---------------------------
# 5. 可视化绩效比较
# ---------------------------
# %matplotlib inline
plt.figure(figsize=(14, 12))

plt.subplot(3, 1, 1)
performance_df['Annual Return (%)'].plot(kind='bar', color='green')
plt.title('年化收益率比较')
plt.ylabel('年化收益率 (%)')
plt.grid(axis='y', alpha=0.3)

plt.subplot(3, 1, 2)
performance_df['Max Drawdown (%)'].plot(kind='bar', color='red')
plt.title('最大回撤比较')
plt.ylabel('最大回撤 (%)')
plt.grid(axis='y', alpha=0.3)

plt.subplot(3, 1, 3)
performance_df['Sharpe Ratio'].plot(kind='bar', color='blue')
plt.title('夏普比率比较')
plt.ylabel('夏普比率')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 策略参数优化
#
# 优化表现最好的策略的参数：

# %%
# 假设我们要优化移动平均线交叉策略的参数

# 定义要优化的参数范围
fast_periods = range(5, 30, 5)  # 5, 10, 15, 20, 25
slow_periods = range(30, 100, 10)  # 30, 40, 50, 60, 70, 80, 90

# 存储优化结果
optimization_results = []

# 创建Cerebro引擎
cerebro = bt.Cerebro(optreturn=False)

# 添加数据
cerebro.adddata(create_bt_data_feed(csv_file))

# 添加策略进行优化
cerebro.optstrategy(
    MovingAverageCrossStrategy,
    fast_period=fast_periods,
    slow_period=slow_periods,
    ma_type='SMA'
)

# 设置初始资金和佣金
cerebro.broker.setcash(100000.0)
cerebro.broker.setcommission(commission=0.001)

# 添加分析器
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe')
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')

# 运行优化
print("正在优化参数，这可能需要一些时间...")
results = cerebro.run()

# 处理优化结果
for run in results:
    # 注意：每次run都是一组参数的策略运行结果
    fast_period = run[0].params.fast_period
    slow_period = run[0].params.slow_period
    
    # 获取性能指标
    sharpe = run[0].analyzers.sharpe.get_analysis()["sharperatio"]
    max_dd = run[0].analyzers.drawdown.get_analysis()["max"]["drawdown"]
    annual_return = run[0].analyzers.returns.get_analysis()["rnorm100"]
    
    # 存储结果
    optimization_results.append({
        'fast_period': fast_period,
        'slow_period': slow_period,
        'Sharpe Ratio': sharpe,
        'Max Drawdown (%)': max_dd,
        'Annual Return (%)': annual_return
    })

# 转换为DataFrame
optimization_df = pd.DataFrame(optimization_results)

# 按夏普比率排序
optimization_df = optimization_df.sort_values('Sharpe Ratio', ascending=False)

# 显示前10个最佳参数组合
print("=== 按夏普比率排序的前10个最佳参数组合 ===")
optimization_df.head(10)

# %%
# 获取最佳参数
best_params = optimization_df.iloc[0]
print(f"最佳参数组合: 快线周期={int(best_params['fast_period'])}, 慢线周期={int(best_params['slow_period'])}")
print(f"夏普比率: {best_params['Sharpe Ratio']:.4f}")
print(f"最大回撤: {best_params['Max Drawdown (%)']:.2f}%")
print(f"年化收益率: {best_params['Annual Return (%)']:.2f}%")

# 使用最佳参数运行回测
data_feed = create_bt_data_feed(csv_file)
best_cerebro, best_strategy, best_results = run_backtest(
    MovingAverageCrossStrategy, 
    data_feed,
    fast_period=int(best_params['fast_period']),
    slow_period=int(best_params['slow_period']),
    ma_type='SMA'
)

# 绘制回测结果
best_cerebro.plot(style='candlestick', barup='green', bardown='red')

# %% [markdown]
# ## 结论与后续研究
#
# 在本笔记本中，我们比较了多种交易策略，并优化了表现最好的策略参数。
#
# 主要发现：
#
# 1. 策略性能比较结果表明，不同策略在不同市场环境下表现各异
# 2. 参数优化可以显著提高策略性能，但需要注意过拟合风险
# 3. 良好的风险管理比简单追求高收益更重要
#
# 后续研究方向：
#
# 1. 结合多个策略创建集成策略
# 2. 添加止损和风险控制机制
# 3. 扩展到多资产组合策略
# 4. 引入机器学习方法优化策略
# 5. 研究策略在不同市场条件下的表现
#
# 最终，成功的量化交易需要平衡数学模型、技术实现和风险管理，关注长期稳定的风险调整后收益，而非追求短期高收益。
